# %%
### IMPORT SCIENTIFIC LIBRARIES ###
import numpy as np
import pandas as pd
from scipy import sparse
from scipy.optimize import curve_fit
import importlib

import matplotlib.pyplot as plt
#import seaborn as sns
plt.rcParams['font.size'], plt.rcParams['axes.labelsize'] = 14, 18
#%matplotlib widget

from tqdm import tqdm
import io, sys
from contextlib import redirect_stdout, redirect_stderr

import os

import h5py
import hdf5plugin

import sys
sys.path.append('./XPCS_library/')

import ID10_tools as ID10
from ID10_tools import Nx, Ny, Npx
importlib.reload(ID10)
ID10.set_version('v2')

import XPCS_tools as XPCS
from XPCS_tools import E2lambda, lambda2E, theta2Q, Q2theta, decorelation_f
importlib.reload(XPCS)
XPCS.set_beamline('ID10')

import COSMICRAY_tools as COSMIC
importlib.reload(COSMIC)
COSMIC.set_beamline('ID10')

# RAW FOLDER PATH
raw_folder = '../RAW_DATA/'
masks_folder = '../masks/'
fit_outs_folder = './data/fit_outs/'
Idts_folder = './data/Idts/'
g2_folder = './data/g2/'

# EXPERIMENTAL VARIABLES
XPCS.set_expvar(1350, 1350, 7)
ID10.Nfmax_dense_file = 2000
ID10.Nfmax_sparse_file = 5000

# %% [markdown]
# ## Load masks

# %%
e4m_htmask = np.load(masks_folder+'e4m_htmask_copper_foil_30um_1_1'+'.npy')
e4m_mask = np.load(masks_folder+'e4m_mask'+'.npy')
#bs_mask = np.load(masks_folder+'bs_mask_copper_foil_30um'+'.npy')  # beam-stop mask

# %%
plt.figure(figsize=(8, 8))
plt.imshow((e4m_mask*e4m_htmask).reshape(Nx,Ny), cmap='gray', origin='lower')

# %% [markdown]
# ### BS mask and Q definition
# Using a random scan in GeO2_6, because we are not changing the measurement configuration

# %% [markdown]
# #### Beamstop mask

# %%
#######################################
sample_name = 'GeO2_6'
Ndataset = 1
Nscan =12
Nfi, Nff = 0, 1000
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
# Out:
# #############################
# command = mtimescan 0.02 1 220000
# Ei = 9.699998837562536
# itime = 0.0201
# theta = 1.7500000000000004
# Q = 0.15
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/1 loops)
# Done!
# Concatenating vectors ...
# Done!
# 	 | Sparse array loaded from ../RAW_DATA/GeO2_6/GeO2_6_0001/scan0012/
# 	 | Shape:       (1000, 4471016)
# 	 | Sparsity:     3.8e-03
# 	 | Memory usage (scipy.csr_array): 0.192 GB (np.array usage: 16.656 GB)

# %%
geom = [{'geom':'Rectangle', 'x0':1250, 'y0':1300, 'xl':250, 'yl':1950, 'inside':False},
        {'geom':'Circle', 'Cx':1300, 'Cy':950, 'r':1470, 'inside':True}, 
        ]
XPCS.gen_plots4mask(e4m_data, itime, Ith_high=1, Nff=10000, mask_geom=geom,)
# Out:
# ################################################################################
# Maximum count in the hull run -> 4689
# # of pixels above Ith_high treshold ->  75 pixels (of 4471016 => 0.0 %)
# ################################################################################

# %%
bs_mask = XPCS.gen_mask(e4m_data, itime, e4m_mask=None, mask_geom=geom)
# Out:
# #################################################
# Masked area =  93.74594052000708 %
# #################################################

# %% [markdown]
# #### Q mask

# %%
Qmask = XPCS.gen_Qmask(Ei, theta, .19, .02, Qmap_plot=True)

# %% [markdown]
# ## XPCS mesh (T = 730C Q =  0.13 Å, 30 min @ 1ms (1_800_000 fm)) (GeO2_3, dataset 1, scan 4)

# %%
#######################################
sample_name = 'GeO2_3_730C_Q'
Ndataset = 1
Nscan = 4
Nfi, Nff =  None, None
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
#e4m_data = ID10.load_dense_e4m_new(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )

e4m_data = COSMIC.fast_gamma_filter(e4m_data, Imaxth_high=5)
# Out:
# #############################
# command = mtimescan 0.001 1 1800288
# Ei = 9.699998837562536
# itime = 0.0011
# theta = 1.0000000000000004
# Q = 0.09
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00001.h5 (2/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00002.h5 (3/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00003.h5 (4/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00004.h5 (5/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00005.h5 (6/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00006.h5 (7/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00007.h5 (8/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00008.h5 (9/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00009.h5 (10/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00010.h5 (11/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00011.h5 (12/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00012.h5 (13/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00013.h5 (14/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00014.h5 (15/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00015.h5 (16/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00016.h5 (17/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00017.h5 (18/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00018.h5 (19/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00019.h5 (20/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00020.h5 (21/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00021.h5 (22/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00022.h5 (23/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00023.h5 (24/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00024.h5 (25/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00025.h5 (26/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00026.h5 (27/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00027.h5 (28/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00028.h5 (29/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00029.h5 (30/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00030.h5 (31/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00031.h5 (32/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00032.h5 (33/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00033.h5 (34/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00034.h5 (35/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00035.h5 (36/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00036.h5 (37/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00037.h5 (38/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00038.h5 (39/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00039.h5 (40/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00040.h5 (41/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00041.h5 (42/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00042.h5 (43/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00043.h5 (44/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00044.h5 (45/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00045.h5 (46/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00046.h5 (47/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00047.h5 (48/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00048.h5 (49/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00049.h5 (50/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00050.h5 (51/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00051.h5 (52/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00052.h5 (53/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00053.h5 (54/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00054.h5 (55/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00055.h5 (56/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00056.h5 (57/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00057.h5 (58/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00058.h5 (59/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00059.h5 (60/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00060.h5 (61/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00061.h5 (62/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00062.h5 (63/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00063.h5 (64/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00064.h5 (65/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00065.h5 (66/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00066.h5 (67/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00067.h5 (68/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00068.h5 (69/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00069.h5 (70/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00070.h5 (71/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00071.h5 (72/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00072.h5 (73/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00073.h5 (74/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00074.h5 (75/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00075.h5 (76/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00076.h5 (77/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00077.h5 (78/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00078.h5 (79/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00079.h5 (80/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00080.h5 (81/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00081.h5 (82/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00082.h5 (83/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00083.h5 (84/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00084.h5 (85/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00085.h5 (86/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00086.h5 (87/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00087.h5 (88/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00088.h5 (89/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00089.h5 (90/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00090.h5 (91/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00091.h5 (92/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00092.h5 (93/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00093.h5 (94/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00094.h5 (95/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00095.h5 (96/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00096.h5 (97/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00097.h5 (98/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00098.h5 (99/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00099.h5 (100/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00100.h5 (101/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00101.h5 (102/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00102.h5 (103/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00103.h5 (104/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00104.h5 (105/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00105.h5 (106/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00106.h5 (107/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00107.h5 (108/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00108.h5 (109/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00109.h5 (110/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00110.h5 (111/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00111.h5 (112/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00112.h5 (113/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00113.h5 (114/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00114.h5 (115/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00115.h5 (116/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00116.h5 (117/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00117.h5 (118/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00118.h5 (119/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00119.h5 (120/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00120.h5 (121/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00121.h5 (122/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00122.h5 (123/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00123.h5 (124/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00124.h5 (125/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00125.h5 (126/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00126.h5 (127/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00127.h5 (128/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00128.h5 (129/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00129.h5 (130/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00130.h5 (131/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00131.h5 (132/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00132.h5 (133/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00133.h5 (134/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00134.h5 (135/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00135.h5 (136/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00136.h5 (137/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00137.h5 (138/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00138.h5 (139/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00139.h5 (140/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00140.h5 (141/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00141.h5 (142/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00142.h5 (143/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00143.h5 (144/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00144.h5 (145/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00145.h5 (146/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00146.h5 (147/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00147.h5 (148/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00148.h5 (149/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00149.h5 (150/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00150.h5 (151/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00151.h5 (152/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00152.h5 (153/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00153.h5 (154/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00154.h5 (155/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00155.h5 (156/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00156.h5 (157/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00157.h5 (158/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00158.h5 (159/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00159.h5 (160/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00160.h5 (161/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00161.h5 (162/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00162.h5 (163/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00163.h5 (164/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00164.h5 (165/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00165.h5 (166/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00166.h5 (167/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00167.h5 (168/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00168.h5 (169/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00169.h5 (170/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00170.h5 (171/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00171.h5 (172/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00172.h5 (173/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00173.h5 (174/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00174.h5 (175/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00175.h5 (176/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00176.h5 (177/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00177.h5 (178/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00178.h5 (179/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00179.h5 (180/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00180.h5 (181/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00181.h5 (182/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00182.h5 (183/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00183.h5 (184/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00184.h5 (185/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00185.h5 (186/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00186.h5 (187/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00187.h5 (188/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00188.h5 (189/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00189.h5 (190/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00190.h5 (191/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00191.h5 (192/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00192.h5 (193/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00193.h5 (194/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00194.h5 (195/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00195.h5 (196/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00196.h5 (197/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00197.h5 (198/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00198.h5 (199/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00199.h5 (200/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00200.h5 (201/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00201.h5 (202/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00202.h5 (203/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00203.h5 (204/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00204.h5 (205/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00205.h5 (206/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00206.h5 (207/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00207.h5 (208/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00208.h5 (209/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00209.h5 (210/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00210.h5 (211/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00211.h5 (212/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00212.h5 (213/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00213.h5 (214/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00214.h5 (215/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00215.h5 (216/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00216.h5 (217/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00217.h5 (218/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00218.h5 (219/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00219.h5 (220/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00220.h5 (221/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00221.h5 (222/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00222.h5 (223/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00223.h5 (224/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00224.h5 (225/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00225.h5 (226/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00226.h5 (227/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00227.h5 (228/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00228.h5 (229/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00229.h5 (230/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00230.h5 (231/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00231.h5 (232/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00232.h5 (233/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00233.h5 (234/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00234.h5 (235/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00235.h5 (236/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00236.h5 (237/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00237.h5 (238/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00238.h5 (239/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00239.h5 (240/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00240.h5 (241/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00241.h5 (242/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00242.h5 (243/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00243.h5 (244/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00244.h5 (245/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00245.h5 (246/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00246.h5 (247/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00247.h5 (248/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00248.h5 (249/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00249.h5 (250/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00250.h5 (251/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00251.h5 (252/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00252.h5 (253/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00253.h5 (254/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00254.h5 (255/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00255.h5 (256/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00256.h5 (257/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00257.h5 (258/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00258.h5 (259/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00259.h5 (260/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00260.h5 (261/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00261.h5 (262/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00262.h5 (263/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00263.h5 (264/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00264.h5 (265/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00265.h5 (266/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00266.h5 (267/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00267.h5 (268/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00268.h5 (269/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00269.h5 (270/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00270.h5 (271/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00271.h5 (272/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00272.h5 (273/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00273.h5 (274/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00274.h5 (275/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00275.h5 (276/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00276.h5 (277/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00277.h5 (278/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00278.h5 (279/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00279.h5 (280/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00280.h5 (281/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00281.h5 (282/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00282.h5 (283/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00283.h5 (284/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00284.h5 (285/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00285.h5 (286/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00286.h5 (287/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00287.h5 (288/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00288.h5 (289/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00289.h5 (290/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00290.h5 (291/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00291.h5 (292/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00292.h5 (293/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00293.h5 (294/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00294.h5 (295/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00295.h5 (296/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00296.h5 (297/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00297.h5 (298/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00298.h5 (299/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00299.h5 (300/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00300.h5 (301/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00301.h5 (302/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00302.h5 (303/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00303.h5 (304/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00304.h5 (305/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00305.h5 (306/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00306.h5 (307/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00307.h5 (308/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00308.h5 (309/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00309.h5 (310/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00310.h5 (311/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00311.h5 (312/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00312.h5 (313/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00313.h5 (314/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00314.h5 (315/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00315.h5 (316/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00316.h5 (317/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00317.h5 (318/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00318.h5 (319/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00319.h5 (320/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00320.h5 (321/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00321.h5 (322/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00322.h5 (323/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00323.h5 (324/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00324.h5 (325/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00325.h5 (326/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00326.h5 (327/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00327.h5 (328/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00328.h5 (329/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00329.h5 (330/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00330.h5 (331/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00331.h5 (332/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00332.h5 (333/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00333.h5 (334/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00334.h5 (335/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00335.h5 (336/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00336.h5 (337/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00337.h5 (338/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00338.h5 (339/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00339.h5 (340/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00340.h5 (341/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00341.h5 (342/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00342.h5 (343/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00343.h5 (344/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00344.h5 (345/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00345.h5 (346/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00346.h5 (347/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00347.h5 (348/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00348.h5 (349/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00349.h5 (350/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00350.h5 (351/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00351.h5 (352/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00352.h5 (353/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00353.h5 (354/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00354.h5 (355/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00355.h5 (356/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00356.h5 (357/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00357.h5 (358/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00358.h5 (359/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00359.h5 (360/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00360.h5 (361/361 loops)
# Done!
# Concatenating vectors ...
# Done!
# 	 | Sparse array loaded from ../RAW_DATA/GeO2_3_730C_Q/GeO2_3_730C_Q_0001/scan0004/
# 	 | Shape:       (1800288, 4471016)
# 	 | Sparsity:     1.7e-04
# 	 | Memory usage (scipy.csr_array): 11.580 GB (np.array usage: 29985.295 GB)
# Filtering gamma ray signal (i.e. signals over treshold) ...
# Done! (elapsed time = 5.63 s)
# Removing gamma ray signal (set 0s) ...
# Done! (elapsed time = 7.22 s)

# %% [markdown]
# ### Qmask

# %%
###################
Q    = .13
Qres = .02
###################

Qmask = XPCS.gen_Qmask(Ei, theta, Q, Qres, Qmap_plot=True)

# %% [markdown]
# ### Flux check

# %%
#############################################
mask = e4m_mask * e4m_htmask * bs_mask
#############################################

XPCS.gen_plots4mask(e4m_data, itime, Ith_high= .4, Nff=100_000, e4m_mask=mask)
# Out:
# ################################################################################
# Maximum count in the hull run -> 5
# # of pixels above Ith_high treshold ->  54 pixels (of 4471016 => 0.0 %)
# ################################################################################

# %% [markdown]
# ### Intensity analysis

# %%
####################
Lbin = 1
Nstep = 100
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
####################

t_It, It = XPCS.get_It(e4m_data, itime, mask=mask, Lbin=Lbin, Nstep=Nstep)
np.savez(Idts_folder+'Idt_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4), t_It=t_It, It=It)

# %%
plt.figure(figsize=(10,5))
plt.scatter(t_It, It, label='It')

plt.xlabel('Time (s)')
plt.ylabel('Integrated intensity [photons/pixel/s]')
plt.xscale('log')
#plt.xlim(1e-2, 1)
plt.gca().secondary_xaxis('top', functions=(lambda x: x/itime, lambda x: x*itime))
plt.grid()

# %% [markdown]
# ### Correlation

# %%
###################
Nfi = 100_000
Nff = None
Lbin = 1
Nbunch = 100
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
###################
if Lbin is None: Lbin=1

G2t = XPCS.get_G2t_bybunch(e4m_data, mask=mask, Nfi=Nfi, Nff=Nff, Lbin=Lbin, Nbunch=Nbunch)
# Out:
# Computing G2t for bunch 1 (Nfi = 100000 , Nff = 117002 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.113 GB
# Masking data ...
# Done! (elapsed time = 0.53 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.87e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.039 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.19 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.95 s)
#
# Done!
#
# Computing G2t for bunch 2 (Nfi = 117002 , Nff = 134004 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.113 GB
# Masking data ...
# Done! (elapsed time = 0.59 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.86e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.039 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.33 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.27 s)
#
# Done!
#
# Computing G2t for bunch 3 (Nfi = 134004 , Nff = 151006 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.76e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.112 GB
# Masking data ...
# Done! (elapsed time = 0.56 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.86e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.039 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.17 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.05 s)
#
# Done!
#
# Computing G2t for bunch 4 (Nfi = 151006 , Nff = 168008 ) ...
# Loading frames ...
# Done! (elapsed time = 0.14 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.75e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.112 GB
# Masking data ...
# Done! (elapsed time = 0.45 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.85e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.039 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.33 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.26 s)
#
# Done!
#
# Computing G2t for bunch 5 (Nfi = 168008 , Nff = 185010 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.74e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.111 GB
# Masking data ...
# Done! (elapsed time = 0.47 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.12 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.0 s)
#
# Done!
#
# Computing G2t for bunch 6 (Nfi = 185010 , Nff = 202012 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.74e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.111 GB
# Masking data ...
# Done! (elapsed time = 0.47 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.26 s)
#
# Done!
#
# Computing G2t for bunch 7 (Nfi = 202012 , Nff = 219014 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.73e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.111 GB
# Masking data ...
# Done! (elapsed time = 0.39 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.15 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.13 s)
#
# Done!
#
# Computing G2t for bunch 8 (Nfi = 219014 , Nff = 236016 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.73e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.11 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.32 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.28 s)
#
# Done!
#
# Computing G2t for bunch 9 (Nfi = 236016 , Nff = 253018 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.73e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.11 GB
# Masking data ...
# Done! (elapsed time = 0.59 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.22 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.98 s)
#
# Done!
#
# Computing G2t for bunch 10 (Nfi = 253018 , Nff = 270020 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.73e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.11 GB
# Masking data ...
# Done! (elapsed time = 0.58 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.28 s)
#
# Done!
#
# Computing G2t for bunch 11 (Nfi = 270020 , Nff = 287022 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.72e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.11 GB
# Masking data ...
# Done! (elapsed time = 0.93 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.23 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.06 s)
#
# Done!
#
# Computing G2t for bunch 12 (Nfi = 287022 , Nff = 304024 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.72e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.11 GB
# Masking data ...
# Done! (elapsed time = 1.0 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.44 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.49 s)
#
# Done!
#
# Computing G2t for bunch 13 (Nfi = 304024 , Nff = 321026 ) ...
# Loading frames ...
# Done! (elapsed time = 0.21 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.72e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.11 GB
# Masking data ...
# Done! (elapsed time = 0.74 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.24 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.87 s)
#
# Done!
#
# Computing G2t for bunch 14 (Nfi = 321026 , Nff = 338028 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.4 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 15 (Nfi = 338028 , Nff = 355030 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.53 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.19 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.06 s)
#
# Done!
#
# Computing G2t for bunch 16 (Nfi = 355030 , Nff = 372032 ) ...
# Loading frames ...
# Done! (elapsed time = 0.23 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.98 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.38 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.46 s)
#
# Done!
#
# Computing G2t for bunch 17 (Nfi = 372032 , Nff = 389034 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.77 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.32 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.96 s)
#
# Done!
#
# Computing G2t for bunch 18 (Nfi = 389034 , Nff = 406036 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.73 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.45 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.37 s)
#
# Done!
#
# Computing G2t for bunch 19 (Nfi = 406036 , Nff = 423038 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.58 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.23 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.91 s)
#
# Done!
#
# Computing G2t for bunch 20 (Nfi = 423038 , Nff = 440040 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.59 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.32 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.27 s)
#
# Done!
#
# Computing G2t for bunch 21 (Nfi = 440040 , Nff = 457042 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.6 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.33 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.94 s)
#
# Done!
#
# Computing G2t for bunch 22 (Nfi = 457042 , Nff = 474044 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.53 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.27 s)
#
# Done!
#
# Computing G2t for bunch 23 (Nfi = 474044 , Nff = 491046 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.56 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.19 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.95 s)
#
# Done!
#
# Computing G2t for bunch 24 (Nfi = 491046 , Nff = 508048 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.91 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.44 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.28 s)
#
# Done!
#
# Computing G2t for bunch 25 (Nfi = 508048 , Nff = 525050 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.79 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.35 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.97 s)
#
# Done!
#
# Computing G2t for bunch 26 (Nfi = 525050 , Nff = 542052 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.55 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.4 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.31 s)
#
# Done!
#
# Computing G2t for bunch 27 (Nfi = 542052 , Nff = 559054 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.45 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.08 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.88 s)
#
# Done!
#
# Computing G2t for bunch 28 (Nfi = 559054 , Nff = 576056 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.46 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.27 s)
#
# Done!
#
# Computing G2t for bunch 29 (Nfi = 576056 , Nff = 593058 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.45 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.1 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.02 s)
#
# Done!
#
# Computing G2t for bunch 30 (Nfi = 593058 , Nff = 610060 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.92 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.44 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.47 s)
#
# Done!
#
# Computing G2t for bunch 31 (Nfi = 610060 , Nff = 627062 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.7 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.22 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.01 s)
#
# Done!
#
# Computing G2t for bunch 32 (Nfi = 627062 , Nff = 644064 ) ...
# Loading frames ...
# Done! (elapsed time = 0.2 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.69 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.29 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.37 s)
#
# Done!
#
# Computing G2t for bunch 33 (Nfi = 644064 , Nff = 661066 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.13 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.1 s)
#
# Done!
#
# Computing G2t for bunch 34 (Nfi = 661066 , Nff = 678068 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.62 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.31 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.41 s)
#
# Done!
#
# Computing G2t for bunch 35 (Nfi = 678068 , Nff = 695070 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.16 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.85 s)
#
# Done!
#
# Computing G2t for bunch 36 (Nfi = 695070 , Nff = 712072 ) ...
# Loading frames ...
# Done! (elapsed time = 0.2 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.76 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.33 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.33 s)
#
# Done!
#
# Computing G2t for bunch 37 (Nfi = 712072 , Nff = 729074 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.54 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.13 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.89 s)
#
# Done!
#
# Computing G2t for bunch 38 (Nfi = 729074 , Nff = 746076 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.4 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.31 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 39 (Nfi = 746076 , Nff = 763078 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.18 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.92 s)
#
# Done!
#
# Computing G2t for bunch 40 (Nfi = 763078 , Nff = 780080 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.46 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.26 s)
#
# Done!
#
# Computing G2t for bunch 41 (Nfi = 780080 , Nff = 797082 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.47 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.09 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.0 s)
#
# Done!
#
# Computing G2t for bunch 42 (Nfi = 797082 , Nff = 814084 ) ...
# Loading frames ...
# Done! (elapsed time = 0.2 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.66 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.29 s)
#
# Done!
#
# Computing G2t for bunch 43 (Nfi = 814084 , Nff = 831086 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.51 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.25 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.11 s)
#
# Done!
#
# Computing G2t for bunch 44 (Nfi = 831086 , Nff = 848088 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.43 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.26 s)
#
# Done!
#
# Computing G2t for bunch 45 (Nfi = 848088 , Nff = 865090 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.47 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.18 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.94 s)
#
# Done!
#
# Computing G2t for bunch 46 (Nfi = 865090 , Nff = 882092 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.27 s)
#
# Done!
#
# Computing G2t for bunch 47 (Nfi = 882092 , Nff = 899094 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.15 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.92 s)
#
# Done!
#
# Computing G2t for bunch 48 (Nfi = 899094 , Nff = 916096 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.42 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.28 s)
#
# Done!
#
# Computing G2t for bunch 49 (Nfi = 916096 , Nff = 933098 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.65 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.33 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.01 s)
#
# Done!
#
# Computing G2t for bunch 50 (Nfi = 933098 , Nff = 950100 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.43 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 51 (Nfi = 950100 , Nff = 967102 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.13 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.05 s)
#
# Done!
#
# Computing G2t for bunch 52 (Nfi = 967102 , Nff = 984104 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.68 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.35 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.45 s)
#
# Done!
#
# Computing G2t for bunch 53 (Nfi = 984104 , Nff = 1001106 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.59 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.14 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.14 s)
#
# Done!
#
# Computing G2t for bunch 54 (Nfi = 1001106 , Nff = 1018108 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.29 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.26 s)
#
# Done!
#
# Computing G2t for bunch 55 (Nfi = 1018108 , Nff = 1035110 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.53 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.36 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.95 s)
#
# Done!
#
# Computing G2t for bunch 56 (Nfi = 1035110 , Nff = 1052112 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.33 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.47 s)
#
# Done!
#
# Computing G2t for bunch 57 (Nfi = 1052112 , Nff = 1069114 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.65 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.2 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.15 s)
#
# Done!
#
# Computing G2t for bunch 58 (Nfi = 1069114 , Nff = 1086116 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.38 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.26 s)
#
# Done!
#
# Computing G2t for bunch 59 (Nfi = 1086116 , Nff = 1103118 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.26 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.85 s)
#
# Done!
#
# Computing G2t for bunch 60 (Nfi = 1103118 , Nff = 1120120 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.26 s)
#
# Done!
#
# Computing G2t for bunch 61 (Nfi = 1120120 , Nff = 1137122 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.47 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.2 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.89 s)
#
# Done!
#
# Computing G2t for bunch 62 (Nfi = 1137122 , Nff = 1154124 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.41 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.27 s)
#
# Done!
#
# Computing G2t for bunch 63 (Nfi = 1154124 , Nff = 1171126 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.2 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.15 s)
#
# Done!
#
# Computing G2t for bunch 64 (Nfi = 1171126 , Nff = 1188128 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.44 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.26 s)
#
# Done!
#
# Computing G2t for bunch 65 (Nfi = 1188128 , Nff = 1205130 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.18 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.02 s)
#
# Done!
#
# Computing G2t for bunch 66 (Nfi = 1205130 , Nff = 1222132 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.29 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.26 s)
#
# Done!
#
# Computing G2t for bunch 67 (Nfi = 1222132 , Nff = 1239134 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.21 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.97 s)
#
# Done!
#
# Computing G2t for bunch 68 (Nfi = 1239134 , Nff = 1256136 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.38 s)
#
# Done!
#
# Computing G2t for bunch 69 (Nfi = 1256136 , Nff = 1273138 ) ...
# Loading frames ...
# Done! (elapsed time = 0.2 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.99 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.5 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.02 s)
#
# Done!
#
# Computing G2t for bunch 70 (Nfi = 1273138 , Nff = 1290140 ) ...
# Loading frames ...
# Done! (elapsed time = 0.24 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 1.03 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.46 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.39 s)
#
# Done!
#
# Computing G2t for bunch 71 (Nfi = 1290140 , Nff = 1307142 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.28 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.98 s)
#
# Done!
#
# Computing G2t for bunch 72 (Nfi = 1307142 , Nff = 1324144 ) ...
# Loading frames ...
# Done! (elapsed time = 0.23 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.9 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.39 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.33 s)
#
# Done!
#
# Computing G2t for bunch 73 (Nfi = 1324144 , Nff = 1341146 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.58 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.25 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.02 s)
#
# Done!
#
# Computing G2t for bunch 74 (Nfi = 1341146 , Nff = 1358148 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.78 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.41 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.4 s)
#
# Done!
#
# Computing G2t for bunch 75 (Nfi = 1358148 , Nff = 1375150 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.6 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.2 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.03 s)
#
# Done!
#
# Computing G2t for bunch 76 (Nfi = 1375150 , Nff = 1392152 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.95 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.4 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.38 s)
#
# Done!
#
# Computing G2t for bunch 77 (Nfi = 1392152 , Nff = 1409154 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.6 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.22 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.92 s)
#
# Done!
#
# Computing G2t for bunch 78 (Nfi = 1409154 , Nff = 1426156 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.36 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.45 s)
#
# Done!
#
# Computing G2t for bunch 79 (Nfi = 1426156 , Nff = 1443158 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.68 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.17 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.98 s)
#
# Done!
#
# Computing G2t for bunch 80 (Nfi = 1443158 , Nff = 1460160 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.37 s)
#
# Done!
#
# Computing G2t for bunch 81 (Nfi = 1460160 , Nff = 1477162 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.53 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.14 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.91 s)
#
# Done!
#
# Computing G2t for bunch 82 (Nfi = 1477162 , Nff = 1494164 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 83 (Nfi = 1494164 , Nff = 1511166 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.22 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.95 s)
#
# Done!
#
# Computing G2t for bunch 84 (Nfi = 1511166 , Nff = 1528168 ) ...
# Loading frames ...
# Done! (elapsed time = 0.2 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.28 s)
#
# Done!
#
# Computing G2t for bunch 85 (Nfi = 1528168 , Nff = 1545170 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.46 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.17 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.05 s)
#
# Done!
#
# Computing G2t for bunch 86 (Nfi = 1545170 , Nff = 1562172 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.36 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.45 s)
#
# Done!
#
# Computing G2t for bunch 87 (Nfi = 1562172 , Nff = 1579174 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.82 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.28 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.98 s)
#
# Done!
#
# Computing G2t for bunch 88 (Nfi = 1579174 , Nff = 1596176 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.8 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.45 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.28 s)
#
# Done!
#
# Computing G2t for bunch 89 (Nfi = 1596176 , Nff = 1613178 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.74 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.34 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.94 s)
#
# Done!
#
# Computing G2t for bunch 90 (Nfi = 1613178 , Nff = 1630180 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.65 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.38 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.29 s)
#
# Done!
#
# Computing G2t for bunch 91 (Nfi = 1630180 , Nff = 1647182 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.71 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.23 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.96 s)
#
# Done!
#
# Computing G2t for bunch 92 (Nfi = 1647182 , Nff = 1664184 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.66 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.33 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.45 s)
#
# Done!
#
# Computing G2t for bunch 93 (Nfi = 1664184 , Nff = 1681186 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.66 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.21 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.93 s)
#
# Done!
#
# Computing G2t for bunch 94 (Nfi = 1681186 , Nff = 1698188 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.33 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 95 (Nfi = 1698188 , Nff = 1715190 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.33 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.93 s)
#
# Done!
#
# Computing G2t for bunch 96 (Nfi = 1715190 , Nff = 1732192 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.67 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.34 s)
#
# Done!
#
# Computing G2t for bunch 97 (Nfi = 1732192 , Nff = 1749194 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.15 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.01 s)
#
# Done!
#
# Computing G2t for bunch 98 (Nfi = 1749194 , Nff = 1766196 ) ...
# Loading frames ...
# Done! (elapsed time = 0.23 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.63 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.26 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.37 s)
#
# Done!
#
# Computing G2t for bunch 99 (Nfi = 1766196 , Nff = 1783198 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.53 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.15 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.0 s)
#
# Done!
#
# Computing G2t for bunch 100 (Nfi = 1783198 , Nff = 1800200 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.46 s)
# 	 | 17002 frames X 1461854 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.038 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.26 s)
#
# Done!

# %%
############################
t1, t2 = 0, 10
vmin, vmax = 1.0, 1.06
############################
XPCS.plot_G2t(G2t, vmin, vmax, itime=itime, t1=t1, t2=t2, sigma_filter=3)

# %% [markdown]
# ### g2(t)

# %%
################
Nbunch = 1
################

NfXbunch = int(G2t.shape[0]/Nbunch)
t, g2, t_mt, g2_mt = {}, {}, {}, {}
for n in range(Nbunch):
    t_bunch = round(itime*Lbin*NfXbunch*(n+1/2),1)

    t[t_bunch], g2[t_bunch] = XPCS.get_g2(itime*Lbin, np.array(G2t[NfXbunch*n:NfXbunch*(n+1), NfXbunch*n:NfXbunch*(n+1)]), cython=False)
    t_mt[t_bunch], g2_mt[t_bunch] = XPCS.get_g2_mt(itime*Lbin, g2[t_bunch])
# Out:
# Computing g2...
# Done! (elapsed time = 0.28 s)

# %%
##################
t1_fit = 0
t2_fit = 1e8
##################
 
plt.figure(figsize=(10,5))
fit_out = pd.DataFrame(columns=['tau', 'beta', 'c', 'y0', 'dtau', 'dbeta', 'dc', 'dy0'])
fit_out.index.name = 't'
for k in g2.keys():
    #plt.scatter(t[k], g2[k], s=1, label = str(k)+'s')
    plt.scatter(t_mt[k], g2_mt[k], label=str(k)+'s')

    popt, pcov = curve_fit(decorelation_f, t[k][(t1_fit<t[k])*(t[k]<t2_fit)], g2[k][(t1_fit<t[k])*(t[k]<t2_fit)], p0=[3, .7, .02, 1], bounds=([0, 0, 0, 0], [np.inf, np.inf, np.inf, np.inf]))
    fit_out.loc[k] = [popt[0], popt[1], popt[2], popt[3], np.sqrt(pcov[0,0]), np.sqrt(pcov[1,1]), np.sqrt(pcov[2,2]), np.sqrt(pcov[3,3])]
    
    x = np.arange(np.min(t[k]), np.max(t[k]), 1e-2)
    y = decorelation_f(x, *popt)
    plt.plot(x, y,)

fit_out.to_csv(fit_outs_folder+'fit_out_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4)+'.csv')

plt.xlabel('t [s]')
plt.ylabel('g2')
plt.xscale('log')
plt.legend()
plt.show()

if Nbunch == 1:
    print(f'tau = {popt[0]} +/- {np.sqrt(pcov[0,0])}')
    print(f'beta = {popt[1]} +/- {np.sqrt(pcov[1,1])}')
    print(f'c = {popt[2]} +/- {np.sqrt(pcov[2,2])}')
    print(f'y0 = {popt[3]} +/- {np.sqrt(pcov[3,3])}')
else:
    plt.figure(figsize=(10,5))
    plt.title('tau')
    plt.errorbar(fit_out.index, fit_out.tau,  yerr=fit_out.dtau, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('tau [s]')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('beta')
    plt.errorbar(fit_out.index, fit_out.beta,  yerr=fit_out.dbeta, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('beta')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('c')
    plt.errorbar(fit_out.index, fit_out.c,  yerr=fit_out.dc, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('c')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('y0')
    plt.errorbar(fit_out.index, fit_out.y0,  yerr=fit_out.dy0, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('y0')
    plt.show()
# Out:
# tau = 0.32165541720269253 +/- 0.07017522359662673
# beta = 0.6891727572614254 +/- 0.09711502190975027
# c = 0.023033930025721263 +/- 0.0027398033991368337
# y0 = 1.002671829658822 +/- 9.057884837924134e-05

# %% [markdown]
# ## XPCS mesh (T = 730C Q =  0.29 Å, 30 min @ 1ms (1_800_000 fm)) (GeO2_3, dataset 1, scan 5)

# %%
#######################################
sample_name = 'GeO2_3_730C_Q'
Ndataset = 1
Nscan = 5
Nfi, Nff =  None, None
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
#e4m_data = ID10.load_dense_e4m_new(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )

e4m_data = COSMIC.fast_gamma_filter(e4m_data, Imaxth_high=5)
# Out:
# #############################
# command = mtimescan 0.001 1 1800288
# Ei = 9.699998837562536
# itime = 0.0011
# theta = 3.0000000000000004
# Q = 0.26
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00001.h5 (2/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00002.h5 (3/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00003.h5 (4/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00004.h5 (5/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00005.h5 (6/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00006.h5 (7/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00007.h5 (8/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00008.h5 (9/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00009.h5 (10/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00010.h5 (11/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00011.h5 (12/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00012.h5 (13/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00013.h5 (14/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00014.h5 (15/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00015.h5 (16/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00016.h5 (17/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00017.h5 (18/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00018.h5 (19/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00019.h5 (20/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00020.h5 (21/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00021.h5 (22/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00022.h5 (23/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00023.h5 (24/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00024.h5 (25/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00025.h5 (26/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00026.h5 (27/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00027.h5 (28/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00028.h5 (29/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00029.h5 (30/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00030.h5 (31/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00031.h5 (32/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00032.h5 (33/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00033.h5 (34/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00034.h5 (35/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00035.h5 (36/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00036.h5 (37/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00037.h5 (38/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00038.h5 (39/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00039.h5 (40/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00040.h5 (41/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00041.h5 (42/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00042.h5 (43/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00043.h5 (44/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00044.h5 (45/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00045.h5 (46/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00046.h5 (47/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00047.h5 (48/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00048.h5 (49/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00049.h5 (50/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00050.h5 (51/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00051.h5 (52/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00052.h5 (53/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00053.h5 (54/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00054.h5 (55/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00055.h5 (56/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00056.h5 (57/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00057.h5 (58/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00058.h5 (59/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00059.h5 (60/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00060.h5 (61/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00061.h5 (62/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00062.h5 (63/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00063.h5 (64/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00064.h5 (65/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00065.h5 (66/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00066.h5 (67/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00067.h5 (68/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00068.h5 (69/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00069.h5 (70/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00070.h5 (71/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00071.h5 (72/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00072.h5 (73/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00073.h5 (74/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00074.h5 (75/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00075.h5 (76/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00076.h5 (77/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00077.h5 (78/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00078.h5 (79/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00079.h5 (80/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00080.h5 (81/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00081.h5 (82/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00082.h5 (83/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00083.h5 (84/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00084.h5 (85/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00085.h5 (86/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00086.h5 (87/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00087.h5 (88/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00088.h5 (89/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00089.h5 (90/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00090.h5 (91/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00091.h5 (92/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00092.h5 (93/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00093.h5 (94/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00094.h5 (95/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00095.h5 (96/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00096.h5 (97/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00097.h5 (98/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00098.h5 (99/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00099.h5 (100/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00100.h5 (101/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00101.h5 (102/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00102.h5 (103/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00103.h5 (104/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00104.h5 (105/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00105.h5 (106/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00106.h5 (107/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00107.h5 (108/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00108.h5 (109/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00109.h5 (110/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00110.h5 (111/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00111.h5 (112/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00112.h5 (113/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00113.h5 (114/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00114.h5 (115/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00115.h5 (116/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00116.h5 (117/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00117.h5 (118/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00118.h5 (119/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00119.h5 (120/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00120.h5 (121/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00121.h5 (122/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00122.h5 (123/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00123.h5 (124/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00124.h5 (125/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00125.h5 (126/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00126.h5 (127/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00127.h5 (128/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00128.h5 (129/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00129.h5 (130/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00130.h5 (131/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00131.h5 (132/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00132.h5 (133/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00133.h5 (134/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00134.h5 (135/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00135.h5 (136/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00136.h5 (137/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00137.h5 (138/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00138.h5 (139/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00139.h5 (140/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00140.h5 (141/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00141.h5 (142/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00142.h5 (143/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00143.h5 (144/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00144.h5 (145/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00145.h5 (146/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00146.h5 (147/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00147.h5 (148/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00148.h5 (149/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00149.h5 (150/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00150.h5 (151/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00151.h5 (152/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00152.h5 (153/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00153.h5 (154/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00154.h5 (155/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00155.h5 (156/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00156.h5 (157/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00157.h5 (158/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00158.h5 (159/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00159.h5 (160/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00160.h5 (161/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00161.h5 (162/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00162.h5 (163/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00163.h5 (164/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00164.h5 (165/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00165.h5 (166/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00166.h5 (167/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00167.h5 (168/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00168.h5 (169/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00169.h5 (170/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00170.h5 (171/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00171.h5 (172/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00172.h5 (173/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00173.h5 (174/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00174.h5 (175/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00175.h5 (176/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00176.h5 (177/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00177.h5 (178/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00178.h5 (179/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00179.h5 (180/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00180.h5 (181/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00181.h5 (182/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00182.h5 (183/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00183.h5 (184/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00184.h5 (185/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00185.h5 (186/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00186.h5 (187/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00187.h5 (188/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00188.h5 (189/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00189.h5 (190/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00190.h5 (191/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00191.h5 (192/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00192.h5 (193/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00193.h5 (194/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00194.h5 (195/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00195.h5 (196/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00196.h5 (197/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00197.h5 (198/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00198.h5 (199/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00199.h5 (200/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00200.h5 (201/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00201.h5 (202/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00202.h5 (203/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00203.h5 (204/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00204.h5 (205/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00205.h5 (206/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00206.h5 (207/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00207.h5 (208/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00208.h5 (209/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00209.h5 (210/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00210.h5 (211/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00211.h5 (212/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00212.h5 (213/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00213.h5 (214/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00214.h5 (215/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00215.h5 (216/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00216.h5 (217/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00217.h5 (218/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00218.h5 (219/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00219.h5 (220/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00220.h5 (221/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00221.h5 (222/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00222.h5 (223/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00223.h5 (224/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00224.h5 (225/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00225.h5 (226/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00226.h5 (227/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00227.h5 (228/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00228.h5 (229/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00229.h5 (230/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00230.h5 (231/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00231.h5 (232/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00232.h5 (233/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00233.h5 (234/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00234.h5 (235/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00235.h5 (236/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00236.h5 (237/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00237.h5 (238/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00238.h5 (239/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00239.h5 (240/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00240.h5 (241/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00241.h5 (242/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00242.h5 (243/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00243.h5 (244/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00244.h5 (245/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00245.h5 (246/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00246.h5 (247/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00247.h5 (248/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00248.h5 (249/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00249.h5 (250/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00250.h5 (251/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00251.h5 (252/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00252.h5 (253/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00253.h5 (254/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00254.h5 (255/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00255.h5 (256/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00256.h5 (257/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00257.h5 (258/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00258.h5 (259/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00259.h5 (260/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00260.h5 (261/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00261.h5 (262/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00262.h5 (263/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00263.h5 (264/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00264.h5 (265/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00265.h5 (266/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00266.h5 (267/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00267.h5 (268/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00268.h5 (269/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00269.h5 (270/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00270.h5 (271/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00271.h5 (272/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00272.h5 (273/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00273.h5 (274/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00274.h5 (275/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00275.h5 (276/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00276.h5 (277/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00277.h5 (278/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00278.h5 (279/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00279.h5 (280/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00280.h5 (281/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00281.h5 (282/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00282.h5 (283/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00283.h5 (284/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00284.h5 (285/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00285.h5 (286/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00286.h5 (287/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00287.h5 (288/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00288.h5 (289/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00289.h5 (290/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00290.h5 (291/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00291.h5 (292/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00292.h5 (293/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00293.h5 (294/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00294.h5 (295/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00295.h5 (296/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00296.h5 (297/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00297.h5 (298/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00298.h5 (299/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00299.h5 (300/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00300.h5 (301/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00301.h5 (302/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00302.h5 (303/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00303.h5 (304/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00304.h5 (305/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00305.h5 (306/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00306.h5 (307/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00307.h5 (308/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00308.h5 (309/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00309.h5 (310/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00310.h5 (311/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00311.h5 (312/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00312.h5 (313/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00313.h5 (314/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00314.h5 (315/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00315.h5 (316/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00316.h5 (317/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00317.h5 (318/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00318.h5 (319/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00319.h5 (320/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00320.h5 (321/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00321.h5 (322/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00322.h5 (323/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00323.h5 (324/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00324.h5 (325/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00325.h5 (326/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00326.h5 (327/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00327.h5 (328/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00328.h5 (329/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00329.h5 (330/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00330.h5 (331/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00331.h5 (332/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00332.h5 (333/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00333.h5 (334/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00334.h5 (335/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00335.h5 (336/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00336.h5 (337/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00337.h5 (338/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00338.h5 (339/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00339.h5 (340/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00340.h5 (341/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00341.h5 (342/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00342.h5 (343/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00343.h5 (344/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00344.h5 (345/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00345.h5 (346/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00346.h5 (347/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00347.h5 (348/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00348.h5 (349/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00349.h5 (350/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00350.h5 (351/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00351.h5 (352/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00352.h5 (353/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00353.h5 (354/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00354.h5 (355/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00355.h5 (356/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00356.h5 (357/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00357.h5 (358/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00358.h5 (359/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00359.h5 (360/361 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00360.h5 (361/361 loops)
# Done!
# Concatenating vectors ...
# Done!
# 	 | Sparse array loaded from ../RAW_DATA/GeO2_3_730C_Q/GeO2_3_730C_Q_0001/scan0005/
# 	 | Shape:       (1800288, 4471016)
# 	 | Sparsity:     1.7e-04
# 	 | Memory usage (scipy.csr_array): 11.318 GB (np.array usage: 29985.295 GB)
# Filtering gamma ray signal (i.e. signals over treshold) ...
# Done! (elapsed time = 4.65 s)
# Removing gamma ray signal (set 0s) ...
# Done! (elapsed time = 5.84 s)

# %% [markdown]
# ### Qmask

# %%
###################
Q    = .29
Qres = .02
###################

Qmask = XPCS.gen_Qmask(Ei, theta, Q, Qres, Qmap_plot=True)

# %% [markdown]
# ### Flux check

# %%
#############################################
mask = e4m_mask * e4m_htmask * bs_mask
#############################################

XPCS.gen_plots4mask(e4m_data, itime, Ith_high= .4, Nff=100_000, e4m_mask=mask)
# Out:
# ################################################################################
# Maximum count in the hull run -> 5
# # of pixels above Ith_high treshold ->  14 pixels (of 4471016 => 0.0 %)
# ################################################################################

# %% [markdown]
# ### Intensity analysis

# %%
####################
Lbin = 1
Nstep = 100
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
####################

t_It, It = XPCS.get_It(e4m_data, itime, mask=mask, Lbin=Lbin, Nstep=Nstep)
np.savez(Idts_folder+'Idt_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4), t_It=t_It, It=It)

# %%
plt.figure(figsize=(10,5))
plt.scatter(t_It, It, label='It')

plt.xlabel('Time (s)')
plt.ylabel('Integrated intensity [photons/pixel/s]')
plt.xscale('log')
#plt.xlim(1e-2, 1)
plt.gca().secondary_xaxis('top', functions=(lambda x: x/itime, lambda x: x*itime))
plt.grid()

# %% [markdown]
# ### Correlation

# %%
###################
Nfi = 100_000
Nff = None
Lbin = 1
Nbunch = 100
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
###################
if Lbin is None: Lbin=1

G2t = XPCS.get_G2t_bybunch(e4m_data, mask=mask, Nfi=Nfi, Nff=Nff, Lbin=Lbin, Nbunch=Nbunch)
# Out:
# Computing G2t for bunch 1 (Nfi = 100000 , Nff = 117002 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.45 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.12 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.92 s)
#
# Done!
#
# Computing G2t for bunch 2 (Nfi = 117002 , Nff = 134004 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.4 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 3 (Nfi = 134004 , Nff = 151006 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.47 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.1 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.9 s)
#
# Done!
#
# Computing G2t for bunch 4 (Nfi = 151006 , Nff = 168008 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.42 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.38 s)
#
# Done!
#
# Computing G2t for bunch 5 (Nfi = 168008 , Nff = 185010 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.69 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.22 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.94 s)
#
# Done!
#
# Computing G2t for bunch 6 (Nfi = 185010 , Nff = 202012 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.72 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.45 s)
#
# Done!
#
# Computing G2t for bunch 7 (Nfi = 202012 , Nff = 219014 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.63 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.27 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.93 s)
#
# Done!
#
# Computing G2t for bunch 8 (Nfi = 219014 , Nff = 236016 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.41 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.32 s)
#
# Done!
#
# Computing G2t for bunch 9 (Nfi = 236016 , Nff = 253018 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.6 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.26 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.01 s)
#
# Done!
#
# Computing G2t for bunch 10 (Nfi = 253018 , Nff = 270020 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.107 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.29 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.36 s)
#
# Done!
#
# Computing G2t for bunch 11 (Nfi = 270020 , Nff = 287022 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.68e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.107 GB
# Masking data ...
# Done! (elapsed time = 0.41 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.24 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.94 s)
#
# Done!
#
# Computing G2t for bunch 12 (Nfi = 287022 , Nff = 304024 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.68e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.107 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.46 s)
#
# Done!
#
# Computing G2t for bunch 13 (Nfi = 304024 , Nff = 321026 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.68e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.107 GB
# Masking data ...
# Done! (elapsed time = 0.59 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.11 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.92 s)
#
# Done!
#
# Computing G2t for bunch 14 (Nfi = 321026 , Nff = 338028 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.68e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.107 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 15 (Nfi = 338028 , Nff = 355030 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.68e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.107 GB
# Masking data ...
# Done! (elapsed time = 0.36 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.08 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.05 s)
#
# Done!
#
# Computing G2t for bunch 16 (Nfi = 355030 , Nff = 372032 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.68e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.107 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.36 s)
#
# Done!
#
# Computing G2t for bunch 17 (Nfi = 372032 , Nff = 389034 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.107 GB
# Masking data ...
# Done! (elapsed time = 0.59 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.13 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.98 s)
#
# Done!
#
# Computing G2t for bunch 18 (Nfi = 389034 , Nff = 406036 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.107 GB
# Masking data ...
# Done! (elapsed time = 0.36 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 19 (Nfi = 406036 , Nff = 423038 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.107 GB
# Masking data ...
# Done! (elapsed time = 0.36 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.08 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.93 s)
#
# Done!
#
# Computing G2t for bunch 20 (Nfi = 423038 , Nff = 440040 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.107 GB
# Masking data ...
# Done! (elapsed time = 0.36 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.26 s)
#
# Done!
#
# Computing G2t for bunch 21 (Nfi = 440040 , Nff = 457042 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.106 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.22 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.01 s)
#
# Done!
#
# Computing G2t for bunch 22 (Nfi = 457042 , Nff = 474044 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.106 GB
# Masking data ...
# Done! (elapsed time = 0.38 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.39 s)
#
# Done!
#
# Computing G2t for bunch 23 (Nfi = 474044 , Nff = 491046 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.106 GB
# Masking data ...
# Done! (elapsed time = 0.64 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.19 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.99 s)
#
# Done!
#
# Computing G2t for bunch 24 (Nfi = 491046 , Nff = 508048 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.106 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.26 s)
#
# Done!
#
# Computing G2t for bunch 25 (Nfi = 508048 , Nff = 525050 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.106 GB
# Masking data ...
# Done! (elapsed time = 0.42 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.07 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.96 s)
#
# Done!
#
# Computing G2t for bunch 26 (Nfi = 525050 , Nff = 542052 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.106 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.34 s)
#
# Done!
#
# Computing G2t for bunch 27 (Nfi = 542052 , Nff = 559054 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.106 GB
# Masking data ...
# Done! (elapsed time = 0.35 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.21 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.19 s)
#
# Done!
#
# Computing G2t for bunch 28 (Nfi = 559054 , Nff = 576056 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.106 GB
# Masking data ...
# Done! (elapsed time = 0.36 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 29 (Nfi = 576056 , Nff = 593058 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.106 GB
# Masking data ...
# Done! (elapsed time = 0.35 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.14 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.96 s)
#
# Done!
#
# Computing G2t for bunch 30 (Nfi = 593058 , Nff = 610060 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.106 GB
# Masking data ...
# Done! (elapsed time = 0.51 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.31 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.39 s)
#
# Done!
#
# Computing G2t for bunch 31 (Nfi = 610060 , Nff = 627062 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.106 GB
# Masking data ...
# Done! (elapsed time = 0.46 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.06 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.92 s)
#
# Done!
#
# Computing G2t for bunch 32 (Nfi = 627062 , Nff = 644064 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.106 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 33 (Nfi = 644064 , Nff = 661066 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.106 GB
# Masking data ...
# Done! (elapsed time = 0.36 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.07 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.0 s)
#
# Done!
#
# Computing G2t for bunch 34 (Nfi = 661066 , Nff = 678068 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.36 s)
#
# Done!
#
# Computing G2t for bunch 35 (Nfi = 678068 , Nff = 695070 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.86 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.27 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.94 s)
#
# Done!
#
# Computing G2t for bunch 36 (Nfi = 695070 , Nff = 712072 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.65 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.36 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.27 s)
#
# Done!
#
# Computing G2t for bunch 37 (Nfi = 712072 , Nff = 729074 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.88 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.36 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.95 s)
#
# Done!
#
# Computing G2t for bunch 38 (Nfi = 729074 , Nff = 746076 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.71 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.33 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.28 s)
#
# Done!
#
# Computing G2t for bunch 39 (Nfi = 746076 , Nff = 763078 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.53 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.17 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.99 s)
#
# Done!
#
# Computing G2t for bunch 40 (Nfi = 763078 , Nff = 780080 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.27 s)
#
# Done!
#
# Computing G2t for bunch 41 (Nfi = 780080 , Nff = 797082 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.53 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.18 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.93 s)
#
# Done!
#
# Computing G2t for bunch 42 (Nfi = 797082 , Nff = 814084 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.55 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.28 s)
#
# Done!
#
# Computing G2t for bunch 43 (Nfi = 814084 , Nff = 831086 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.52 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.09 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.05 s)
#
# Done!
#
# Computing G2t for bunch 44 (Nfi = 831086 , Nff = 848088 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.53 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.28 s)
#
# Done!
#
# Computing G2t for bunch 45 (Nfi = 848088 , Nff = 865090 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.33 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.13 s)
#
# Done!
#
# Computing G2t for bunch 46 (Nfi = 865090 , Nff = 882092 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.29 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.35 s)
#
# Done!
#
# Computing G2t for bunch 47 (Nfi = 882092 , Nff = 899094 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.38 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.15 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.0 s)
#
# Done!
#
# Computing G2t for bunch 48 (Nfi = 899094 , Nff = 916096 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.26 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.37 s)
#
# Done!
#
# Computing G2t for bunch 49 (Nfi = 916096 , Nff = 933098 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.4 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.14 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.01 s)
#
# Done!
#
# Computing G2t for bunch 50 (Nfi = 933098 , Nff = 950100 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.26 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.37 s)
#
# Done!
#
# Computing G2t for bunch 51 (Nfi = 950100 , Nff = 967102 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.4 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.12 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.13 s)
#
# Done!
#
# Computing G2t for bunch 52 (Nfi = 967102 , Nff = 984104 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.31 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.41 s)
#
# Done!
#
# Computing G2t for bunch 53 (Nfi = 984104 , Nff = 1001106 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.38 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.1 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.95 s)
#
# Done!
#
# Computing G2t for bunch 54 (Nfi = 1001106 , Nff = 1018108 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.47 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.32 s)
#
# Done!
#
# Computing G2t for bunch 55 (Nfi = 1018108 , Nff = 1035110 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.17 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.92 s)
#
# Done!
#
# Computing G2t for bunch 56 (Nfi = 1035110 , Nff = 1052112 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.77 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.39 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.33 s)
#
# Done!
#
# Computing G2t for bunch 57 (Nfi = 1052112 , Nff = 1069114 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.19 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.97 s)
#
# Done!
#
# Computing G2t for bunch 58 (Nfi = 1069114 , Nff = 1086116 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.35 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.3 s)
#
# Done!
#
# Computing G2t for bunch 59 (Nfi = 1086116 , Nff = 1103118 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.36 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.12 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.0 s)
#
# Done!
#
# Computing G2t for bunch 60 (Nfi = 1103118 , Nff = 1120120 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.52 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.34 s)
#
# Done!
#
# Computing G2t for bunch 61 (Nfi = 1120120 , Nff = 1137122 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.105 GB
# Masking data ...
# Done! (elapsed time = 0.42 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.18 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.02 s)
#
# Done!
#
# Computing G2t for bunch 62 (Nfi = 1137122 , Nff = 1154124 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.104 GB
# Masking data ...
# Done! (elapsed time = 0.59 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.44 s)
#
# Done!
#
# Computing G2t for bunch 63 (Nfi = 1154124 , Nff = 1171126 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.104 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.04 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.98 s)
#
# Done!
#
# Computing G2t for bunch 64 (Nfi = 1171126 , Nff = 1188128 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.104 GB
# Masking data ...
# Done! (elapsed time = 0.52 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.39 s)
#
# Done!
#
# Computing G2t for bunch 65 (Nfi = 1188128 , Nff = 1205130 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.104 GB
# Masking data ...
# Done! (elapsed time = 0.4 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.05 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.96 s)
#
# Done!
#
# Computing G2t for bunch 66 (Nfi = 1205130 , Nff = 1222132 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.104 GB
# Masking data ...
# Done! (elapsed time = 0.55 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.29 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.29 s)
#
# Done!
#
# Computing G2t for bunch 67 (Nfi = 1222132 , Nff = 1239134 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.104 GB
# Masking data ...
# Done! (elapsed time = 0.36 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.11 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.02 s)
#
# Done!
#
# Computing G2t for bunch 68 (Nfi = 1239134 , Nff = 1256136 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.104 GB
# Masking data ...
# Done! (elapsed time = 0.64 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.49 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.28 s)
#
# Done!
#
# Computing G2t for bunch 69 (Nfi = 1256136 , Nff = 1273138 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.63e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.104 GB
# Masking data ...
# Done! (elapsed time = 0.71 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.035 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.35 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.92 s)
#
# Done!
#
# Computing G2t for bunch 70 (Nfi = 1273138 , Nff = 1290140 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.63e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.104 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.035 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 71 (Nfi = 1290140 , Nff = 1307142 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.63e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.104 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.035 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.15 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.85 s)
#
# Done!
#
# Computing G2t for bunch 72 (Nfi = 1307142 , Nff = 1324144 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.107 GB
# Masking data ...
# Done! (elapsed time = 0.56 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.036 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.3 s)
#
# Done!
#
# Computing G2t for bunch 73 (Nfi = 1324144 , Nff = 1341146 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.11 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.96 s)
#
# Done!
#
# Computing G2t for bunch 74 (Nfi = 1341146 , Nff = 1358148 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.6 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.26 s)
#
# Done!
#
# Computing G2t for bunch 75 (Nfi = 1358148 , Nff = 1375150 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.45 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.19 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.97 s)
#
# Done!
#
# Computing G2t for bunch 76 (Nfi = 1375150 , Nff = 1392152 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.109 GB
# Masking data ...
# Done! (elapsed time = 0.72 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.34 s)
#
# Done!
#
# Computing G2t for bunch 77 (Nfi = 1392152 , Nff = 1409154 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.12 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.08 s)
#
# Done!
#
# Computing G2t for bunch 78 (Nfi = 1409154 , Nff = 1426156 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.45 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.36 s)
#
# Done!
#
# Computing G2t for bunch 79 (Nfi = 1426156 , Nff = 1443158 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.61 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.08 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.05 s)
#
# Done!
#
# Computing G2t for bunch 80 (Nfi = 1443158 , Nff = 1460160 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.44 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 81 (Nfi = 1460160 , Nff = 1477162 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.44 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.16 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.89 s)
#
# Done!
#
# Computing G2t for bunch 82 (Nfi = 1477162 , Nff = 1494164 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.70e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 83 (Nfi = 1494164 , Nff = 1511166 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.47 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.16 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.07 s)
#
# Done!
#
# Computing G2t for bunch 84 (Nfi = 1511166 , Nff = 1528168 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.67 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.38 s)
#
# Done!
#
# Computing G2t for bunch 85 (Nfi = 1528168 , Nff = 1545170 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.17 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.03 s)
#
# Done!
#
# Computing G2t for bunch 86 (Nfi = 1545170 , Nff = 1562172 ) ...
# Loading frames ...
# Done! (elapsed time = 0.14 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.68 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.32 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.34 s)
#
# Done!
#
# Computing G2t for bunch 87 (Nfi = 1562172 , Nff = 1579174 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.13 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.97 s)
#
# Done!
#
# Computing G2t for bunch 88 (Nfi = 1579174 , Nff = 1596176 ) ...
# Loading frames ...
# Done! (elapsed time = 0.14 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.61 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.3 s)
#
# Done!
#
# Computing G2t for bunch 89 (Nfi = 1596176 , Nff = 1613178 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.34 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.93 s)
#
# Done!
#
# Computing G2t for bunch 90 (Nfi = 1613178 , Nff = 1630180 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.95 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.44 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.4 s)
#
# Done!
#
# Computing G2t for bunch 91 (Nfi = 1630180 , Nff = 1647182 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 1.02 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.29 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.05 s)
#
# Done!
#
# Computing G2t for bunch 92 (Nfi = 1647182 , Nff = 1664184 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.47 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.25 s)
#
# Done!
#
# Computing G2t for bunch 93 (Nfi = 1664184 , Nff = 1681186 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.46 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.2 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.95 s)
#
# Done!
#
# Computing G2t for bunch 94 (Nfi = 1681186 , Nff = 1698188 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.27 s)
#
# Done!
#
# Computing G2t for bunch 95 (Nfi = 1698188 , Nff = 1715190 ) ...
# Loading frames ...
# Done! (elapsed time = 0.08 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.06 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.96 s)
#
# Done!
#
# Computing G2t for bunch 96 (Nfi = 1715190 , Nff = 1732192 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.58 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.31 s)
#
# Done!
#
# Computing G2t for bunch 97 (Nfi = 1732192 , Nff = 1749194 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.17 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.06 s)
#
# Done!
#
# Computing G2t for bunch 98 (Nfi = 1749194 , Nff = 1766196 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.75 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.38 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.41 s)
#
# Done!
#
# Computing G2t for bunch 99 (Nfi = 1766196 , Nff = 1783198 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.55 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.2 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.97 s)
#
# Done!
#
# Computing G2t for bunch 100 (Nfi = 1783198 , Nff = 1800200 ) ...
# Loading frames ...
# Done! (elapsed time = 0.09 s)
# 	 | 17002 frames X 4471016 pixels
# 	 | sparsity = 1.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.108 GB
# Masking data ...
# Done! (elapsed time = 0.55 s)
# 	 | 17002 frames X 1404018 pixels
# 	 | sparsity = 1.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.037 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.29 s)
# 	 | 17002 X 17002 squared matrix
# 	 | memory usage (np.array @ float64) = 2.154 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.28 s)
#
# Done!

# %%
############################
t1, t2 = 0, 10
vmin, vmax = 1.0, 1.06
############################
XPCS.plot_G2t(G2t, vmin, vmax, itime=itime, t1=t1, t2=t2, sigma_filter=3)

# %% [markdown]
# ### g2(t)

# %%
################
Nbunch = 1
################

NfXbunch = int(G2t.shape[0]/Nbunch)
t, g2, t_mt, g2_mt = {}, {}, {}, {}
for n in range(Nbunch):
    t_bunch = round(itime*Lbin*NfXbunch*(n+1/2),1)

    t[t_bunch], g2[t_bunch] = XPCS.get_g2(itime*Lbin, np.array(G2t[NfXbunch*n:NfXbunch*(n+1), NfXbunch*n:NfXbunch*(n+1)]), cython=False)
    t_mt[t_bunch], g2_mt[t_bunch] = XPCS.get_g2_mt(itime*Lbin, g2[t_bunch])
# Out:
# Computing g2...
# Done! (elapsed time = 0.49 s)

# %%
##################
t1_fit = 0
t2_fit = 1e8
##################
 
plt.figure(figsize=(10,5))
fit_out = pd.DataFrame(columns=['tau', 'beta', 'c', 'y0', 'dtau', 'dbeta', 'dc', 'dy0'])
fit_out.index.name = 't'
for k in g2.keys():
    #plt.scatter(t[k], g2[k], s=1, label = str(k)+'s')
    plt.scatter(t_mt[k], g2_mt[k], label=str(k)+'s')

    popt, pcov = curve_fit(decorelation_f, t[k][(t1_fit<t[k])*(t[k]<t2_fit)], g2[k][(t1_fit<t[k])*(t[k]<t2_fit)], p0=[3, .7, .02, 1], bounds=([0, 0, 0, 0], [np.inf, np.inf, np.inf, np.inf]))
    fit_out.loc[k] = [popt[0], popt[1], popt[2], popt[3], np.sqrt(pcov[0,0]), np.sqrt(pcov[1,1]), np.sqrt(pcov[2,2]), np.sqrt(pcov[3,3])]
    
    x = np.arange(np.min(t[k]), np.max(t[k]), 1e-2)
    y = decorelation_f(x, *popt)
    plt.plot(x, y,)

fit_out.to_csv(fit_outs_folder+'fit_out_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4)+'.csv')

plt.xlabel('t [s]')
plt.ylabel('g2')
plt.xscale('log')
plt.legend()
plt.show()

if Nbunch == 1:
    print(f'tau = {popt[0]} +/- {np.sqrt(pcov[0,0])}')
    print(f'beta = {popt[1]} +/- {np.sqrt(pcov[1,1])}')
    print(f'c = {popt[2]} +/- {np.sqrt(pcov[2,2])}')
    print(f'y0 = {popt[3]} +/- {np.sqrt(pcov[3,3])}')
else:
    plt.figure(figsize=(10,5))
    plt.title('tau')
    plt.errorbar(fit_out.index, fit_out.tau,  yerr=fit_out.dtau, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('tau [s]')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('beta')
    plt.errorbar(fit_out.index, fit_out.beta,  yerr=fit_out.dbeta, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('beta')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('c')
    plt.errorbar(fit_out.index, fit_out.c,  yerr=fit_out.dc, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('c')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('y0')
    plt.errorbar(fit_out.index, fit_out.y0,  yerr=fit_out.dy0, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('y0')
    plt.show()
# Out:
# tau = 0.21731895797619163 +/- 0.06871635103882352
# beta = 0.7046293587296015 +/- 0.14689456323252756
# c = 0.021248260404926476 +/- 0.0037041892823897085
# y0 = 1.0025172242425269 +/- 9.779727940322079e-05

# %% [markdown]
# ## XPCS mesh (T = 730C Q =  0.38 Å, 20 min @ 1ms (1_200_000 fm)) (GeO2_3, dataset 1, scan 6)

# %%
#######################################
sample_name = 'GeO2_3_730C_Q'
Ndataset = 1
Nscan = 6
Nfi, Nff =  None, None
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
#e4m_data = ID10.load_dense_e4m_new(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )

e4m_data = COSMIC.fast_gamma_filter(e4m_data, Imaxth_high=5)
# Out:
# #############################
# command = mtimescan 0.001 1 1200192
# Ei = 9.699998837562536
# itime = 0.0011
# theta = 4.0
# Q = 0.34
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00001.h5 (2/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00002.h5 (3/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00003.h5 (4/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00004.h5 (5/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00005.h5 (6/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00006.h5 (7/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00007.h5 (8/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00008.h5 (9/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00009.h5 (10/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00010.h5 (11/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00011.h5 (12/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00012.h5 (13/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00013.h5 (14/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00014.h5 (15/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00015.h5 (16/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00016.h5 (17/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00017.h5 (18/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00018.h5 (19/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00019.h5 (20/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00020.h5 (21/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00021.h5 (22/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00022.h5 (23/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00023.h5 (24/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00024.h5 (25/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00025.h5 (26/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00026.h5 (27/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00027.h5 (28/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00028.h5 (29/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00029.h5 (30/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00030.h5 (31/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00031.h5 (32/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00032.h5 (33/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00033.h5 (34/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00034.h5 (35/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00035.h5 (36/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00036.h5 (37/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00037.h5 (38/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00038.h5 (39/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00039.h5 (40/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00040.h5 (41/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00041.h5 (42/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00042.h5 (43/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00043.h5 (44/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00044.h5 (45/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00045.h5 (46/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00046.h5 (47/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00047.h5 (48/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00048.h5 (49/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00049.h5 (50/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00050.h5 (51/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00051.h5 (52/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00052.h5 (53/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00053.h5 (54/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00054.h5 (55/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00055.h5 (56/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00056.h5 (57/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00057.h5 (58/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00058.h5 (59/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00059.h5 (60/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00060.h5 (61/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00061.h5 (62/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00062.h5 (63/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00063.h5 (64/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00064.h5 (65/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00065.h5 (66/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00066.h5 (67/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00067.h5 (68/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00068.h5 (69/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00069.h5 (70/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00070.h5 (71/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00071.h5 (72/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00072.h5 (73/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00073.h5 (74/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00074.h5 (75/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00075.h5 (76/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00076.h5 (77/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00077.h5 (78/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00078.h5 (79/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00079.h5 (80/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00080.h5 (81/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00081.h5 (82/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00082.h5 (83/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00083.h5 (84/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00084.h5 (85/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00085.h5 (86/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00086.h5 (87/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00087.h5 (88/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00088.h5 (89/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00089.h5 (90/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00090.h5 (91/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00091.h5 (92/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00092.h5 (93/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00093.h5 (94/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00094.h5 (95/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00095.h5 (96/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00096.h5 (97/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00097.h5 (98/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00098.h5 (99/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00099.h5 (100/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00100.h5 (101/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00101.h5 (102/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00102.h5 (103/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00103.h5 (104/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00104.h5 (105/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00105.h5 (106/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00106.h5 (107/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00107.h5 (108/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00108.h5 (109/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00109.h5 (110/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00110.h5 (111/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00111.h5 (112/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00112.h5 (113/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00113.h5 (114/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00114.h5 (115/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00115.h5 (116/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00116.h5 (117/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00117.h5 (118/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00118.h5 (119/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00119.h5 (120/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00120.h5 (121/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00121.h5 (122/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00122.h5 (123/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00123.h5 (124/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00124.h5 (125/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00125.h5 (126/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00126.h5 (127/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00127.h5 (128/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00128.h5 (129/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00129.h5 (130/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00130.h5 (131/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00131.h5 (132/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00132.h5 (133/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00133.h5 (134/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00134.h5 (135/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00135.h5 (136/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00136.h5 (137/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00137.h5 (138/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00138.h5 (139/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00139.h5 (140/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00140.h5 (141/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00141.h5 (142/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00142.h5 (143/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00143.h5 (144/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00144.h5 (145/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00145.h5 (146/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00146.h5 (147/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00147.h5 (148/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00148.h5 (149/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00149.h5 (150/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00150.h5 (151/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00151.h5 (152/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00152.h5 (153/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00153.h5 (154/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00154.h5 (155/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00155.h5 (156/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00156.h5 (157/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00157.h5 (158/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00158.h5 (159/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00159.h5 (160/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00160.h5 (161/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00161.h5 (162/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00162.h5 (163/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00163.h5 (164/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00164.h5 (165/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00165.h5 (166/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00166.h5 (167/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00167.h5 (168/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00168.h5 (169/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00169.h5 (170/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00170.h5 (171/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00171.h5 (172/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00172.h5 (173/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00173.h5 (174/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00174.h5 (175/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00175.h5 (176/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00176.h5 (177/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00177.h5 (178/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00178.h5 (179/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00179.h5 (180/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00180.h5 (181/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00181.h5 (182/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00182.h5 (183/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00183.h5 (184/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00184.h5 (185/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00185.h5 (186/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00186.h5 (187/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00187.h5 (188/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00188.h5 (189/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00189.h5 (190/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00190.h5 (191/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00191.h5 (192/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00192.h5 (193/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00193.h5 (194/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00194.h5 (195/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00195.h5 (196/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00196.h5 (197/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00197.h5 (198/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00198.h5 (199/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00199.h5 (200/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00200.h5 (201/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00201.h5 (202/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00202.h5 (203/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00203.h5 (204/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00204.h5 (205/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00205.h5 (206/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00206.h5 (207/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00207.h5 (208/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00208.h5 (209/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00209.h5 (210/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00210.h5 (211/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00211.h5 (212/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00212.h5 (213/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00213.h5 (214/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00214.h5 (215/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00215.h5 (216/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00216.h5 (217/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00217.h5 (218/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00218.h5 (219/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00219.h5 (220/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00220.h5 (221/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00221.h5 (222/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00222.h5 (223/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00223.h5 (224/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00224.h5 (225/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00225.h5 (226/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00226.h5 (227/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00227.h5 (228/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00228.h5 (229/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00229.h5 (230/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00230.h5 (231/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00231.h5 (232/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00232.h5 (233/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00233.h5 (234/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00234.h5 (235/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00235.h5 (236/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00236.h5 (237/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00237.h5 (238/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00238.h5 (239/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00239.h5 (240/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00240.h5 (241/241 loops)
# Done!
# Concatenating vectors ...
# Done!
# 	 | Sparse array loaded from ../RAW_DATA/GeO2_3_730C_Q/GeO2_3_730C_Q_0001/scan0006/
# 	 | Shape:       (1200192, 4471016)
# 	 | Sparsity:     3.3e-04
# 	 | Memory usage (scipy.csr_array): 14.728 GB (np.array usage: 19990.197 GB)
# Filtering gamma ray signal (i.e. signals over treshold) ...
# Done! (elapsed time = 5.01 s)
# Removing gamma ray signal (set 0s) ...
# Done! (elapsed time = 7.9 s)

# %% [markdown]
# ### Qmask

# %%
###################
Q    = .38
Qres = .02
###################

Qmask = XPCS.gen_Qmask(Ei, theta, Q, Qres, Qmap_plot=True)

# %% [markdown]
# ### Flux check

# %%
#############################################
mask = e4m_mask * e4m_htmask * bs_mask
#############################################

XPCS.gen_plots4mask(e4m_data, itime, Ith_high= .4, Nff=100_000, e4m_mask=mask)
# Out:
# ################################################################################
# Maximum count in the hull run -> 5
# # of pixels above Ith_high treshold ->  836068 pixels (of 4471016 => 25.14 %)
# ################################################################################

# %% [markdown]
# ### Intensity analysis

# %%
####################
Lbin = 1
Nstep = 100
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
####################

t_It, It = XPCS.get_It(e4m_data, itime, mask=mask, Lbin=Lbin, Nstep=Nstep)
np.savez(Idts_folder+'Idt_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4), t_It=t_It, It=It)

# %%
plt.figure(figsize=(10,5))
plt.scatter(t_It, It, label='It')

plt.xlabel('Time (s)')
plt.ylabel('Integrated intensity [photons/pixel/s]')
plt.xscale('log')
#plt.xlim(1e-2, 1)
plt.gca().secondary_xaxis('top', functions=(lambda x: x/itime, lambda x: x*itime))
plt.grid()

# %% [markdown]
# ### Correlation

# %%
###################
Nfi = 100_000
Nff = None
Lbin = 1
Nbunch = 100
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
###################
if Lbin is None: Lbin=1

G2t = XPCS.get_G2t_bybunch(e4m_data, mask=mask, Nfi=Nfi, Nff=Nff, Lbin=Lbin, Nbunch=Nbunch)
# Out:
# Computing G2t for bunch 1 (Nfi = 100000 , Nff = 111001 ) ...
# Loading frames ...
# Done! (elapsed time = 0.2 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.42e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.141 GB
# Masking data ...
# Done! (elapsed time = 0.74 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.98e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.052 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.4 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 2 (Nfi = 111001 , Nff = 122002 ) ...
# Loading frames ...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.39e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.14 GB
# Masking data ...
# Done! (elapsed time = 0.63 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.95e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.051 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.4 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 3 (Nfi = 122002 , Nff = 133003 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.41e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.14 GB
# Masking data ...
# Done! (elapsed time = 0.51 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.97e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.051 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.32 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.1 s)
#
# Done!
#
# Computing G2t for bunch 4 (Nfi = 133003 , Nff = 144004 ) ...
# Loading frames ...
# Done! (elapsed time = 0.23 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.40e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.14 GB
# Masking data ...
# Done! (elapsed time = 0.74 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.96e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.051 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 5 (Nfi = 144004 , Nff = 155005 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.38e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.14 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.94e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.051 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.33 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 6 (Nfi = 155005 , Nff = 166006 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.39e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.14 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.94e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.051 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.36 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 7 (Nfi = 166006 , Nff = 177007 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.37e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.139 GB
# Masking data ...
# Done! (elapsed time = 0.68 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.92e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.051 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.39 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 8 (Nfi = 177007 , Nff = 188008 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.32e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.137 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.86e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.33 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 9 (Nfi = 188008 , Nff = 199009 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.30e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.136 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.26 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 10 (Nfi = 199009 , Nff = 210010 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.33e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.137 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.87e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 11 (Nfi = 210010 , Nff = 221011 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.41e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.141 GB
# Masking data ...
# Done! (elapsed time = 0.64 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.98e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.052 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.26 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 12 (Nfi = 221011 , Nff = 232012 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.44e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.142 GB
# Masking data ...
# Done! (elapsed time = 0.67 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 4.01e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.052 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.38 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 13 (Nfi = 232012 , Nff = 243013 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.38e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.139 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.93e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.051 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 14 (Nfi = 243013 , Nff = 254014 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.34e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.138 GB
# Masking data ...
# Done! (elapsed time = 0.65 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.88e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.37 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 15 (Nfi = 254014 , Nff = 265015 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.33e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.137 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.87e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.32 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 16 (Nfi = 265015 , Nff = 276016 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.40e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.14 GB
# Masking data ...
# Done! (elapsed time = 0.61 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.96e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.051 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.36 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.08 s)
#
# Done!
#
# Computing G2t for bunch 17 (Nfi = 276016 , Nff = 287017 ) ...
# Loading frames ...
# Done! (elapsed time = 0.23 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.41e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.141 GB
# Masking data ...
# Done! (elapsed time = 1.23 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.97e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.051 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.48 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 18 (Nfi = 287017 , Nff = 298018 ) ...
# Loading frames ...
# Done! (elapsed time = 0.23 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.39e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.14 GB
# Masking data ...
# Done! (elapsed time = 1.11 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.95e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.051 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.4 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.08 s)
#
# Done!
#
# Computing G2t for bunch 19 (Nfi = 298018 , Nff = 309019 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.37e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.139 GB
# Masking data ...
# Done! (elapsed time = 0.82 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.92e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.051 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.4 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.08 s)
#
# Done!
#
# Computing G2t for bunch 20 (Nfi = 309019 , Nff = 320020 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.36e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.139 GB
# Masking data ...
# Done! (elapsed time = 0.7 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.91e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.051 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 21 (Nfi = 320020 , Nff = 331021 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.34e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.138 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.88e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 22 (Nfi = 331021 , Nff = 342022 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.32e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.137 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.86e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 23 (Nfi = 342022 , Nff = 353023 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.32e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.137 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.85e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 24 (Nfi = 353023 , Nff = 364024 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.29e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.136 GB
# Masking data ...
# Done! (elapsed time = 0.51 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 25 (Nfi = 364024 , Nff = 375025 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.31e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.136 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 26 (Nfi = 375025 , Nff = 386026 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.30e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.136 GB
# Masking data ...
# Done! (elapsed time = 0.54 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.08 s)
#
# Done!
#
# Computing G2t for bunch 27 (Nfi = 386026 , Nff = 397027 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.30e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.136 GB
# Masking data ...
# Done! (elapsed time = 0.47 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 28 (Nfi = 397027 , Nff = 408028 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.30e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.136 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.08 s)
#
# Done!
#
# Computing G2t for bunch 29 (Nfi = 408028 , Nff = 419029 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.28e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.135 GB
# Masking data ...
# Done! (elapsed time = 0.54 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.08 s)
#
# Done!
#
# Computing G2t for bunch 30 (Nfi = 419029 , Nff = 430030 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.31e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.137 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.85e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.08 s)
#
# Done!
#
# Computing G2t for bunch 31 (Nfi = 430030 , Nff = 441031 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.36e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.139 GB
# Masking data ...
# Done! (elapsed time = 0.6 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.91e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.051 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.08 s)
#
# Done!
#
# Computing G2t for bunch 32 (Nfi = 441031 , Nff = 452032 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.33e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.137 GB
# Masking data ...
# Done! (elapsed time = 0.51 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.87e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 33 (Nfi = 452032 , Nff = 463033 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.30e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.136 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.09 s)
#
# Done!
#
# Computing G2t for bunch 34 (Nfi = 463033 , Nff = 474034 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.31e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.137 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.84e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.08 s)
#
# Done!
#
# Computing G2t for bunch 35 (Nfi = 474034 , Nff = 485035 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.29e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.136 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 36 (Nfi = 485035 , Nff = 496036 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.26e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.134 GB
# Masking data ...
# Done! (elapsed time = 0.49 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 37 (Nfi = 496036 , Nff = 507037 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.30e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.136 GB
# Masking data ...
# Done! (elapsed time = 0.47 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.83e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 38 (Nfi = 507037 , Nff = 518038 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.28e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.135 GB
# Masking data ...
# Done! (elapsed time = 0.51 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.80e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 39 (Nfi = 518038 , Nff = 529039 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.25e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.134 GB
# Masking data ...
# Done! (elapsed time = 0.51 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.77e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 40 (Nfi = 529039 , Nff = 540040 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.23e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.133 GB
# Masking data ...
# Done! (elapsed time = 0.52 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.75e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 41 (Nfi = 540040 , Nff = 551041 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.29e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.136 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 42 (Nfi = 551041 , Nff = 562042 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.32e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.137 GB
# Masking data ...
# Done! (elapsed time = 0.61 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.86e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 43 (Nfi = 562042 , Nff = 573043 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.29e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.136 GB
# Masking data ...
# Done! (elapsed time = 0.51 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 44 (Nfi = 573043 , Nff = 584044 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.29e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.136 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.82e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 45 (Nfi = 584044 , Nff = 595045 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.31e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.137 GB
# Masking data ...
# Done! (elapsed time = 0.63 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.85e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.05 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 46 (Nfi = 595045 , Nff = 606046 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.29e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.136 GB
# Masking data ...
# Done! (elapsed time = 0.56 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 47 (Nfi = 606046 , Nff = 617047 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.28e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.135 GB
# Masking data ...
# Done! (elapsed time = 0.56 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 48 (Nfi = 617047 , Nff = 628048 ) ...
# Loading frames ...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.28e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.135 GB
# Masking data ...
# Done! (elapsed time = 0.83 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.81e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 49 (Nfi = 628048 , Nff = 639049 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.27e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.135 GB
# Masking data ...
# Done! (elapsed time = 0.73 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 50 (Nfi = 639049 , Nff = 650050 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.26e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.135 GB
# Masking data ...
# Done! (elapsed time = 0.58 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.79e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 51 (Nfi = 650050 , Nff = 661051 ) ...
# Loading frames ...
# Done! (elapsed time = 0.22 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.26e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.135 GB
# Masking data ...
# Done! (elapsed time = 1.12 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.78e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.049 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.38 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 52 (Nfi = 661051 , Nff = 672052 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.22e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.133 GB
# Masking data ...
# Done! (elapsed time = 0.86 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.74e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 53 (Nfi = 672052 , Nff = 683053 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.21e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.132 GB
# Masking data ...
# Done! (elapsed time = 0.97 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.72e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 54 (Nfi = 683053 , Nff = 694054 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.22e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.133 GB
# Masking data ...
# Done! (elapsed time = 0.66 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.73e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.08 s)
#
# Done!
#
# Computing G2t for bunch 55 (Nfi = 694054 , Nff = 705055 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.21e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.133 GB
# Masking data ...
# Done! (elapsed time = 0.77 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.72e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.41 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 56 (Nfi = 705055 , Nff = 716056 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.16e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.13 GB
# Masking data ...
# Done! (elapsed time = 0.75 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.4 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.14 s)
#
# Done!
#
# Computing G2t for bunch 57 (Nfi = 716056 , Nff = 727057 ) ...
# Loading frames ...
# Done! (elapsed time = 0.27 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.14e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.129 GB
# Masking data ...
# Done! (elapsed time = 0.87 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.63e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.31 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 58 (Nfi = 727057 , Nff = 738058 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.16e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.13 GB
# Masking data ...
# Done! (elapsed time = 0.71 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.35 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 59 (Nfi = 738058 , Nff = 749059 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.17e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.131 GB
# Masking data ...
# Done! (elapsed time = 0.84 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.36 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 60 (Nfi = 749059 , Nff = 760060 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.19e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.131 GB
# Masking data ...
# Done! (elapsed time = 0.96 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.34 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 61 (Nfi = 760060 , Nff = 771061 ) ...
# Loading frames ...
# Done! (elapsed time = 0.22 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.19e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.132 GB
# Masking data ...
# Done! (elapsed time = 0.97 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 62 (Nfi = 771061 , Nff = 782062 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.16e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.13 GB
# Masking data ...
# Done! (elapsed time = 0.66 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 63 (Nfi = 782062 , Nff = 793063 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.12e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.129 GB
# Masking data ...
# Done! (elapsed time = 0.65 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.60e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.26 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 64 (Nfi = 793063 , Nff = 804064 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.11e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.128 GB
# Masking data ...
# Done! (elapsed time = 0.69 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.59e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.046 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.37 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 65 (Nfi = 804064 , Nff = 815065 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.09e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.128 GB
# Masking data ...
# Done! (elapsed time = 0.64 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.57e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.046 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.29 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 66 (Nfi = 815065 , Nff = 826066 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.11e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.128 GB
# Masking data ...
# Done! (elapsed time = 0.8 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.59e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.046 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.32 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 67 (Nfi = 826066 , Nff = 837067 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.17e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.131 GB
# Masking data ...
# Done! (elapsed time = 0.9 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.34 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 68 (Nfi = 837067 , Nff = 848068 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.18e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.131 GB
# Masking data ...
# Done! (elapsed time = 0.69 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.68e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.41 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 69 (Nfi = 848068 , Nff = 859069 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.17e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.131 GB
# Masking data ...
# Done! (elapsed time = 0.66 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.29 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 70 (Nfi = 859069 , Nff = 870070 ) ...
# Loading frames ...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.21e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.132 GB
# Masking data ...
# Done! (elapsed time = 0.67 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.71e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.35 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 71 (Nfi = 870070 , Nff = 881071 ) ...
# Loading frames ...
# Done! (elapsed time = 0.22 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.22e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.133 GB
# Masking data ...
# Done! (elapsed time = 0.94 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.73e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 72 (Nfi = 881071 , Nff = 892072 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.21e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.132 GB
# Masking data ...
# Done! (elapsed time = 1.14 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.72e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.48 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 73 (Nfi = 892072 , Nff = 903073 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.19e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.131 GB
# Masking data ...
# Done! (elapsed time = 0.72 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.69e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.34 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 74 (Nfi = 903073 , Nff = 914074 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.15e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.13 GB
# Masking data ...
# Done! (elapsed time = 0.55 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.31 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 75 (Nfi = 914074 , Nff = 925075 ) ...
# Loading frames ...
# Done! (elapsed time = 0.2 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.15e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.13 GB
# Masking data ...
# Done! (elapsed time = 1.03 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.35 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Done!
#
# Computing G2t for bunch 76 (Nfi = 925075 , Nff = 936076 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.17e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.131 GB
# Masking data ...
# Done! (elapsed time = 0.99 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.37 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.12 s)
#
# Done!
#
# Computing G2t for bunch 77 (Nfi = 936076 , Nff = 947077 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.15e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.13 GB
# Masking data ...
# Done! (elapsed time = 0.63 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 78 (Nfi = 947077 , Nff = 958078 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.13e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.129 GB
# Masking data ...
# Done! (elapsed time = 0.72 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.61e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 79 (Nfi = 958078 , Nff = 969079 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.15e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.13 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 80 (Nfi = 969079 , Nff = 980080 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.17e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.131 GB
# Masking data ...
# Done! (elapsed time = 0.44 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 81 (Nfi = 980080 , Nff = 991081 ) ...
# Loading frames ...
# Done! (elapsed time = 0.2 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.22e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.133 GB
# Masking data ...
# Done! (elapsed time = 0.7 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.73e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 82 (Nfi = 991081 , Nff = 1002082 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.23e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.133 GB
# Masking data ...
# Done! (elapsed time = 0.6 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.74e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.04 s)
#
# Done!
#
# Computing G2t for bunch 83 (Nfi = 1002082 , Nff = 1013083 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.22e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.133 GB
# Masking data ...
# Done! (elapsed time = 0.45 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.73e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 84 (Nfi = 1013083 , Nff = 1024084 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.23e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.133 GB
# Masking data ...
# Done! (elapsed time = 0.43 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.74e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.04 s)
#
# Done!
#
# Computing G2t for bunch 85 (Nfi = 1024084 , Nff = 1035085 ) ...
# Loading frames ...
# Done! (elapsed time = 0.12 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.23e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.133 GB
# Masking data ...
# Done! (elapsed time = 0.55 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.74e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 86 (Nfi = 1035085 , Nff = 1046086 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.17e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.131 GB
# Masking data ...
# Done! (elapsed time = 0.58 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.67e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 87 (Nfi = 1046086 , Nff = 1057087 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.16e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.131 GB
# Masking data ...
# Done! (elapsed time = 0.66 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 88 (Nfi = 1057087 , Nff = 1068088 ) ...
# Loading frames ...
# Done! (elapsed time = 0.2 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.18e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.131 GB
# Masking data ...
# Done! (elapsed time = 0.6 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.68e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.048 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 89 (Nfi = 1068088 , Nff = 1079089 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.15e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.13 GB
# Masking data ...
# Done! (elapsed time = 0.74 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 90 (Nfi = 1079089 , Nff = 1090090 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.14e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.13 GB
# Masking data ...
# Done! (elapsed time = 0.63 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.63e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 91 (Nfi = 1090090 , Nff = 1101091 ) ...
# Loading frames ...
# Done! (elapsed time = 0.13 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.10e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.128 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.58e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.046 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 92 (Nfi = 1101091 , Nff = 1112092 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.07e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.126 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.53e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.046 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 93 (Nfi = 1112092 , Nff = 1123093 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.10e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.128 GB
# Masking data ...
# Done! (elapsed time = 0.76 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.58e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.046 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.32 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 94 (Nfi = 1123093 , Nff = 1134094 ) ...
# Loading frames ...
# Done! (elapsed time = 0.2 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.13e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.129 GB
# Masking data ...
# Done! (elapsed time = 0.81 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.62e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 95 (Nfi = 1134094 , Nff = 1145095 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.16e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.13 GB
# Masking data ...
# Done! (elapsed time = 0.69 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Done!
#
# Computing G2t for bunch 96 (Nfi = 1145095 , Nff = 1156096 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.10e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.128 GB
# Masking data ...
# Done! (elapsed time = 0.58 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.57e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.046 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.04 s)
#
# Done!
#
# Computing G2t for bunch 97 (Nfi = 1156096 , Nff = 1167097 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.06e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.126 GB
# Masking data ...
# Done! (elapsed time = 0.59 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.53e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.046 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.04 s)
#
# Done!
#
# Computing G2t for bunch 98 (Nfi = 1167097 , Nff = 1178098 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.05e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.126 GB
# Masking data ...
# Done! (elapsed time = 0.61 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.52e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.046 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!
#
# Computing G2t for bunch 99 (Nfi = 1178098 , Nff = 1189099 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.12e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.129 GB
# Masking data ...
# Done! (elapsed time = 0.57 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.60e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.19 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.04 s)
#
# Done!
#
# Computing G2t for bunch 100 (Nfi = 1189099 , Nff = 1200100 ) ...
# Loading frames ...
# Done! (elapsed time = 0.11 s)
# 	 | 11001 frames X 4471016 pixels
# 	 | sparsity = 3.11e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.128 GB
# Masking data ...
# Done! (elapsed time = 0.51 s)
# 	 | 11001 frames X 1402367 pixels
# 	 | sparsity = 3.60e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.047 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 11001 X 11001 squared matrix
# 	 | memory usage (np.array @ float64) = 0.902 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Done!

# %%
############################
t1, t2 = 0, 10
vmin, vmax = 1.0, 1.06
############################
XPCS.plot_G2t(G2t, vmin, vmax, itime=itime, t1=t1, t2=t2, sigma_filter=3)

# %% [markdown]
# ### g2(t)

# %%
################
Nbunch = 1
################

NfXbunch = int(G2t.shape[0]/Nbunch)
t, g2, t_mt, g2_mt = {}, {}, {}, {}
for n in range(Nbunch):
    t_bunch = round(itime*Lbin*NfXbunch*(n+1/2),1)

    t[t_bunch], g2[t_bunch] = XPCS.get_g2(itime*Lbin, np.array(G2t[NfXbunch*n:NfXbunch*(n+1), NfXbunch*n:NfXbunch*(n+1)]), cython=False)
    t_mt[t_bunch], g2_mt[t_bunch] = XPCS.get_g2_mt(itime*Lbin, g2[t_bunch])
# Out:
# Computing g2...
# Done! (elapsed time = 0.42 s)

# %%
##################
t1_fit = 0
t2_fit = 1e8
##################
 
plt.figure(figsize=(10,5))
fit_out = pd.DataFrame(columns=['tau', 'beta', 'c', 'y0', 'dtau', 'dbeta', 'dc', 'dy0'])
fit_out.index.name = 't'
for k in g2.keys():
    #plt.scatter(t[k], g2[k], s=1, label = str(k)+'s')
    plt.scatter(t_mt[k], g2_mt[k], label=str(k)+'s')

    popt, pcov = curve_fit(decorelation_f, t[k][(t1_fit<t[k])*(t[k]<t2_fit)], g2[k][(t1_fit<t[k])*(t[k]<t2_fit)], p0=[3, .7, .02, 1], bounds=([0, 0, 0, 0], [np.inf, np.inf, np.inf, np.inf]))
    fit_out.loc[k] = [popt[0], popt[1], popt[2], popt[3], np.sqrt(pcov[0,0]), np.sqrt(pcov[1,1]), np.sqrt(pcov[2,2]), np.sqrt(pcov[3,3])]
    
    x = np.arange(np.min(t[k]), np.max(t[k]), 1e-2)
    y = decorelation_f(x, *popt)
    plt.plot(x, y,)

fit_out.to_csv(fit_outs_folder+'fit_out_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4)+'.csv')

plt.xlabel('t [s]')
plt.ylabel('g2')
plt.xscale('log')
plt.legend()
plt.show()

if Nbunch == 1:
    print(f'tau = {popt[0]} +/- {np.sqrt(pcov[0,0])}')
    print(f'beta = {popt[1]} +/- {np.sqrt(pcov[1,1])}')
    print(f'c = {popt[2]} +/- {np.sqrt(pcov[2,2])}')
    print(f'y0 = {popt[3]} +/- {np.sqrt(pcov[3,3])}')
else:
    plt.figure(figsize=(10,5))
    plt.title('tau')
    plt.errorbar(fit_out.index, fit_out.tau,  yerr=fit_out.dtau, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('tau [s]')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('beta')
    plt.errorbar(fit_out.index, fit_out.beta,  yerr=fit_out.dbeta, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('beta')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('c')
    plt.errorbar(fit_out.index, fit_out.c,  yerr=fit_out.dc, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('c')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('y0')
    plt.errorbar(fit_out.index, fit_out.y0,  yerr=fit_out.dy0, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('y0')
    plt.show()
# Out:
# tau = 0.25072401272600964 +/- 0.11861587264470112
# beta = 1.0960998908068509 +/- 0.6586157978490594
# c = 0.003965244322021065 +/- 0.0013934570629277412
# y0 = 1.0062535858690247 +/- 6.684160416315285e-05

# %% [markdown]
# ## XPCS mesh (T = 730C Q =  0.46 Å, 20 min @ 1ms (1_200_000 fm)) (GeO2_3, dataset 1, scan 7)

# %%
#######################################
sample_name = 'GeO2_3_730C_Q'
Ndataset = 1
Nscan = 7
Nfi, Nff =  None, None
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
#e4m_data = ID10.load_dense_e4m_new(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )

e4m_data = COSMIC.fast_gamma_filter(e4m_data, Imaxth_high=5)
# Out:
# #############################
# command = mtimescan 0.001 1 1200192
# Ei = 9.699998837562536
# itime = 0.0011
# theta = 5.0
# Q = 0.43
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00001.h5 (2/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00002.h5 (3/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00003.h5 (4/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00004.h5 (5/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00005.h5 (6/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00006.h5 (7/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00007.h5 (8/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00008.h5 (9/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00009.h5 (10/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00010.h5 (11/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00011.h5 (12/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00012.h5 (13/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00013.h5 (14/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00014.h5 (15/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00015.h5 (16/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00016.h5 (17/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00017.h5 (18/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00018.h5 (19/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00019.h5 (20/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00020.h5 (21/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00021.h5 (22/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00022.h5 (23/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00023.h5 (24/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00024.h5 (25/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00025.h5 (26/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00026.h5 (27/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00027.h5 (28/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00028.h5 (29/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00029.h5 (30/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00030.h5 (31/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00031.h5 (32/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00032.h5 (33/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00033.h5 (34/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00034.h5 (35/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00035.h5 (36/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00036.h5 (37/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00037.h5 (38/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00038.h5 (39/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00039.h5 (40/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00040.h5 (41/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00041.h5 (42/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00042.h5 (43/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00043.h5 (44/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00044.h5 (45/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00045.h5 (46/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00046.h5 (47/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00047.h5 (48/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00048.h5 (49/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00049.h5 (50/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00050.h5 (51/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00051.h5 (52/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00052.h5 (53/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00053.h5 (54/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00054.h5 (55/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00055.h5 (56/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00056.h5 (57/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00057.h5 (58/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00058.h5 (59/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00059.h5 (60/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00060.h5 (61/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00061.h5 (62/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00062.h5 (63/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00063.h5 (64/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00064.h5 (65/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00065.h5 (66/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00066.h5 (67/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00067.h5 (68/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00068.h5 (69/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00069.h5 (70/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00070.h5 (71/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00071.h5 (72/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00072.h5 (73/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00073.h5 (74/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00074.h5 (75/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00075.h5 (76/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00076.h5 (77/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00077.h5 (78/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00078.h5 (79/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00079.h5 (80/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00080.h5 (81/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00081.h5 (82/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00082.h5 (83/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00083.h5 (84/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00084.h5 (85/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00085.h5 (86/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00086.h5 (87/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00087.h5 (88/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00088.h5 (89/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00089.h5 (90/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00090.h5 (91/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00091.h5 (92/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00092.h5 (93/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00093.h5 (94/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00094.h5 (95/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00095.h5 (96/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00096.h5 (97/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00097.h5 (98/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00098.h5 (99/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00099.h5 (100/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00100.h5 (101/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00101.h5 (102/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00102.h5 (103/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00103.h5 (104/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00104.h5 (105/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00105.h5 (106/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00106.h5 (107/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00107.h5 (108/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00108.h5 (109/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00109.h5 (110/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00110.h5 (111/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00111.h5 (112/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00112.h5 (113/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00113.h5 (114/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00114.h5 (115/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00115.h5 (116/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00116.h5 (117/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00117.h5 (118/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00118.h5 (119/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00119.h5 (120/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00120.h5 (121/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00121.h5 (122/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00122.h5 (123/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00123.h5 (124/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00124.h5 (125/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00125.h5 (126/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00126.h5 (127/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00127.h5 (128/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00128.h5 (129/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00129.h5 (130/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00130.h5 (131/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00131.h5 (132/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00132.h5 (133/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00133.h5 (134/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00134.h5 (135/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00135.h5 (136/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00136.h5 (137/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00137.h5 (138/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00138.h5 (139/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00139.h5 (140/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00140.h5 (141/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00141.h5 (142/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00142.h5 (143/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00143.h5 (144/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00144.h5 (145/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00145.h5 (146/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00146.h5 (147/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00147.h5 (148/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00148.h5 (149/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00149.h5 (150/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00150.h5 (151/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00151.h5 (152/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00152.h5 (153/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00153.h5 (154/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00154.h5 (155/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00155.h5 (156/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00156.h5 (157/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00157.h5 (158/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00158.h5 (159/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00159.h5 (160/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00160.h5 (161/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00161.h5 (162/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00162.h5 (163/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00163.h5 (164/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00164.h5 (165/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00165.h5 (166/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00166.h5 (167/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00167.h5 (168/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00168.h5 (169/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00169.h5 (170/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00170.h5 (171/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00171.h5 (172/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00172.h5 (173/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00173.h5 (174/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00174.h5 (175/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00175.h5 (176/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00176.h5 (177/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00177.h5 (178/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00178.h5 (179/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00179.h5 (180/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00180.h5 (181/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00181.h5 (182/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00182.h5 (183/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00183.h5 (184/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00184.h5 (185/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00185.h5 (186/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00186.h5 (187/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00187.h5 (188/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00188.h5 (189/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00189.h5 (190/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00190.h5 (191/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00191.h5 (192/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00192.h5 (193/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00193.h5 (194/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00194.h5 (195/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00195.h5 (196/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00196.h5 (197/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00197.h5 (198/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00198.h5 (199/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00199.h5 (200/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00200.h5 (201/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00201.h5 (202/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00202.h5 (203/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00203.h5 (204/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00204.h5 (205/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00205.h5 (206/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00206.h5 (207/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00207.h5 (208/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00208.h5 (209/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00209.h5 (210/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00210.h5 (211/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00211.h5 (212/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00212.h5 (213/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00213.h5 (214/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00214.h5 (215/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00215.h5 (216/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00216.h5 (217/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00217.h5 (218/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00218.h5 (219/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00219.h5 (220/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00220.h5 (221/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00221.h5 (222/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00222.h5 (223/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00223.h5 (224/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00224.h5 (225/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00225.h5 (226/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00226.h5 (227/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00227.h5 (228/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00228.h5 (229/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00229.h5 (230/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00230.h5 (231/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00231.h5 (232/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00232.h5 (233/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00233.h5 (234/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00234.h5 (235/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00235.h5 (236/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00236.h5 (237/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00237.h5 (238/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00238.h5 (239/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00239.h5 (240/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00240.h5 (241/241 loops)
# Done!
# Concatenating vectors ...
# Done!
# 	 | Sparse array loaded from ../RAW_DATA/GeO2_3_730C_Q/GeO2_3_730C_Q_0001/scan0007/
# 	 | Shape:       (1200192, 4471016)
# 	 | Sparsity:     3.5e-04
# 	 | Memory usage (scipy.csr_array): 15.802 GB (np.array usage: 19990.197 GB)
# Filtering gamma ray signal (i.e. signals over treshold) ...
# Done! (elapsed time = 9.11 s)
# Removing gamma ray signal (set 0s) ...
# Done! (elapsed time = 9.61 s)

# %% [markdown]
# ### Qmask

# %%
###################
Q    = .46
Qres = .02
###################

Qmask = XPCS.gen_Qmask(Ei, theta, Q, Qres, Qmap_plot=True)

# %% [markdown]
# ### Flux check

# %%
#############################################
mask = e4m_mask * e4m_htmask * bs_mask
#############################################

XPCS.gen_plots4mask(e4m_data, itime, Ith_high= .4, Nff=100_000, e4m_mask=mask)
# Out:
# ################################################################################
# Maximum count in the hull run -> 5
# # of pixels above Ith_high treshold ->  808101 pixels (of 4471016 => 24.3 %)
# ################################################################################

# %% [markdown]
# ### Intensity analysis

# %%
####################
Lbin = 1
Nstep = 100
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
####################

t_It, It = XPCS.get_It(e4m_data, itime, mask=mask, Lbin=Lbin, Nstep=Nstep)
np.savez(Idts_folder+'Idt_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4), t_It=t_It, It=It)

# %%
plt.figure(figsize=(10,5))
plt.scatter(t_It, It, label='It')

plt.xlabel('Time (s)')
plt.ylabel('Integrated intensity [photons/pixel/s]')
plt.xscale('log')
#plt.xlim(1e-2, 1)
plt.gca().secondary_xaxis('top', functions=(lambda x: x/itime, lambda x: x*itime))
plt.grid()

# %% [markdown]
# ### Correlation

# %%
###################
Nfi = 100_000
Nff = None
Lbin = 10
Nbunch = 100
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
###################
if Lbin is None: Lbin=1

G2t = XPCS.get_G2t_bybunch(e4m_data, mask=mask, Nfi=Nfi, Nff=Nff, Lbin=Lbin, Nbunch=Nbunch)
# Out:
# Computing G2t for bunch 1 (Nfi = 100000 , Nff = 111001 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.42 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.53e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.194 GB
# Masking data ...
# Done! (elapsed time = 0.39 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.09e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.071 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 2 (Nfi = 111001 , Nff = 122002 ) ...
# Loading frames ...
# Done! (elapsed time = 0.22 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.4 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.53e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.194 GB
# Masking data ...
# Done! (elapsed time = 0.33 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.09e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.071 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.33 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 3 (Nfi = 122002 , Nff = 133003 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.36 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.53e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.194 GB
# Masking data ...
# Done! (elapsed time = 0.45 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.09e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.071 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.62 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 4 (Nfi = 133003 , Nff = 144004 ) ...
# Loading frames ...
# Done! (elapsed time = 0.21 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.37 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.52e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.194 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.08e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.32 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 5 (Nfi = 144004 , Nff = 155005 ) ...
# Loading frames ...
# Done! (elapsed time = 0.26 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.49 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.52e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.194 GB
# Masking data ...
# Done! (elapsed time = 0.4 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.08e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 6 (Nfi = 155005 , Nff = 166006 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.29 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.52e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.194 GB
# Masking data ...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.08e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.071 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 7 (Nfi = 166006 , Nff = 177007 ) ...
# Loading frames ...
# Done! (elapsed time = 0.32 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.38 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.52e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.33 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.08e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.34 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 8 (Nfi = 177007 , Nff = 188008 ) ...
# Loading frames ...
# Done! (elapsed time = 0.34 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.42 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.07e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.33 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.02 s)
#
# Done!
#
# Computing G2t for bunch 9 (Nfi = 188008 , Nff = 199009 ) ...
# Loading frames ...
# Done! (elapsed time = 0.27 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.45 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.42 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.07e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 10 (Nfi = 199009 , Nff = 210010 ) ...
# Loading frames ...
# Done! (elapsed time = 0.23 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.37 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.52e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.3 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.07e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 11 (Nfi = 210010 , Nff = 221011 ) ...
# Loading frames ...
# Done! (elapsed time = 0.22 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.38 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.52e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.38 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.08e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 12 (Nfi = 221011 , Nff = 232012 ) ...
# Loading frames ...
# Done! (elapsed time = 0.23 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.44 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.52e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.35 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.08e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 13 (Nfi = 232012 , Nff = 243013 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.33 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.52e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.07e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.02 s)
#
# Done!
#
# Computing G2t for bunch 14 (Nfi = 243013 , Nff = 254014 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.26 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.07e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.26 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 15 (Nfi = 254014 , Nff = 265015 ) ...
# Loading frames ...
# Done! (elapsed time = 0.27 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.38 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 16 (Nfi = 265015 , Nff = 276016 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.4 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 17 (Nfi = 276016 , Nff = 287017 ) ...
# Loading frames ...
# Done! (elapsed time = 0.2 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.4 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.41 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.26 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 18 (Nfi = 287017 , Nff = 298018 ) ...
# Loading frames ...
# Done! (elapsed time = 0.3 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.44 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.31 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.02 s)
#
# Done!
#
# Computing G2t for bunch 19 (Nfi = 298018 , Nff = 309019 ) ...
# Loading frames ...
# Done! (elapsed time = 0.31 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.41 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.48 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 20 (Nfi = 309019 , Nff = 320020 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.4 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.59 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.35 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 21 (Nfi = 320020 , Nff = 331021 ) ...
# Loading frames ...
# Done! (elapsed time = 0.22 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.56 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.55 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.07e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.38 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 22 (Nfi = 331021 , Nff = 342022 ) ...
# Loading frames ...
# Done! (elapsed time = 0.3 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.36 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.31 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.07e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.32 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 23 (Nfi = 342022 , Nff = 353023 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.26 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.07e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.26 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 24 (Nfi = 353023 , Nff = 364024 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.35 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.42 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 25 (Nfi = 364024 , Nff = 375025 ) ...
# Loading frames ...
# Done! (elapsed time = 0.22 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.35 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.35 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 26 (Nfi = 375025 , Nff = 386026 ) ...
# Loading frames ...
# Done! (elapsed time = 0.26 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.39 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.41 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 27 (Nfi = 386026 , Nff = 397027 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.19 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 28 (Nfi = 397027 , Nff = 408028 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.29 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.18 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 29 (Nfi = 408028 , Nff = 419029 ) ...
# Loading frames ...
# Done! (elapsed time = 0.23 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.35 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.39 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 30 (Nfi = 419029 , Nff = 430030 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.31 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.29 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 31 (Nfi = 430030 , Nff = 441031 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.18 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 32 (Nfi = 441031 , Nff = 452032 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.32 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.05e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 33 (Nfi = 452032 , Nff = 463033 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 34 (Nfi = 463033 , Nff = 474034 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.26 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.32 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 35 (Nfi = 474034 , Nff = 485035 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.34 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.3 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.19 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 36 (Nfi = 485035 , Nff = 496036 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.26 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.51e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.3 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 37 (Nfi = 496036 , Nff = 507037 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 38 (Nfi = 507037 , Nff = 518038 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.29 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 39 (Nfi = 518038 , Nff = 529039 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.26 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.47 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.05e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 40 (Nfi = 529039 , Nff = 540040 ) ...
# Loading frames ...
# Done! (elapsed time = 0.31 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.38 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.4 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 41 (Nfi = 540040 , Nff = 551041 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.3 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.193 GB
# Masking data ...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.06e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 42 (Nfi = 551041 , Nff = 562042 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.37 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.46 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.05e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 43 (Nfi = 562042 , Nff = 573043 ) ...
# Loading frames ...
# Done! (elapsed time = 0.22 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.31 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.29 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.05e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 44 (Nfi = 573043 , Nff = 584044 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.36 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.05e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 45 (Nfi = 584044 , Nff = 595045 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.36 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.50e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.41 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.05e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 46 (Nfi = 595045 , Nff = 606046 ) ...
# Loading frames ...
# Done! (elapsed time = 0.26 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.44 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.35 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.05e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.19 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 47 (Nfi = 606046 , Nff = 617047 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.3 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.05e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 48 (Nfi = 617047 , Nff = 628048 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.33 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.05e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 49 (Nfi = 628048 , Nff = 639049 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.31 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.26 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.18 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 50 (Nfi = 639049 , Nff = 650050 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.19 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 51 (Nfi = 650050 , Nff = 661051 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.32 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.38 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 52 (Nfi = 661051 , Nff = 672052 ) ...
# Loading frames ...
# Done! (elapsed time = 0.22 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.36 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.36 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.05e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 53 (Nfi = 672052 , Nff = 683053 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.3 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 54 (Nfi = 683053 , Nff = 694054 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.3 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.26 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.19 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 55 (Nfi = 694054 , Nff = 705055 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.33 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.53 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 56 (Nfi = 705055 , Nff = 716056 ) ...
# Loading frames ...
# Done! (elapsed time = 0.28 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.46 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.41 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.3 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 57 (Nfi = 716056 , Nff = 727057 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.34 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 58 (Nfi = 727057 , Nff = 738058 ) ...
# Loading frames ...
# Done! (elapsed time = 0.15 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.34 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.32 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.18 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 59 (Nfi = 738058 , Nff = 749059 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.3 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.26 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 60 (Nfi = 749059 , Nff = 760060 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 61 (Nfi = 760060 , Nff = 771061 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.41 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.26 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 62 (Nfi = 771061 , Nff = 782062 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.31 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 63 (Nfi = 782062 , Nff = 793063 ) ...
# Loading frames ...
# Done! (elapsed time = 0.33 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.36 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.39 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 64 (Nfi = 793063 , Nff = 804064 ) ...
# Loading frames ...
# Done! (elapsed time = 0.3 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.47 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.51 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.02 s)
#
# Done!
#
# Computing G2t for bunch 65 (Nfi = 804064 , Nff = 815065 ) ...
# Loading frames ...
# Done! (elapsed time = 0.43 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.57 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.37 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 66 (Nfi = 815065 , Nff = 826066 ) ...
# Loading frames ...
# Done! (elapsed time = 0.31 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.42 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.58 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 67 (Nfi = 826066 , Nff = 837067 ) ...
# Loading frames ...
# Done! (elapsed time = 0.28 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.36 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.32 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 68 (Nfi = 837067 , Nff = 848068 ) ...
# Loading frames ...
# Done! (elapsed time = 0.25 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.35 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.32 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 69 (Nfi = 848068 , Nff = 859069 ) ...
# Loading frames ...
# Done! (elapsed time = 0.25 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.43 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.49e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.192 GB
# Masking data ...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.04e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 70 (Nfi = 859069 , Nff = 870070 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.31 s)
# 	 | 1100 frames X 4471016 pixels
# ...
#
# Done!
#
# Computing G2t for bunch 78 (Nfi = 947077 , Nff = 958078 ) ...
# Loading frames ...
# Done! (elapsed time = 0.22 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.38 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.33 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 79 (Nfi = 958078 , Nff = 969079 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.26 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 80 (Nfi = 969079 , Nff = 980080 ) ...
# Loading frames ...
# Done! (elapsed time = 0.17 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.37 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.27 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 81 (Nfi = 980080 , Nff = 991081 ) ...
# Loading frames ...
# Done! (elapsed time = 0.16 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.0 s)
#
# Done!
#
# Computing G2t for bunch 82 (Nfi = 991081 , Nff = 1002082 ) ...
# Loading frames ...
# Done! (elapsed time = 0.3 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.57 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.25 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 83 (Nfi = 1002082 , Nff = 1013083 ) ...
# Loading frames ...
# Done! (elapsed time = 0.26 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.41 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.32 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 84 (Nfi = 1013083 , Nff = 1024084 ) ...
# Loading frames ...
# Done! (elapsed time = 0.25 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.45 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.22 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 85 (Nfi = 1024084 , Nff = 1035085 ) ...
# Loading frames ...
# Done! (elapsed time = 0.25 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.37 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.33 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.58 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 86 (Nfi = 1035085 , Nff = 1046086 ) ...
# Loading frames ...
# Done! (elapsed time = 0.26 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.55 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.43 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 87 (Nfi = 1046086 , Nff = 1057087 ) ...
# Loading frames ...
# Done! (elapsed time = 0.26 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.36 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.3 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 88 (Nfi = 1057087 , Nff = 1068088 ) ...
# Loading frames ...
# Done! (elapsed time = 0.25 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.36 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.5 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.33 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.03 s)
#
# Done!
#
# Computing G2t for bunch 89 (Nfi = 1068088 , Nff = 1079089 ) ...
# Loading frames ...
# Done! (elapsed time = 0.42 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.45 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.53 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 90 (Nfi = 1079089 , Nff = 1090090 ) ...
# Loading frames ...
# Done! (elapsed time = 0.25 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.33 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.3 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 91 (Nfi = 1090090 , Nff = 1101091 ) ...
# Loading frames ...
# Done! (elapsed time = 0.25 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.49 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.43 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 92 (Nfi = 1101091 , Nff = 1112092 ) ...
# Loading frames ...
# Done! (elapsed time = 0.25 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.36 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.32 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.37 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 93 (Nfi = 1112092 , Nff = 1123093 ) ...
# Loading frames ...
# Done! (elapsed time = 0.19 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.41 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.29 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.24 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 94 (Nfi = 1123093 , Nff = 1134094 ) ...
# Loading frames ...
# Done! (elapsed time = 0.26 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.33 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.34 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.21 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 95 (Nfi = 1134094 , Nff = 1145095 ) ...
# Loading frames ...
# Done! (elapsed time = 0.26 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.36 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.58 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.29 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 96 (Nfi = 1145095 , Nff = 1156096 ) ...
# Loading frames ...
# Done! (elapsed time = 0.3 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.45 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.63 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.29 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 97 (Nfi = 1156096 , Nff = 1167097 ) ...
# Loading frames ...
# Done! (elapsed time = 0.3 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.48 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.53 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 98 (Nfi = 1167097 , Nff = 1178098 ) ...
# Loading frames ...
# Done! (elapsed time = 0.2 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.31 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.3 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 99 (Nfi = 1178098 , Nff = 1189099 ) ...
# Loading frames ...
# Done! (elapsed time = 0.24 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.52 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.28 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.2 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!
#
# Computing G2t for bunch 100 (Nfi = 1189099 , Nff = 1200100 ) ...
# Loading frames ...
# Done! (elapsed time = 0.18 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.31 s)
# 	 | 1100 frames X 4471016 pixels
# 	 | sparsity = 3.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.191 GB
# Masking data ...
# Done! (elapsed time = 0.31 s)
# 	 | 1100 frames X 1405396 pixels
# 	 | sparsity = 4.03e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.07 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.23 s)
# 	 | 1100 X 1100 squared matrix
# 	 | memory usage (np.array @ float64) = 0.009 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.01 s)
#
# Done!

# %%
############################
t1, t2 = 0, 10
vmin, vmax = 1.0, 1.06
############################
XPCS.plot_G2t(G2t, vmin, vmax, itime=itime, t1=t1, t2=t2, sigma_filter=3)

# %% [markdown]
# ### g2(t)

# %%
################
Nbunch = 1
################

NfXbunch = int(G2t.shape[0]/Nbunch)
t, g2, t_mt, g2_mt = {}, {}, {}, {}
for n in range(Nbunch):
    t_bunch = round(itime*Lbin*NfXbunch*(n+1/2),1)

    t[t_bunch], g2[t_bunch] = XPCS.get_g2(itime*Lbin, np.array(G2t[NfXbunch*n:NfXbunch*(n+1), NfXbunch*n:NfXbunch*(n+1)]), cython=False)
    t_mt[t_bunch], g2_mt[t_bunch] = XPCS.get_g2_mt(itime*Lbin, g2[t_bunch])
# Out:
# Computing g2...
# Done! (elapsed time = 0.01 s)

# %%
##################
t1_fit = 0
t2_fit = 1e8
##################
 
plt.figure(figsize=(10,5))
fit_out = pd.DataFrame(columns=['tau', 'beta', 'c', 'y0', 'dtau', 'dbeta', 'dc', 'dy0'])
fit_out.index.name = 't'
for k in g2.keys():
    #plt.scatter(t[k], g2[k], s=1, label = str(k)+'s')
    plt.scatter(t_mt[k], g2_mt[k], label=str(k)+'s')

    popt, pcov = curve_fit(decorelation_f, t[k][(t1_fit<t[k])*(t[k]<t2_fit)], g2[k][(t1_fit<t[k])*(t[k]<t2_fit)], p0=[3, .7, .02, 1], bounds=([0, 0, 0, 0], [np.inf, np.inf, np.inf, np.inf]))
    fit_out.loc[k] = [popt[0], popt[1], popt[2], popt[3], np.sqrt(pcov[0,0]), np.sqrt(pcov[1,1]), np.sqrt(pcov[2,2]), np.sqrt(pcov[3,3])]
    
    x = np.arange(np.min(t[k]), np.max(t[k]), 1e-2)
    y = decorelation_f(x, *popt)
    plt.plot(x, y,)

fit_out.to_csv(fit_outs_folder+'fit_out_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4)+'.csv')

plt.xlabel('t [s]')
plt.ylabel('g2')
plt.xscale('log')
plt.legend()
plt.show()

if Nbunch == 1:
    print(f'tau = {popt[0]} +/- {np.sqrt(pcov[0,0])}')
    print(f'beta = {popt[1]} +/- {np.sqrt(pcov[1,1])}')
    print(f'c = {popt[2]} +/- {np.sqrt(pcov[2,2])}')
    print(f'y0 = {popt[3]} +/- {np.sqrt(pcov[3,3])}')
else:
    plt.figure(figsize=(10,5))
    plt.title('tau')
    plt.errorbar(fit_out.index, fit_out.tau,  yerr=fit_out.dtau, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('tau [s]')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('beta')
    plt.errorbar(fit_out.index, fit_out.beta,  yerr=fit_out.dbeta, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('beta')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('c')
    plt.errorbar(fit_out.index, fit_out.c,  yerr=fit_out.dc, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('c')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('y0')
    plt.errorbar(fit_out.index, fit_out.y0,  yerr=fit_out.dy0, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('y0')
    plt.show()
# Out:
# tau = 0.24402690179863976 +/- 0.1369221570896865
# beta = 0.8592080229035906 +/- 0.42019322152597915
# c = 0.0043290805291683965 +/- 0.001569462365215996
# y0 = 1.0035978602484277 +/- 5.616554531898223e-05
