# %%
### IMPORT SCIENTIFIC LIBRARIES ###
import numpy as np
import pandas as pd
from scipy import sparse
from scipy.optimize import curve_fit
import importlib

import matplotlib.pyplot as plt
#import seaborn as sns
plt.rcParams['font.size'], plt.rcParams['axes.labelsize'] = 14, 18
#%matplotlib widget

from tqdm import tqdm
import io, sys
from contextlib import redirect_stdout, redirect_stderr

import os

import h5py
import hdf5plugin

import sys
sys.path.append('./XPCS_library/')

import ID10_tools as ID10
from ID10_tools import Nx, Ny, Npx
importlib.reload(ID10)
ID10.set_version('v2')

import XPCS_tools as XPCS
from XPCS_tools import E2lambda, lambda2E, theta2Q, Q2theta, decorelation_f
importlib.reload(XPCS)
XPCS.set_beamline('ID10')

import COSMICRAY_tools as COSMIC
importlib.reload(COSMIC)
COSMIC.set_beamline('ID10')

# RAW FOLDER PATH
raw_folder = '../RAW_DATA/'
masks_folder = '../masks/'
fit_outs_folder = './data/fit_outs/'
Idts_folder = './data/Idts/'

# EXPERIMENTAL VARIABLES
XPCS.set_expvar(1350, 1350, 7)
ID10.Nfmax_dense_file = 2000
ID10.Nfmax_sparse_file = 5000

# %% [markdown]
# ## Load masks

# %%
e4m_htmask = np.load(masks_folder+'e4m_htmask_copper_foil_30um_1_1'+'.npy')
e4m_mask = np.load(masks_folder+'e4m_mask'+'.npy')
#bs_mask = np.load(masks_folder+'bs_mask_copper_foil_30um'+'.npy')  # beam-stop mask

# %%
plt.figure(figsize=(8, 8))
plt.imshow((e4m_mask*e4m_htmask).reshape(Nx,Ny), cmap='gray', origin='lower')

# %% [markdown]
# ### BS mask and Q definition
# Using a random scan in GeO2_6, because we are not changing the measurement configuration

# %% [markdown]
# #### Beamstop mask

# %%
#######################################
sample_name = 'GeO2_6'
Ndataset = 1
Nscan =12
Nfi, Nff = 0, 1000
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
# Out:
# #############################
# command = mtimescan 0.02 1 220000
# Ei = 9.699998837562536
# itime = 0.0201
# theta = 1.7500000000000004
# Q = 0.15
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/1 loops)
# Done!
# Concatenating vectors ...
# Done!
# 	 | Sparse array loaded from ../RAW_DATA/GeO2_6/GeO2_6_0001/scan0012/
# 	 | Shape:       (1000, 4471016)
# 	 | Sparsity:     3.8e-03
# 	 | Memory usage (scipy.csr_array): 0.192 GB (np.array usage: 16.656 GB)

# %%
geom = [{'geom':'Rectangle', 'x0':1250, 'y0':1300, 'xl':250, 'yl':1950, 'inside':False},
        {'geom':'Circle', 'Cx':1300, 'Cy':950, 'r':1470, 'inside':True}, 
        ]
XPCS.gen_plots4mask(e4m_data, itime, Ith_high=1, Nff=10000, mask_geom=geom,)
# Out:
# ################################################################################
# Maximum count in the hull run -> 4689
# # of pixels above Ith_high treshold ->  75 pixels (of 4471016 => 0.0 %)
# ################################################################################

# %%
bs_mask = XPCS.gen_mask(e4m_data, itime, e4m_mask=None, mask_geom=geom)
# Out:
# #################################################
# Masked area =  93.74594052000708 %
# #################################################

# %% [markdown]
# #### Q mask

# %%
Qmask = XPCS.gen_Qmask(Ei, theta, .19, .02, Qmap_plot=True)

# %% [markdown]
# ## XPCS scan (T = 415C Q =  0.19 Å, 50 min @ 1ms (3_000_000 fm)) (GeO2_3, dataset 1, scan 4)

# %%
#######################################
sample_name = 'GeO2_3_415C'
Ndataset = 1
Nscan = 4
Nfi, Nff =  None, None
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
#e4m_data = ID10.load_dense_e4m_new(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )

e4m_data = COSMIC.fast_gamma_filter(e4m_data, Imaxth_high=5)
# Out:
# #############################
# command = mtimescan 0.001 1 2999568
# Ei = 9.699998837562536
# itime = 0.0011
# theta = 1.7500000000000004
# Q = 0.15
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00001.h5 (2/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00002.h5 (3/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00003.h5 (4/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00004.h5 (5/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00005.h5 (6/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00006.h5 (7/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00007.h5 (8/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00008.h5 (9/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00009.h5 (10/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00010.h5 (11/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00011.h5 (12/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00012.h5 (13/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00013.h5 (14/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00014.h5 (15/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00015.h5 (16/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00016.h5 (17/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00017.h5 (18/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00018.h5 (19/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00019.h5 (20/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00020.h5 (21/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00021.h5 (22/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00022.h5 (23/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00023.h5 (24/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00024.h5 (25/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00025.h5 (26/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00026.h5 (27/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00027.h5 (28/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00028.h5 (29/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00029.h5 (30/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00030.h5 (31/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00031.h5 (32/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00032.h5 (33/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00033.h5 (34/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00034.h5 (35/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00035.h5 (36/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00036.h5 (37/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00037.h5 (38/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00038.h5 (39/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00039.h5 (40/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00040.h5 (41/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00041.h5 (42/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00042.h5 (43/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00043.h5 (44/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00044.h5 (45/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00045.h5 (46/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00046.h5 (47/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00047.h5 (48/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00048.h5 (49/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00049.h5 (50/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00050.h5 (51/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00051.h5 (52/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00052.h5 (53/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00053.h5 (54/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00054.h5 (55/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00055.h5 (56/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00056.h5 (57/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00057.h5 (58/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00058.h5 (59/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00059.h5 (60/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00060.h5 (61/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00061.h5 (62/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00062.h5 (63/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00063.h5 (64/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00064.h5 (65/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00065.h5 (66/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00066.h5 (67/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00067.h5 (68/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00068.h5 (69/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00069.h5 (70/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00070.h5 (71/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00071.h5 (72/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00072.h5 (73/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00073.h5 (74/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00074.h5 (75/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00075.h5 (76/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00076.h5 (77/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00077.h5 (78/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00078.h5 (79/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00079.h5 (80/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00080.h5 (81/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00081.h5 (82/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00082.h5 (83/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00083.h5 (84/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00084.h5 (85/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00085.h5 (86/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00086.h5 (87/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00087.h5 (88/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00088.h5 (89/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00089.h5 (90/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00090.h5 (91/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00091.h5 (92/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00092.h5 (93/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00093.h5 (94/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00094.h5 (95/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00095.h5 (96/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00096.h5 (97/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00097.h5 (98/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00098.h5 (99/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00099.h5 (100/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00100.h5 (101/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00101.h5 (102/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00102.h5 (103/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00103.h5 (104/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00104.h5 (105/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00105.h5 (106/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00106.h5 (107/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00107.h5 (108/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00108.h5 (109/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00109.h5 (110/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00110.h5 (111/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00111.h5 (112/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00112.h5 (113/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00113.h5 (114/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00114.h5 (115/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00115.h5 (116/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00116.h5 (117/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00117.h5 (118/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00118.h5 (119/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00119.h5 (120/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00120.h5 (121/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00121.h5 (122/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00122.h5 (123/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00123.h5 (124/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00124.h5 (125/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00125.h5 (126/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00126.h5 (127/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00127.h5 (128/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00128.h5 (129/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00129.h5 (130/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00130.h5 (131/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00131.h5 (132/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00132.h5 (133/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00133.h5 (134/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00134.h5 (135/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00135.h5 (136/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00136.h5 (137/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00137.h5 (138/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00138.h5 (139/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00139.h5 (140/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00140.h5 (141/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00141.h5 (142/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00142.h5 (143/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00143.h5 (144/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00144.h5 (145/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00145.h5 (146/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00146.h5 (147/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00147.h5 (148/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00148.h5 (149/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00149.h5 (150/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00150.h5 (151/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00151.h5 (152/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00152.h5 (153/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00153.h5 (154/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00154.h5 (155/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00155.h5 (156/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00156.h5 (157/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00157.h5 (158/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00158.h5 (159/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00159.h5 (160/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00160.h5 (161/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00161.h5 (162/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00162.h5 (163/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00163.h5 (164/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00164.h5 (165/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00165.h5 (166/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00166.h5 (167/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00167.h5 (168/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00168.h5 (169/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00169.h5 (170/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00170.h5 (171/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00171.h5 (172/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00172.h5 (173/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00173.h5 (174/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00174.h5 (175/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00175.h5 (176/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00176.h5 (177/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00177.h5 (178/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00178.h5 (179/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00179.h5 (180/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00180.h5 (181/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00181.h5 (182/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00182.h5 (183/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00183.h5 (184/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00184.h5 (185/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00185.h5 (186/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00186.h5 (187/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00187.h5 (188/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00188.h5 (189/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00189.h5 (190/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00190.h5 (191/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00191.h5 (192/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00192.h5 (193/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00193.h5 (194/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00194.h5 (195/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00195.h5 (196/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00196.h5 (197/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00197.h5 (198/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00198.h5 (199/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00199.h5 (200/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00200.h5 (201/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00201.h5 (202/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00202.h5 (203/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00203.h5 (204/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00204.h5 (205/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00205.h5 (206/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00206.h5 (207/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00207.h5 (208/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00208.h5 (209/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00209.h5 (210/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00210.h5 (211/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00211.h5 (212/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00212.h5 (213/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00213.h5 (214/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00214.h5 (215/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00215.h5 (216/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00216.h5 (217/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00217.h5 (218/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00218.h5 (219/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00219.h5 (220/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00220.h5 (221/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00221.h5 (222/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00222.h5 (223/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00223.h5 (224/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00224.h5 (225/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00225.h5 (226/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00226.h5 (227/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00227.h5 (228/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00228.h5 (229/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00229.h5 (230/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00230.h5 (231/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00231.h5 (232/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00232.h5 (233/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00233.h5 (234/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00234.h5 (235/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00235.h5 (236/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00236.h5 (237/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00237.h5 (238/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00238.h5 (239/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00239.h5 (240/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00240.h5 (241/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00241.h5 (242/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00242.h5 (243/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00243.h5 (244/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00244.h5 (245/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00245.h5 (246/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00246.h5 (247/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00247.h5 (248/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00248.h5 (249/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00249.h5 (250/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00250.h5 (251/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00251.h5 (252/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00252.h5 (253/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00253.h5 (254/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00254.h5 (255/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00255.h5 (256/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00256.h5 (257/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00257.h5 (258/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00258.h5 (259/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00259.h5 (260/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00260.h5 (261/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00261.h5 (262/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00262.h5 (263/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00263.h5 (264/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00264.h5 (265/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00265.h5 (266/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00266.h5 (267/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00267.h5 (268/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00268.h5 (269/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00269.h5 (270/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00270.h5 (271/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00271.h5 (272/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00272.h5 (273/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00273.h5 (274/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00274.h5 (275/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00275.h5 (276/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00276.h5 (277/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00277.h5 (278/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00278.h5 (279/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00279.h5 (280/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00280.h5 (281/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00281.h5 (282/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00282.h5 (283/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00283.h5 (284/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00284.h5 (285/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00285.h5 (286/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00286.h5 (287/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00287.h5 (288/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00288.h5 (289/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00289.h5 (290/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00290.h5 (291/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00291.h5 (292/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00292.h5 (293/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00293.h5 (294/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00294.h5 (295/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00295.h5 (296/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00296.h5 (297/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00297.h5 (298/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00298.h5 (299/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00299.h5 (300/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00300.h5 (301/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00301.h5 (302/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00302.h5 (303/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00303.h5 (304/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00304.h5 (305/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00305.h5 (306/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00306.h5 (307/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00307.h5 (308/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00308.h5 (309/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00309.h5 (310/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00310.h5 (311/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00311.h5 (312/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00312.h5 (313/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00313.h5 (314/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00314.h5 (315/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00315.h5 (316/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00316.h5 (317/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00317.h5 (318/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00318.h5 (319/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00319.h5 (320/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00320.h5 (321/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00321.h5 (322/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00322.h5 (323/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00323.h5 (324/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00324.h5 (325/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00325.h5 (326/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00326.h5 (327/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00327.h5 (328/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00328.h5 (329/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00329.h5 (330/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00330.h5 (331/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00331.h5 (332/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00332.h5 (333/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00333.h5 (334/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00334.h5 (335/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00335.h5 (336/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00336.h5 (337/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00337.h5 (338/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00338.h5 (339/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00339.h5 (340/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00340.h5 (341/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00341.h5 (342/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00342.h5 (343/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00343.h5 (344/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00344.h5 (345/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00345.h5 (346/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00346.h5 (347/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00347.h5 (348/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00348.h5 (349/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00349.h5 (350/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00350.h5 (351/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00351.h5 (352/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00352.h5 (353/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00353.h5 (354/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00354.h5 (355/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00355.h5 (356/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00356.h5 (357/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00357.h5 (358/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00358.h5 (359/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00359.h5 (360/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00360.h5 (361/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00361.h5 (362/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00362.h5 (363/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00363.h5 (364/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00364.h5 (365/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00365.h5 (366/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00366.h5 (367/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00367.h5 (368/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00368.h5 (369/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00369.h5 (370/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00370.h5 (371/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00371.h5 (372/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00372.h5 (373/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00373.h5 (374/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00374.h5 (375/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00375.h5 (376/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00376.h5 (377/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00377.h5 (378/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00378.h5 (379/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00379.h5 (380/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00380.h5 (381/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00381.h5 (382/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00382.h5 (383/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00383.h5 (384/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00384.h5 (385/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00385.h5 (386/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00386.h5 (387/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00387.h5 (388/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00388.h5 (389/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00389.h5 (390/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00390.h5 (391/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00391.h5 (392/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00392.h5 (393/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00393.h5 (394/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00394.h5 (395/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00395.h5 (396/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00396.h5 (397/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00397.h5 (398/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00398.h5 (399/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00399.h5 (400/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00400.h5 (401/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00401.h5 (402/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00402.h5 (403/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00403.h5 (404/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00404.h5 (405/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00405.h5 (406/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00406.h5 (407/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00407.h5 (408/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00408.h5 (409/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00409.h5 (410/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00410.h5 (411/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00411.h5 (412/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00412.h5 (413/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00413.h5 (414/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00414.h5 (415/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00415.h5 (416/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00416.h5 (417/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00417.h5 (418/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00418.h5 (419/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00419.h5 (420/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00420.h5 (421/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00421.h5 (422/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00422.h5 (423/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00423.h5 (424/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00424.h5 (425/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00425.h5 (426/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00426.h5 (427/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00427.h5 (428/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00428.h5 (429/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00429.h5 (430/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00430.h5 (431/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00431.h5 (432/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00432.h5 (433/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00433.h5 (434/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00434.h5 (435/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00435.h5 (436/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00436.h5 (437/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00437.h5 (438/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00438.h5 (439/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00439.h5 (440/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00440.h5 (441/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00441.h5 (442/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00442.h5 (443/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00443.h5 (444/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00444.h5 (445/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00445.h5 (446/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00446.h5 (447/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00447.h5 (448/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00448.h5 (449/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00449.h5 (450/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00450.h5 (451/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00451.h5 (452/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00452.h5 (453/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00453.h5 (454/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00454.h5 (455/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00455.h5 (456/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00456.h5 (457/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00457.h5 (458/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00458.h5 (459/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00459.h5 (460/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00460.h5 (461/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00461.h5 (462/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00462.h5 (463/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00463.h5 (464/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00464.h5 (465/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00465.h5 (466/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00466.h5 (467/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00467.h5 (468/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00468.h5 (469/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00469.h5 (470/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00470.h5 (471/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00471.h5 (472/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00472.h5 (473/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00473.h5 (474/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00474.h5 (475/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00475.h5 (476/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00476.h5 (477/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00477.h5 (478/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00478.h5 (479/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00479.h5 (480/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00480.h5 (481/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00481.h5 (482/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00482.h5 (483/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00483.h5 (484/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00484.h5 (485/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00485.h5 (486/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00486.h5 (487/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00487.h5 (488/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00488.h5 (489/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00489.h5 (490/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00490.h5 (491/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00491.h5 (492/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00492.h5 (493/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00493.h5 (494/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00494.h5 (495/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00495.h5 (496/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00496.h5 (497/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00497.h5 (498/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00498.h5 (499/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00499.h5 (500/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00500.h5 (501/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00501.h5 (502/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00502.h5 (503/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00503.h5 (504/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00504.h5 (505/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00505.h5 (506/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00506.h5 (507/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00507.h5 (508/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00508.h5 (509/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00509.h5 (510/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00510.h5 (511/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00511.h5 (512/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00512.h5 (513/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00513.h5 (514/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00514.h5 (515/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00515.h5 (516/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00516.h5 (517/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00517.h5 (518/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00518.h5 (519/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00519.h5 (520/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00520.h5 (521/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00521.h5 (522/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00522.h5 (523/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00523.h5 (524/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00524.h5 (525/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00525.h5 (526/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00526.h5 (527/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00527.h5 (528/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00528.h5 (529/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00529.h5 (530/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00530.h5 (531/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00531.h5 (532/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00532.h5 (533/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00533.h5 (534/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00534.h5 (535/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00535.h5 (536/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00536.h5 (537/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00537.h5 (538/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00538.h5 (539/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00539.h5 (540/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00540.h5 (541/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00541.h5 (542/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00542.h5 (543/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00543.h5 (544/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00544.h5 (545/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00545.h5 (546/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00546.h5 (547/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00547.h5 (548/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00548.h5 (549/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00549.h5 (550/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00550.h5 (551/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00551.h5 (552/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00552.h5 (553/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00553.h5 (554/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00554.h5 (555/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00555.h5 (556/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00556.h5 (557/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00557.h5 (558/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00558.h5 (559/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00559.h5 (560/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00560.h5 (561/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00561.h5 (562/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00562.h5 (563/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00563.h5 (564/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00564.h5 (565/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00565.h5 (566/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00566.h5 (567/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00567.h5 (568/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00568.h5 (569/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00569.h5 (570/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00570.h5 (571/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00571.h5 (572/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00572.h5 (573/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00573.h5 (574/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00574.h5 (575/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00575.h5 (576/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00576.h5 (577/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00577.h5 (578/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00578.h5 (579/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00579.h5 (580/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00580.h5 (581/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00581.h5 (582/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00582.h5 (583/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00583.h5 (584/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00584.h5 (585/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00585.h5 (586/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00586.h5 (587/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00587.h5 (588/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00588.h5 (589/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00589.h5 (590/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00590.h5 (591/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00591.h5 (592/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00592.h5 (593/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00593.h5 (594/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00594.h5 (595/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00595.h5 (596/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00596.h5 (597/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00597.h5 (598/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00598.h5 (599/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00599.h5 (600/600 loops)
# Done!
# Concatenating vectors ...
# Done!
# 	 | Sparse array loaded from ../RAW_DATA/GeO2_3_415C/GeO2_3_415C_0001/scan0004/
# 	 | Shape:       (2999568, 4471016)
# 	 | Sparsity:     1.8e-04
# 	 | Memory usage (scipy.csr_array): 19.726 GB (np.array usage: 49960.302 GB)
# Filtering gamma ray signal (i.e. signals over treshold) ...
# Done! (elapsed time = 7.25 s)
# Removing gamma ray signal (set 0s) ...
# Done! (elapsed time = 10.48 s)

# %% [markdown]
# ### Flux check

# %%
#############################################
mask = e4m_mask * e4m_htmask * bs_mask
#############################################

XPCS.gen_plots4mask(e4m_data, itime, Ith_high= .4, Nff=100_000, e4m_mask=mask)
# Out:
# ################################################################################
# Maximum count in the hull run -> 5
# # of pixels above Ith_high treshold ->  9 pixels (of 4471016 => 0.0 %)
# ################################################################################

# %% [markdown]
# ### Intensity analysis

# %%
####################
Lbin = 1
Nstep = 100
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
####################

t_It, It = XPCS.get_It(e4m_data, itime, mask=mask, Lbin=Lbin, Nstep=Nstep)
np.savez(Idts_folder+'Idt_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4), t_It=t_It, It=It)

# %%
plt.figure(figsize=(10,5))
plt.scatter(t_It, It, label='It')

plt.xlabel('Time (s)')
plt.ylabel('Integrated intensity [photons/pixel/s]')
plt.xscale('log')
#plt.xlim(1e-2, 1)
plt.gca().secondary_xaxis('top', functions=(lambda x: x/itime, lambda x: x*itime))
plt.grid()

# %% [markdown]
# ### Correlation

# %%
###################
Nfi = 1
Nff = None
Lbin = 10
Nbunch = 30
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
###################
if Nfi == None: Nfi = 0
if Nff == None: Nff = e4m_data.shape[0]
if Lbin == None: Lbin = 1


Lbunch = (Nff-Nfi)//Nbunch

t, g2, t_mt, g2_mt = {}, {}, {}, {}

for i in range(Nbunch):
    
    print('Computing G2t for bunch', i+1, '(Nfi =', Nfi+i*Lbunch, ', Nff =', Nfi+(i+1)*Lbunch, ') ...')
    G2t = XPCS.get_G2t(e4m_data, mask, Nfi=Nfi+i*Lbunch, Nff=Nfi+(i+1)*Lbunch, Lbin=Lbin)

    t_bunch = round(itime*Lbunch*Nbunch*(i+1/2),1)

    t[t_bunch], g2[t_bunch] = XPCS.get_g2(itime*Lbin, G2t, cython=False)
    t_mt[t_bunch], g2_mt[t_bunch] = XPCS.get_g2_mt(itime*Lbin, g2[t_bunch])
# Out:
# Computing G2t for bunch 1 (Nfi = 1 , Nff = 99986 ) ...
# Loading frames ...
# Done! (elapsed time = 0.83 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.81 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.858 GB
# Masking data ...
# Done! (elapsed time = 1.12 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.85e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.294 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.5 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.39 s)
#
# Computing g2...
# Done! (elapsed time = 0.41 s)
#
# Computing G2t for bunch 2 (Nfi = 99986 , Nff = 199971 ) ...
# Loading frames ...
# Done! (elapsed time = 0.53 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.61 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.71e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.853 GB
# Masking data ...
# Done! (elapsed time = 1.04 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.84e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.293 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.5 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.39 s)
#
# Computing g2...
# Done! (elapsed time = 0.41 s)
#
# Computing G2t for bunch 3 (Nfi = 199971 , Nff = 299956 ) ...
# Loading frames ...
# Done! (elapsed time = 0.51 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.51 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.70e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.852 GB
# Masking data ...
# Done! (elapsed time = 0.97 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.84e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.293 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.38 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.4 s)
#
# Computing g2...
# Done! (elapsed time = 0.41 s)
#
# Computing G2t for bunch 4 (Nfi = 299956 , Nff = 399941 ) ...
# Loading frames ...
# Done! (elapsed time = 0.52 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.54 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.70e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.85 GB
# Masking data ...
# Done! (elapsed time = 1.04 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.84e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.292 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.59 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.42 s)
#
# Computing g2...
# Done! (elapsed time = 0.62 s)
#
# Computing G2t for bunch 5 (Nfi = 399941 , Nff = 499926 ) ...
# Loading frames ...
# Done! (elapsed time = 0.55 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.6 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.864 GB
# Masking data ...
# Done! (elapsed time = 1.06 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.87e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.297 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.56 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.41 s)
#
# Computing g2...
# Done! (elapsed time = 0.4 s)
#
# Computing G2t for bunch 6 (Nfi = 499926 , Nff = 599911 ) ...
# Loading frames ...
# Done! (elapsed time = 0.54 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.63 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.77e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.882 GB
# Masking data ...
# Done! (elapsed time = 1.09 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.90e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.303 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.57 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.44 s)
#
# Computing g2...
# Done! (elapsed time = 0.4 s)
#
# Computing G2t for bunch 7 (Nfi = 599911 , Nff = 699896 ) ...
# Loading frames ...
# Done! (elapsed time = 0.53 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.62 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.76e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.881 GB
# Masking data ...
# Done! (elapsed time = 1.03 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.90e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.303 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.6 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.45 s)
#
# Computing g2...
# Done! (elapsed time = 0.4 s)
#
# Computing G2t for bunch 8 (Nfi = 699896 , Nff = 799881 ) ...
# Loading frames ...
# Done! (elapsed time = 0.54 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.73 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.76e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.88 GB
# Masking data ...
# Done! (elapsed time = 1.52 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.90e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.303 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.5 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.44 s)
#
# Computing g2...
# Done! (elapsed time = 0.4 s)
#
# Computing G2t for bunch 9 (Nfi = 799881 , Nff = 899866 ) ...
# Loading frames ...
# Done! (elapsed time = 0.55 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.79 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.76e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.879 GB
# Masking data ...
# Done! (elapsed time = 2.02 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.90e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.302 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.47 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.47 s)
#
# Computing g2...
# Done! (elapsed time = 0.66 s)
#
# Computing G2t for bunch 10 (Nfi = 899866 , Nff = 999851 ) ...
# Loading frames ...
# Done! (elapsed time = 0.91 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 2.59 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.76e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.877 GB
# Masking data ...
# Done! (elapsed time = 2.28 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.89e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.302 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.66 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.45 s)
#
# Computing g2...
# Done! (elapsed time = 0.52 s)
#
# Computing G2t for bunch 11 (Nfi = 999851 , Nff = 1099836 ) ...
# Loading frames ...
# Done! (elapsed time = 0.62 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 2.24 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.876 GB
# Masking data ...
# Done! (elapsed time = 1.89 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.89e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.301 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.77 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.41 s)
#
# Computing g2...
# Done! (elapsed time = 0.77 s)
#
# Computing G2t for bunch 12 (Nfi = 1099836 , Nff = 1199821 ) ...
# Loading frames ...
# Done! (elapsed time = 1.06 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 2.15 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.876 GB
# Masking data ...
# Done! (elapsed time = 1.51 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.89e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.301 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.8 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.37 s)
#
# Computing g2...
# Done! (elapsed time = 0.42 s)
#
# Computing G2t for bunch 13 (Nfi = 1199821 , Nff = 1299806 ) ...
# Loading frames ...
# Done! (elapsed time = 0.55 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.75 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.875 GB
# Masking data ...
# Done! (elapsed time = 1.15 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.89e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.301 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.65 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.42 s)
#
# Computing g2...
# Done! (elapsed time = 0.41 s)
#
# Computing G2t for bunch 14 (Nfi = 1299806 , Nff = 1399791 ) ...
# Loading frames ...
# Done! (elapsed time = 0.54 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.65 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.874 GB
# Masking data ...
# Done! (elapsed time = 1.03 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.89e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.3 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.5 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.43 s)
#
# Computing g2...
# Done! (elapsed time = 0.42 s)
#
# Computing G2t for bunch 15 (Nfi = 1399791 , Nff = 1499776 ) ...
# Loading frames ...
# Done! (elapsed time = 0.54 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.97 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.874 GB
# Masking data ...
# Done! (elapsed time = 1.81 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.89e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.3 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.67 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.44 s)
#
# Computing g2...
# Done! (elapsed time = 0.45 s)
#
# Computing G2t for bunch 16 (Nfi = 1499776 , Nff = 1599761 ) ...
# Loading frames ...
# Done! (elapsed time = 0.54 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.64 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.874 GB
# Masking data ...
# Done! (elapsed time = 1.01 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.88e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.3 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.39 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.4 s)
#
# Computing g2...
# Done! (elapsed time = 0.4 s)
#
# Computing G2t for bunch 17 (Nfi = 1599761 , Nff = 1699746 ) ...
# Loading frames ...
# Done! (elapsed time = 0.54 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.64 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.874 GB
# Masking data ...
# Done! (elapsed time = 1.0 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.88e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.3 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.53 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.47 s)
#
# Computing g2...
# Done! (elapsed time = 0.4 s)
#
# Computing G2t for bunch 18 (Nfi = 1699746 , Nff = 1799731 ) ...
# Loading frames ...
# Done! (elapsed time = 0.54 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.61 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.873 GB
# Masking data ...
# Done! (elapsed time = 1.0 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.88e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.3 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.63 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.48 s)
#
# Computing g2...
# Done! (elapsed time = 0.66 s)
#
# Computing G2t for bunch 19 (Nfi = 1799731 , Nff = 1899716 ) ...
# Loading frames ...
# Done! (elapsed time = 0.89 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 2.33 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.873 GB
# Masking data ...
# Done! (elapsed time = 2.0 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.88e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.299 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.51 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.48 s)
#
# Computing g2...
# Done! (elapsed time = 0.47 s)
#
# Computing G2t for bunch 20 (Nfi = 1899716 , Nff = 1999701 ) ...
# Loading frames ...
# Done! (elapsed time = 0.61 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 2.12 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.873 GB
# Masking data ...
# Done! (elapsed time = 1.91 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.88e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.299 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.72 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.48 s)
#
# Computing g2...
# Done! (elapsed time = 0.44 s)
#
# Computing G2t for bunch 21 (Nfi = 1999701 , Nff = 2099686 ) ...
# Loading frames ...
# Done! (elapsed time = 0.61 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 2.31 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.872 GB
# Masking data ...
# Done! (elapsed time = 1.6 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.88e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.299 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.59 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.45 s)
#
# Computing g2...
# Done! (elapsed time = 0.66 s)
#
# Computing G2t for bunch 22 (Nfi = 2099686 , Nff = 2199671 ) ...
# Loading frames ...
# Done! (elapsed time = 0.78 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 2.31 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.74e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.872 GB
# Masking data ...
# Done! (elapsed time = 1.66 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.88e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.299 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.64 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.41 s)
#
# Computing g2...
# Done! (elapsed time = 0.43 s)
#
# Computing G2t for bunch 23 (Nfi = 2199671 , Nff = 2299656 ) ...
# Loading frames ...
# Done! (elapsed time = 0.65 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 2.29 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.74e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.871 GB
# Masking data ...
# Done! (elapsed time = 1.77 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.87e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.298 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.58 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.45 s)
#
# Computing g2...
# Done! (elapsed time = 0.43 s)
#
# Computing G2t for bunch 24 (Nfi = 2299656 , Nff = 2399641 ) ...
# Loading frames ...
# Done! (elapsed time = 0.61 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 2.31 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.74e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.87 GB
# Masking data ...
# Done! (elapsed time = 1.52 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.87e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.298 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.66 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.44 s)
#
# Computing g2...
# Done! (elapsed time = 0.66 s)
#
# Computing G2t for bunch 25 (Nfi = 2399641 , Nff = 2499626 ) ...
# Loading frames ...
# Done! (elapsed time = 0.65 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.93 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.74e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.869 GB
# Masking data ...
# Done! (elapsed time = 1.3 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.87e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.297 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.45 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.43 s)
#
# Computing g2...
# Done! (elapsed time = 0.65 s)
#
# Computing G2t for bunch 26 (Nfi = 2499626 , Nff = 2599611 ) ...
# Loading frames ...
# Done! (elapsed time = 0.9 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.77 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.74e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.868 GB
# Masking data ...
# Done! (elapsed time = 1.01 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.87e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.297 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.54 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.41 s)
#
# Computing g2...
# Done! (elapsed time = 0.65 s)
#
# Computing G2t for bunch 27 (Nfi = 2599611 , Nff = 2699596 ) ...
# Loading frames ...
# Done! (elapsed time = 0.85 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.85 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.74e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.867 GB
# Masking data ...
# Done! (elapsed time = 1.32 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.86e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.297 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.68 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.39 s)
#
# Computing g2...
# Done! (elapsed time = 0.41 s)
#
# Computing G2t for bunch 28 (Nfi = 2699596 , Nff = 2799581 ) ...
# Loading frames ...
# Done! (elapsed time = 0.7 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 2.2 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.866 GB
# Masking data ...
# Done! (elapsed time = 0.96 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.86e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.296 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.5 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.41 s)
#
# Computing g2...
# Done! (elapsed time = 0.41 s)
#
# Computing G2t for bunch 29 (Nfi = 2799581 , Nff = 2899566 ) ...
# Loading frames ...
# Done! (elapsed time = 0.58 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.62 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.865 GB
# Masking data ...
# Done! (elapsed time = 0.66 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.86e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.296 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.43 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.41 s)
#
# Computing g2...
# Done! (elapsed time = 0.4 s)
#
# Computing G2t for bunch 30 (Nfi = 2899566 , Nff = 2999551 ) ...
# Loading frames ...
# Done! (elapsed time = 0.56 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.6 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.864 GB
# Masking data ...
# Done! (elapsed time = 0.66 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.85e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.295 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.62 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.37 s)
#
# Computing g2...
# Done! (elapsed time = 0.42 s)

# %%
##################
t1_fit = 0
t2_fit = 1e8
##################
 
plt.figure(figsize=(10,5))
fit_out = pd.DataFrame(columns=['tau', 'beta', 'c', 'y0', 'dtau', 'dbeta', 'dc', 'dy0'])
fit_out.index.name = 't'
for k in g2.keys():
    #plt.scatter(t[k], g2[k], s=1, label = str(k)+'s')
    plt.scatter(t_mt[k], g2_mt[k], label=str(k)+'s')

    popt, pcov = curve_fit(decorelation_f, t[k][(t1_fit<t[k])*(t[k]<t2_fit)], g2[k][(t1_fit<t[k])*(t[k]<t2_fit)], p0=[3, .7, .02, 1], bounds=([0, 0, 0, 0], [np.inf, np.inf, np.inf, np.inf]))
    fit_out.loc[k] = [popt[0], popt[1], popt[2], popt[3], np.sqrt(pcov[0,0]), np.sqrt(pcov[1,1]), np.sqrt(pcov[2,2]), np.sqrt(pcov[3,3])]
    
    x = np.arange(np.min(t[k]), np.max(t[k]), 1e-2)
    y = decorelation_f(x, *popt)
    plt.plot(x, y,)

plt.xlabel('t [s]')
plt.ylabel('g2')
plt.xscale('log')
plt.legend()
plt.show()



plt.figure(figsize=(10,5))
plt.title('tau')
plt.errorbar(fit_out.index, fit_out.tau,  yerr=fit_out.dtau, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('tau [s]')
plt.show()

plt.figure(figsize=(10,5))
plt.title('beta')
plt.errorbar(fit_out.index, fit_out.beta,  yerr=fit_out.dbeta, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('beta')
plt.show()

plt.figure(figsize=(10,5))
plt.title('c')
plt.errorbar(fit_out.index, fit_out.c,  yerr=fit_out.dc, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('c')
plt.show()

plt.figure(figsize=(10,5))
plt.title('y0')
plt.errorbar(fit_out.index, fit_out.y0,  yerr=fit_out.dy0, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('y0')
plt.show()

# %% [markdown]
# ## XPCS scan (T = 450C Q =  0.19 Å, 50 min @ 1ms (3_000_000 fm)) (GeO2_3, dataset 1, scan 4)

# %%
#######################################
sample_name = 'GeO2_3_450C'
Ndataset = 1
Nscan = 4
Nfi, Nff =  None, None
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
#e4m_data = ID10.load_dense_e4m_new(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )

e4m_data = COSMIC.fast_gamma_filter(e4m_data, Imaxth_high=5)
# Out:
# #############################
# command = mtimescan 0.001 1 2999568
# Ei = 9.699998837562536
# itime = 0.0011
# theta = 1.7500000000000004
# Q = 0.15
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00001.h5 (2/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00002.h5 (3/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00003.h5 (4/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00004.h5 (5/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00005.h5 (6/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00006.h5 (7/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00007.h5 (8/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00008.h5 (9/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00009.h5 (10/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00010.h5 (11/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00011.h5 (12/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00012.h5 (13/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00013.h5 (14/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00014.h5 (15/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00015.h5 (16/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00016.h5 (17/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00017.h5 (18/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00018.h5 (19/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00019.h5 (20/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00020.h5 (21/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00021.h5 (22/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00022.h5 (23/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00023.h5 (24/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00024.h5 (25/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00025.h5 (26/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00026.h5 (27/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00027.h5 (28/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00028.h5 (29/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00029.h5 (30/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00030.h5 (31/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00031.h5 (32/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00032.h5 (33/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00033.h5 (34/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00034.h5 (35/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00035.h5 (36/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00036.h5 (37/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00037.h5 (38/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00038.h5 (39/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00039.h5 (40/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00040.h5 (41/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00041.h5 (42/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00042.h5 (43/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00043.h5 (44/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00044.h5 (45/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00045.h5 (46/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00046.h5 (47/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00047.h5 (48/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00048.h5 (49/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00049.h5 (50/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00050.h5 (51/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00051.h5 (52/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00052.h5 (53/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00053.h5 (54/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00054.h5 (55/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00055.h5 (56/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00056.h5 (57/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00057.h5 (58/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00058.h5 (59/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00059.h5 (60/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00060.h5 (61/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00061.h5 (62/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00062.h5 (63/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00063.h5 (64/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00064.h5 (65/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00065.h5 (66/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00066.h5 (67/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00067.h5 (68/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00068.h5 (69/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00069.h5 (70/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00070.h5 (71/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00071.h5 (72/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00072.h5 (73/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00073.h5 (74/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00074.h5 (75/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00075.h5 (76/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00076.h5 (77/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00077.h5 (78/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00078.h5 (79/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00079.h5 (80/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00080.h5 (81/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00081.h5 (82/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00082.h5 (83/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00083.h5 (84/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00084.h5 (85/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00085.h5 (86/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00086.h5 (87/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00087.h5 (88/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00088.h5 (89/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00089.h5 (90/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00090.h5 (91/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00091.h5 (92/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00092.h5 (93/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00093.h5 (94/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00094.h5 (95/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00095.h5 (96/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00096.h5 (97/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00097.h5 (98/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00098.h5 (99/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00099.h5 (100/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00100.h5 (101/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00101.h5 (102/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00102.h5 (103/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00103.h5 (104/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00104.h5 (105/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00105.h5 (106/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00106.h5 (107/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00107.h5 (108/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00108.h5 (109/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00109.h5 (110/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00110.h5 (111/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00111.h5 (112/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00112.h5 (113/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00113.h5 (114/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00114.h5 (115/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00115.h5 (116/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00116.h5 (117/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00117.h5 (118/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00118.h5 (119/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00119.h5 (120/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00120.h5 (121/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00121.h5 (122/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00122.h5 (123/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00123.h5 (124/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00124.h5 (125/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00125.h5 (126/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00126.h5 (127/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00127.h5 (128/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00128.h5 (129/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00129.h5 (130/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00130.h5 (131/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00131.h5 (132/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00132.h5 (133/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00133.h5 (134/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00134.h5 (135/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00135.h5 (136/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00136.h5 (137/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00137.h5 (138/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00138.h5 (139/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00139.h5 (140/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00140.h5 (141/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00141.h5 (142/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00142.h5 (143/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00143.h5 (144/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00144.h5 (145/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00145.h5 (146/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00146.h5 (147/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00147.h5 (148/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00148.h5 (149/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00149.h5 (150/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00150.h5 (151/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00151.h5 (152/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00152.h5 (153/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00153.h5 (154/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00154.h5 (155/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00155.h5 (156/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00156.h5 (157/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00157.h5 (158/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00158.h5 (159/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00159.h5 (160/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00160.h5 (161/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00161.h5 (162/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00162.h5 (163/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00163.h5 (164/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00164.h5 (165/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00165.h5 (166/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00166.h5 (167/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00167.h5 (168/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00168.h5 (169/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00169.h5 (170/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00170.h5 (171/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00171.h5 (172/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00172.h5 (173/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00173.h5 (174/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00174.h5 (175/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00175.h5 (176/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00176.h5 (177/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00177.h5 (178/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00178.h5 (179/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00179.h5 (180/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00180.h5 (181/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00181.h5 (182/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00182.h5 (183/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00183.h5 (184/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00184.h5 (185/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00185.h5 (186/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00186.h5 (187/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00187.h5 (188/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00188.h5 (189/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00189.h5 (190/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00190.h5 (191/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00191.h5 (192/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00192.h5 (193/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00193.h5 (194/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00194.h5 (195/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00195.h5 (196/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00196.h5 (197/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00197.h5 (198/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00198.h5 (199/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00199.h5 (200/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00200.h5 (201/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00201.h5 (202/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00202.h5 (203/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00203.h5 (204/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00204.h5 (205/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00205.h5 (206/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00206.h5 (207/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00207.h5 (208/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00208.h5 (209/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00209.h5 (210/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00210.h5 (211/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00211.h5 (212/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00212.h5 (213/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00213.h5 (214/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00214.h5 (215/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00215.h5 (216/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00216.h5 (217/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00217.h5 (218/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00218.h5 (219/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00219.h5 (220/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00220.h5 (221/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00221.h5 (222/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00222.h5 (223/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00223.h5 (224/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00224.h5 (225/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00225.h5 (226/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00226.h5 (227/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00227.h5 (228/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00228.h5 (229/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00229.h5 (230/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00230.h5 (231/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00231.h5 (232/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00232.h5 (233/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00233.h5 (234/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00234.h5 (235/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00235.h5 (236/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00236.h5 (237/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00237.h5 (238/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00238.h5 (239/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00239.h5 (240/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00240.h5 (241/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00241.h5 (242/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00242.h5 (243/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00243.h5 (244/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00244.h5 (245/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00245.h5 (246/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00246.h5 (247/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00247.h5 (248/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00248.h5 (249/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00249.h5 (250/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00250.h5 (251/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00251.h5 (252/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00252.h5 (253/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00253.h5 (254/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00254.h5 (255/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00255.h5 (256/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00256.h5 (257/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00257.h5 (258/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00258.h5 (259/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00259.h5 (260/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00260.h5 (261/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00261.h5 (262/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00262.h5 (263/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00263.h5 (264/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00264.h5 (265/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00265.h5 (266/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00266.h5 (267/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00267.h5 (268/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00268.h5 (269/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00269.h5 (270/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00270.h5 (271/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00271.h5 (272/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00272.h5 (273/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00273.h5 (274/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00274.h5 (275/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00275.h5 (276/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00276.h5 (277/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00277.h5 (278/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00278.h5 (279/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00279.h5 (280/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00280.h5 (281/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00281.h5 (282/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00282.h5 (283/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00283.h5 (284/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00284.h5 (285/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00285.h5 (286/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00286.h5 (287/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00287.h5 (288/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00288.h5 (289/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00289.h5 (290/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00290.h5 (291/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00291.h5 (292/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00292.h5 (293/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00293.h5 (294/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00294.h5 (295/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00295.h5 (296/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00296.h5 (297/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00297.h5 (298/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00298.h5 (299/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00299.h5 (300/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00300.h5 (301/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00301.h5 (302/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00302.h5 (303/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00303.h5 (304/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00304.h5 (305/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00305.h5 (306/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00306.h5 (307/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00307.h5 (308/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00308.h5 (309/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00309.h5 (310/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00310.h5 (311/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00311.h5 (312/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00312.h5 (313/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00313.h5 (314/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00314.h5 (315/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00315.h5 (316/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00316.h5 (317/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00317.h5 (318/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00318.h5 (319/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00319.h5 (320/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00320.h5 (321/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00321.h5 (322/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00322.h5 (323/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00323.h5 (324/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00324.h5 (325/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00325.h5 (326/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00326.h5 (327/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00327.h5 (328/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00328.h5 (329/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00329.h5 (330/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00330.h5 (331/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00331.h5 (332/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00332.h5 (333/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00333.h5 (334/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00334.h5 (335/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00335.h5 (336/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00336.h5 (337/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00337.h5 (338/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00338.h5 (339/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00339.h5 (340/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00340.h5 (341/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00341.h5 (342/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00342.h5 (343/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00343.h5 (344/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00344.h5 (345/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00345.h5 (346/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00346.h5 (347/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00347.h5 (348/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00348.h5 (349/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00349.h5 (350/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00350.h5 (351/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00351.h5 (352/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00352.h5 (353/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00353.h5 (354/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00354.h5 (355/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00355.h5 (356/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00356.h5 (357/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00357.h5 (358/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00358.h5 (359/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00359.h5 (360/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00360.h5 (361/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00361.h5 (362/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00362.h5 (363/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00363.h5 (364/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00364.h5 (365/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00365.h5 (366/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00366.h5 (367/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00367.h5 (368/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00368.h5 (369/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00369.h5 (370/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00370.h5 (371/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00371.h5 (372/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00372.h5 (373/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00373.h5 (374/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00374.h5 (375/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00375.h5 (376/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00376.h5 (377/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00377.h5 (378/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00378.h5 (379/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00379.h5 (380/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00380.h5 (381/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00381.h5 (382/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00382.h5 (383/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00383.h5 (384/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00384.h5 (385/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00385.h5 (386/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00386.h5 (387/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00387.h5 (388/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00388.h5 (389/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00389.h5 (390/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00390.h5 (391/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00391.h5 (392/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00392.h5 (393/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00393.h5 (394/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00394.h5 (395/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00395.h5 (396/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00396.h5 (397/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00397.h5 (398/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00398.h5 (399/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00399.h5 (400/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00400.h5 (401/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00401.h5 (402/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00402.h5 (403/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00403.h5 (404/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00404.h5 (405/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00405.h5 (406/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00406.h5 (407/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00407.h5 (408/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00408.h5 (409/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00409.h5 (410/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00410.h5 (411/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00411.h5 (412/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00412.h5 (413/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00413.h5 (414/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00414.h5 (415/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00415.h5 (416/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00416.h5 (417/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00417.h5 (418/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00418.h5 (419/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00419.h5 (420/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00420.h5 (421/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00421.h5 (422/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00422.h5 (423/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00423.h5 (424/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00424.h5 (425/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00425.h5 (426/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00426.h5 (427/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00427.h5 (428/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00428.h5 (429/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00429.h5 (430/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00430.h5 (431/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00431.h5 (432/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00432.h5 (433/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00433.h5 (434/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00434.h5 (435/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00435.h5 (436/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00436.h5 (437/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00437.h5 (438/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00438.h5 (439/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00439.h5 (440/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00440.h5 (441/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00441.h5 (442/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00442.h5 (443/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00443.h5 (444/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00444.h5 (445/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00445.h5 (446/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00446.h5 (447/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00447.h5 (448/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00448.h5 (449/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00449.h5 (450/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00450.h5 (451/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00451.h5 (452/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00452.h5 (453/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00453.h5 (454/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00454.h5 (455/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00455.h5 (456/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00456.h5 (457/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00457.h5 (458/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00458.h5 (459/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00459.h5 (460/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00460.h5 (461/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00461.h5 (462/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00462.h5 (463/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00463.h5 (464/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00464.h5 (465/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00465.h5 (466/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00466.h5 (467/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00467.h5 (468/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00468.h5 (469/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00469.h5 (470/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00470.h5 (471/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00471.h5 (472/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00472.h5 (473/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00473.h5 (474/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00474.h5 (475/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00475.h5 (476/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00476.h5 (477/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00477.h5 (478/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00478.h5 (479/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00479.h5 (480/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00480.h5 (481/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00481.h5 (482/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00482.h5 (483/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00483.h5 (484/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00484.h5 (485/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00485.h5 (486/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00486.h5 (487/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00487.h5 (488/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00488.h5 (489/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00489.h5 (490/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00490.h5 (491/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00491.h5 (492/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00492.h5 (493/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00493.h5 (494/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00494.h5 (495/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00495.h5 (496/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00496.h5 (497/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00497.h5 (498/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00498.h5 (499/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00499.h5 (500/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00500.h5 (501/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00501.h5 (502/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00502.h5 (503/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00503.h5 (504/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00504.h5 (505/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00505.h5 (506/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00506.h5 (507/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00507.h5 (508/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00508.h5 (509/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00509.h5 (510/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00510.h5 (511/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00511.h5 (512/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00512.h5 (513/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00513.h5 (514/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00514.h5 (515/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00515.h5 (516/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00516.h5 (517/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00517.h5 (518/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00518.h5 (519/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00519.h5 (520/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00520.h5 (521/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00521.h5 (522/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00522.h5 (523/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00523.h5 (524/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00524.h5 (525/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00525.h5 (526/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00526.h5 (527/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00527.h5 (528/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00528.h5 (529/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00529.h5 (530/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00530.h5 (531/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00531.h5 (532/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00532.h5 (533/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00533.h5 (534/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00534.h5 (535/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00535.h5 (536/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00536.h5 (537/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00537.h5 (538/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00538.h5 (539/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00539.h5 (540/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00540.h5 (541/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00541.h5 (542/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00542.h5 (543/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00543.h5 (544/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00544.h5 (545/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00545.h5 (546/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00546.h5 (547/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00547.h5 (548/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00548.h5 (549/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00549.h5 (550/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00550.h5 (551/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00551.h5 (552/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00552.h5 (553/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00553.h5 (554/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00554.h5 (555/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00555.h5 (556/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00556.h5 (557/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00557.h5 (558/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00558.h5 (559/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00559.h5 (560/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00560.h5 (561/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00561.h5 (562/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00562.h5 (563/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00563.h5 (564/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00564.h5 (565/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00565.h5 (566/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00566.h5 (567/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00567.h5 (568/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00568.h5 (569/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00569.h5 (570/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00570.h5 (571/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00571.h5 (572/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00572.h5 (573/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00573.h5 (574/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00574.h5 (575/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00575.h5 (576/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00576.h5 (577/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00577.h5 (578/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00578.h5 (579/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00579.h5 (580/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00580.h5 (581/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00581.h5 (582/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00582.h5 (583/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00583.h5 (584/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00584.h5 (585/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00585.h5 (586/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00586.h5 (587/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00587.h5 (588/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00588.h5 (589/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00589.h5 (590/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00590.h5 (591/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00591.h5 (592/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00592.h5 (593/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00593.h5 (594/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00594.h5 (595/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00595.h5 (596/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00596.h5 (597/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00597.h5 (598/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00598.h5 (599/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00599.h5 (600/600 loops)
# Done!
# Concatenating vectors ...
# Done!
# 	 | Sparse array loaded from ../RAW_DATA/GeO2_3_450C/GeO2_3_450C_0001/scan0004/
# 	 | Shape:       (2999568, 4471016)
# 	 | Sparsity:     1.7e-04
# 	 | Memory usage (scipy.csr_array): 19.596 GB (np.array usage: 49960.302 GB)
# Filtering gamma ray signal (i.e. signals over treshold) ...
# Done! (elapsed time = 7.23 s)
# Removing gamma ray signal (set 0s) ...
# Done! (elapsed time = 11.97 s)

# %% [markdown]
# ### Flux check

# %%
#############################################
mask = e4m_mask * e4m_htmask * bs_mask
#############################################

XPCS.gen_plots4mask(e4m_data, itime, Ith_high= .4, Nff=100_000, e4m_mask=mask)
# Out:
# ################################################################################
# Maximum count in the hull run -> 5
# # of pixels above Ith_high treshold ->  22 pixels (of 4471016 => 0.0 %)
# ################################################################################

# %% [markdown]
# ### Intensity analysis

# %%
####################
Lbin = 1
Nstep = 100
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
####################

t_It, It = XPCS.get_It(e4m_data, itime, mask=mask, Lbin=Lbin, Nstep=Nstep)
np.savez(Idts_folder+'Idt_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4), t_It=t_It, It=It)

# %%
plt.figure(figsize=(10,5))
plt.scatter(t_It, It, label='It')

plt.xlabel('Time (s)')
plt.ylabel('Integrated intensity [photons/pixel/s]')
plt.xscale('log')
#plt.xlim(1e-2, 1)
plt.gca().secondary_xaxis('top', functions=(lambda x: x/itime, lambda x: x*itime))
plt.grid()

# %% [markdown]
# ### Correlation

# %%
###################
Nfi = 1
Nff = None
Lbin = 10
Nbunch = 30
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
###################
if Nfi == None: Nfi = 0
if Nff == None: Nff = e4m_data.shape[0]
if Lbin == None: Lbin = 1


Lbunch = (Nff-Nfi)//Nbunch

t, g2, t_mt, g2_mt = {}, {}, {}, {}

for i in range(Nbunch):
    
    print('Computing G2t for bunch', i+1, '(Nfi =', Nfi+i*Lbunch, ', Nff =', Nfi+(i+1)*Lbunch, ') ...')
    G2t = XPCS.get_G2t(e4m_data, mask, Nfi=Nfi+i*Lbunch, Nff=Nfi+(i+1)*Lbunch, Lbin=Lbin)

    t_bunch = round(itime*Lbunch*Nbunch*(i+1/2),1)

    t[t_bunch], g2[t_bunch] = XPCS.get_g2(itime*Lbin, G2t, cython=False)
    t_mt[t_bunch], g2_mt[t_bunch] = XPCS.get_g2_mt(itime*Lbin, g2[t_bunch])
# Out:
# Computing G2t for bunch 1 (Nfi = 1 , Nff = 99986 ) ...
# Loading frames ...
# Done! (elapsed time = 0.49 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.89 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.875 GB
# Masking data ...
# Done! (elapsed time = 1.05 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.87e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.297 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.12 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.04 s)
#
# Computing g2...
# Done! (elapsed time = 0.17 s)
#
# Computing G2t for bunch 2 (Nfi = 99986 , Nff = 199971 ) ...
# Loading frames ...
# Done! (elapsed time = 0.49 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.02 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.872 GB
# Masking data ...
# Done! (elapsed time = 1.89 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.86e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.297 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.01 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.17 s)
#
# Computing G2t for bunch 3 (Nfi = 199971 , Nff = 299956 ) ...
# Loading frames ...
# Done! (elapsed time = 0.48 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.3 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.74e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.871 GB
# Masking data ...
# Done! (elapsed time = 1.95 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.86e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.296 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.26 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.04 s)
#
# Computing g2...
# Done! (elapsed time = 0.15 s)
#
# Computing G2t for bunch 4 (Nfi = 299956 , Nff = 399941 ) ...
# Loading frames ...
# Done! (elapsed time = 0.5 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.87 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.74e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.871 GB
# Masking data ...
# Done! (elapsed time = 0.99 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.86e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.296 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.07 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.04 s)
#
# Computing g2...
# Done! (elapsed time = 0.18 s)
#
# Computing G2t for bunch 5 (Nfi = 399941 , Nff = 499926 ) ...
# Loading frames ...
# Done! (elapsed time = 0.49 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.85 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.74e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.87 GB
# Masking data ...
# Done! (elapsed time = 0.97 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.86e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.295 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.26 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.17 s)
#
# Computing G2t for bunch 6 (Nfi = 499926 , Nff = 599911 ) ...
# Loading frames ...
# Done! (elapsed time = 0.99 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.48 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.74e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.869 GB
# Masking data ...
# Done! (elapsed time = 2.02 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.85e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.295 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.24 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.23 s)
#
# Computing G2t for bunch 7 (Nfi = 599911 , Nff = 699896 ) ...
# Loading frames ...
# Done! (elapsed time = 0.76 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.97 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.74e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.868 GB
# Masking data ...
# Done! (elapsed time = 1.57 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.85e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.294 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.01 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.29 s)
#
# Computing G2t for bunch 8 (Nfi = 699896 , Nff = 799881 ) ...
# Loading frames ...
# Done! (elapsed time = 0.66 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.04 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.74e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.867 GB
# Masking data ...
# Done! (elapsed time = 1.0 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.85e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.294 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.92 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.18 s)
#
# Computing G2t for bunch 9 (Nfi = 799881 , Nff = 899866 ) ...
# Loading frames ...
# Done! (elapsed time = 0.48 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.92 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.866 GB
# Masking data ...
# Done! (elapsed time = 0.97 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.84e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.294 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.06 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.17 s)
#
# Computing G2t for bunch 10 (Nfi = 899866 , Nff = 999851 ) ...
# Loading frames ...
# Done! (elapsed time = 0.49 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.84 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.866 GB
# Masking data ...
# Done! (elapsed time = 0.98 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.84e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.293 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.0 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.2 s)
#
# Computing G2t for bunch 11 (Nfi = 999851 , Nff = 1099836 ) ...
# Loading frames ...
# Done! (elapsed time = 0.48 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.84 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.866 GB
# Masking data ...
# Done! (elapsed time = 0.94 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.84e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.293 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.19 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.17 s)
#
# Computing G2t for bunch 12 (Nfi = 1099836 , Nff = 1199821 ) ...
# Loading frames ...
# Done! (elapsed time = 0.49 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.09 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.866 GB
# Masking data ...
# Done! (elapsed time = 0.98 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.84e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.293 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.12 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.18 s)
#
# Computing G2t for bunch 13 (Nfi = 1199821 , Nff = 1299806 ) ...
# Loading frames ...
# Done! (elapsed time = 0.75 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.2 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.865 GB
# Masking data ...
# Done! (elapsed time = 1.22 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.84e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.293 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.19 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.18 s)
#
# Computing G2t for bunch 14 (Nfi = 1299806 , Nff = 1399791 ) ...
# Loading frames ...
# Done! (elapsed time = 0.74 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.28 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.865 GB
# Masking data ...
# Done! (elapsed time = 1.91 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.84e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.293 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.12 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.18 s)
#
# Computing G2t for bunch 15 (Nfi = 1399791 , Nff = 1499776 ) ...
# Loading frames ...
# Done! (elapsed time = 0.52 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.06 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.865 GB
# Masking data ...
# Done! (elapsed time = 1.2 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.84e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.292 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.2 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.56 s)
#
# Computing G2t for bunch 16 (Nfi = 1499776 , Nff = 1599761 ) ...
# Loading frames ...
# Done! (elapsed time = 0.67 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.86 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.864 GB
# Masking data ...
# Done! (elapsed time = 1.5 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.83e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.292 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.26 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.16 s)
#
# Computing G2t for bunch 17 (Nfi = 1599761 , Nff = 1699746 ) ...
# Loading frames ...
# Done! (elapsed time = 0.48 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.95 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.864 GB
# Masking data ...
# Done! (elapsed time = 0.94 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.83e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.292 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.91 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.17 s)
#
# Computing G2t for bunch 18 (Nfi = 1699746 , Nff = 1799731 ) ...
# Loading frames ...
# Done! (elapsed time = 0.48 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.01 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.863 GB
# Masking data ...
# Done! (elapsed time = 0.86 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.83e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.291 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.02 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.28 s)
#
# Computing G2t for bunch 19 (Nfi = 1799731 , Nff = 1899716 ) ...
# Loading frames ...
# Done! (elapsed time = 0.5 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.82 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.862 GB
# Masking data ...
# Done! (elapsed time = 0.89 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.83e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.291 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.0 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.16 s)
#
# Computing G2t for bunch 20 (Nfi = 1899716 , Nff = 1999701 ) ...
# Loading frames ...
# Done! (elapsed time = 0.49 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.95 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.862 GB
# Masking data ...
# Done! (elapsed time = 0.87 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.83e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.291 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.91 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.17 s)
#
# Computing G2t for bunch 21 (Nfi = 1999701 , Nff = 2099686 ) ...
# Loading frames ...
# Done! (elapsed time = 0.49 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.81 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.862 GB
# Masking data ...
# Done! (elapsed time = 0.88 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.82e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.291 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.04 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.08 s)
#
# Computing g2...
# Done! (elapsed time = 0.61 s)
#
# Computing G2t for bunch 22 (Nfi = 2099686 , Nff = 2199671 ) ...
# Loading frames ...
# Done! (elapsed time = 0.99 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.38 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.861 GB
# Masking data ...
# Done! (elapsed time = 1.86 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.82e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.29 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.12 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.08 s)
#
# Computing g2...
# Done! (elapsed time = 0.24 s)
#
# Computing G2t for bunch 23 (Nfi = 2199671 , Nff = 2299656 ) ...
# Loading frames ...
# Done! (elapsed time = 0.53 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.29 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.86 GB
# Masking data ...
# Done! (elapsed time = 0.72 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.82e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.29 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.93 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.21 s)
#
# Computing G2t for bunch 24 (Nfi = 2299656 , Nff = 2399641 ) ...
# Loading frames ...
# Done! (elapsed time = 0.58 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.1 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.859 GB
# Masking data ...
# Done! (elapsed time = 1.53 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.82e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.289 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.08 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.42 s)
#
# Computing G2t for bunch 25 (Nfi = 2399641 , Nff = 2499626 ) ...
# Loading frames ...
# Done! (elapsed time = 0.64 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.85 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.859 GB
# Masking data ...
# Done! (elapsed time = 1.17 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.82e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.289 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.23 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Computing g2...
# Done! (elapsed time = 0.18 s)
#
# Computing G2t for bunch 26 (Nfi = 2499626 , Nff = 2599611 ) ...
# Loading frames ...
# Done! (elapsed time = 0.67 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.23 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.858 GB
# Masking data ...
# Done! (elapsed time = 1.25 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.81e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.289 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.21 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Computing g2...
# Done! (elapsed time = 0.28 s)
#
# Computing G2t for bunch 27 (Nfi = 2599611 , Nff = 2699596 ) ...
# Loading frames ...
# Done! (elapsed time = 0.7 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.85 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.857 GB
# Masking data ...
# Done! (elapsed time = 1.32 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.81e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.288 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.52 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.45 s)
#
# Computing G2t for bunch 28 (Nfi = 2699596 , Nff = 2799581 ) ...
# Loading frames ...
# Done! (elapsed time = 0.72 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.86 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.857 GB
# Masking data ...
# Done! (elapsed time = 0.62 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.81e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.288 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.98 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.18 s)
#
# Computing G2t for bunch 29 (Nfi = 2799581 , Nff = 2899566 ) ...
# Loading frames ...
# Done! (elapsed time = 0.48 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.95 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.71e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.857 GB
# Masking data ...
# Done! (elapsed time = 0.65 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.81e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.288 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.07 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.24 s)
#
# Computing G2t for bunch 30 (Nfi = 2899566 , Nff = 2999551 ) ...
# Loading frames ...
# Done! (elapsed time = 0.49 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.04 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.859 GB
# Masking data ...
# Done! (elapsed time = 0.61 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.81e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.289 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.94 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.04 s)
#
# Computing g2...
# Done! (elapsed time = 0.27 s)

# %%
##################
t1_fit = 0
t2_fit = 1e8
##################
 
plt.figure(figsize=(10,5))
fit_out = pd.DataFrame(columns=['tau', 'beta', 'c', 'y0', 'dtau', 'dbeta', 'dc', 'dy0'])
fit_out.index.name = 't'
for k in g2.keys():
    #plt.scatter(t[k], g2[k], s=1, label = str(k)+'s')
    plt.scatter(t_mt[k], g2_mt[k], label=str(k)+'s')

    popt, pcov = curve_fit(decorelation_f, t[k][(t1_fit<t[k])*(t[k]<t2_fit)], g2[k][(t1_fit<t[k])*(t[k]<t2_fit)], p0=[3, .7, .02, 1], bounds=([0, 0, 0, 0], [np.inf, np.inf, np.inf, np.inf]))
    fit_out.loc[k] = [popt[0], popt[1], popt[2], popt[3], np.sqrt(pcov[0,0]), np.sqrt(pcov[1,1]), np.sqrt(pcov[2,2]), np.sqrt(pcov[3,3])]
    
    x = np.arange(np.min(t[k]), np.max(t[k]), 1e-2)
    y = decorelation_f(x, *popt)
    plt.plot(x, y,)

plt.xlabel('t [s]')
plt.ylabel('g2')
plt.xscale('log')
plt.legend()
plt.show()



plt.figure(figsize=(10,5))
plt.title('tau')
plt.errorbar(fit_out.index, fit_out.tau,  yerr=fit_out.dtau, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('tau [s]')
plt.show()

plt.figure(figsize=(10,5))
plt.title('beta')
plt.errorbar(fit_out.index, fit_out.beta,  yerr=fit_out.dbeta, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('beta')
plt.show()

plt.figure(figsize=(10,5))
plt.title('c')
plt.errorbar(fit_out.index, fit_out.c,  yerr=fit_out.dc, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('c')
plt.show()

plt.figure(figsize=(10,5))
plt.title('y0')
plt.errorbar(fit_out.index, fit_out.y0,  yerr=fit_out.dy0, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('y0')
plt.show()

# %% [markdown]
# ## XPCS scan (T = 485C Q =  0.19 Å, 50 min @ 1ms (3_000_000 fm)) (GeO2_3, dataset 1, scan 4)

# %%
#######################################
sample_name = 'GeO2_3_485C'
Ndataset = 1
Nscan = 4
Nfi, Nff =  None, None
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
#e4m_data = ID10.load_dense_e4m_new(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )

e4m_data = COSMIC.fast_gamma_filter(e4m_data, Imaxth_high=5)
# Out:
# #############################
# command = mtimescan 0.001 1 2999568
# Ei = 9.699998837562536
# itime = 0.0011
# theta = 1.7500000000000004
# Q = 0.15
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00001.h5 (2/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00002.h5 (3/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00003.h5 (4/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00004.h5 (5/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00005.h5 (6/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00006.h5 (7/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00007.h5 (8/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00008.h5 (9/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00009.h5 (10/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00010.h5 (11/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00011.h5 (12/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00012.h5 (13/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00013.h5 (14/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00014.h5 (15/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00015.h5 (16/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00016.h5 (17/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00017.h5 (18/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00018.h5 (19/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00019.h5 (20/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00020.h5 (21/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00021.h5 (22/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00022.h5 (23/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00023.h5 (24/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00024.h5 (25/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00025.h5 (26/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00026.h5 (27/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00027.h5 (28/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00028.h5 (29/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00029.h5 (30/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00030.h5 (31/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00031.h5 (32/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00032.h5 (33/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00033.h5 (34/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00034.h5 (35/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00035.h5 (36/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00036.h5 (37/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00037.h5 (38/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00038.h5 (39/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00039.h5 (40/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00040.h5 (41/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00041.h5 (42/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00042.h5 (43/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00043.h5 (44/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00044.h5 (45/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00045.h5 (46/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00046.h5 (47/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00047.h5 (48/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00048.h5 (49/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00049.h5 (50/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00050.h5 (51/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00051.h5 (52/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00052.h5 (53/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00053.h5 (54/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00054.h5 (55/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00055.h5 (56/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00056.h5 (57/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00057.h5 (58/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00058.h5 (59/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00059.h5 (60/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00060.h5 (61/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00061.h5 (62/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00062.h5 (63/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00063.h5 (64/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00064.h5 (65/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00065.h5 (66/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00066.h5 (67/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00067.h5 (68/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00068.h5 (69/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00069.h5 (70/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00070.h5 (71/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00071.h5 (72/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00072.h5 (73/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00073.h5 (74/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00074.h5 (75/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00075.h5 (76/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00076.h5 (77/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00077.h5 (78/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00078.h5 (79/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00079.h5 (80/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00080.h5 (81/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00081.h5 (82/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00082.h5 (83/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00083.h5 (84/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00084.h5 (85/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00085.h5 (86/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00086.h5 (87/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00087.h5 (88/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00088.h5 (89/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00089.h5 (90/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00090.h5 (91/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00091.h5 (92/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00092.h5 (93/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00093.h5 (94/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00094.h5 (95/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00095.h5 (96/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00096.h5 (97/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00097.h5 (98/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00098.h5 (99/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00099.h5 (100/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00100.h5 (101/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00101.h5 (102/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00102.h5 (103/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00103.h5 (104/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00104.h5 (105/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00105.h5 (106/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00106.h5 (107/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00107.h5 (108/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00108.h5 (109/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00109.h5 (110/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00110.h5 (111/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00111.h5 (112/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00112.h5 (113/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00113.h5 (114/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00114.h5 (115/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00115.h5 (116/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00116.h5 (117/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00117.h5 (118/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00118.h5 (119/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00119.h5 (120/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00120.h5 (121/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00121.h5 (122/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00122.h5 (123/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00123.h5 (124/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00124.h5 (125/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00125.h5 (126/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00126.h5 (127/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00127.h5 (128/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00128.h5 (129/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00129.h5 (130/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00130.h5 (131/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00131.h5 (132/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00132.h5 (133/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00133.h5 (134/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00134.h5 (135/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00135.h5 (136/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00136.h5 (137/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00137.h5 (138/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00138.h5 (139/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00139.h5 (140/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00140.h5 (141/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00141.h5 (142/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00142.h5 (143/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00143.h5 (144/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00144.h5 (145/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00145.h5 (146/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00146.h5 (147/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00147.h5 (148/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00148.h5 (149/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00149.h5 (150/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00150.h5 (151/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00151.h5 (152/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00152.h5 (153/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00153.h5 (154/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00154.h5 (155/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00155.h5 (156/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00156.h5 (157/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00157.h5 (158/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00158.h5 (159/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00159.h5 (160/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00160.h5 (161/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00161.h5 (162/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00162.h5 (163/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00163.h5 (164/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00164.h5 (165/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00165.h5 (166/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00166.h5 (167/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00167.h5 (168/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00168.h5 (169/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00169.h5 (170/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00170.h5 (171/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00171.h5 (172/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00172.h5 (173/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00173.h5 (174/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00174.h5 (175/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00175.h5 (176/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00176.h5 (177/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00177.h5 (178/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00178.h5 (179/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00179.h5 (180/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00180.h5 (181/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00181.h5 (182/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00182.h5 (183/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00183.h5 (184/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00184.h5 (185/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00185.h5 (186/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00186.h5 (187/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00187.h5 (188/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00188.h5 (189/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00189.h5 (190/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00190.h5 (191/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00191.h5 (192/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00192.h5 (193/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00193.h5 (194/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00194.h5 (195/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00195.h5 (196/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00196.h5 (197/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00197.h5 (198/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00198.h5 (199/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00199.h5 (200/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00200.h5 (201/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00201.h5 (202/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00202.h5 (203/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00203.h5 (204/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00204.h5 (205/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00205.h5 (206/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00206.h5 (207/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00207.h5 (208/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00208.h5 (209/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00209.h5 (210/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00210.h5 (211/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00211.h5 (212/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00212.h5 (213/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00213.h5 (214/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00214.h5 (215/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00215.h5 (216/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00216.h5 (217/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00217.h5 (218/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00218.h5 (219/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00219.h5 (220/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00220.h5 (221/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00221.h5 (222/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00222.h5 (223/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00223.h5 (224/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00224.h5 (225/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00225.h5 (226/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00226.h5 (227/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00227.h5 (228/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00228.h5 (229/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00229.h5 (230/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00230.h5 (231/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00231.h5 (232/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00232.h5 (233/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00233.h5 (234/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00234.h5 (235/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00235.h5 (236/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00236.h5 (237/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00237.h5 (238/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00238.h5 (239/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00239.h5 (240/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00240.h5 (241/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00241.h5 (242/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00242.h5 (243/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00243.h5 (244/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00244.h5 (245/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00245.h5 (246/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00246.h5 (247/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00247.h5 (248/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00248.h5 (249/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00249.h5 (250/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00250.h5 (251/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00251.h5 (252/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00252.h5 (253/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00253.h5 (254/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00254.h5 (255/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00255.h5 (256/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00256.h5 (257/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00257.h5 (258/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00258.h5 (259/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00259.h5 (260/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00260.h5 (261/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00261.h5 (262/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00262.h5 (263/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00263.h5 (264/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00264.h5 (265/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00265.h5 (266/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00266.h5 (267/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00267.h5 (268/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00268.h5 (269/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00269.h5 (270/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00270.h5 (271/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00271.h5 (272/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00272.h5 (273/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00273.h5 (274/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00274.h5 (275/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00275.h5 (276/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00276.h5 (277/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00277.h5 (278/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00278.h5 (279/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00279.h5 (280/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00280.h5 (281/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00281.h5 (282/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00282.h5 (283/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00283.h5 (284/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00284.h5 (285/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00285.h5 (286/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00286.h5 (287/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00287.h5 (288/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00288.h5 (289/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00289.h5 (290/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00290.h5 (291/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00291.h5 (292/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00292.h5 (293/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00293.h5 (294/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00294.h5 (295/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00295.h5 (296/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00296.h5 (297/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00297.h5 (298/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00298.h5 (299/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00299.h5 (300/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00300.h5 (301/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00301.h5 (302/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00302.h5 (303/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00303.h5 (304/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00304.h5 (305/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00305.h5 (306/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00306.h5 (307/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00307.h5 (308/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00308.h5 (309/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00309.h5 (310/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00310.h5 (311/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00311.h5 (312/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00312.h5 (313/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00313.h5 (314/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00314.h5 (315/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00315.h5 (316/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00316.h5 (317/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00317.h5 (318/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00318.h5 (319/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00319.h5 (320/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00320.h5 (321/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00321.h5 (322/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00322.h5 (323/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00323.h5 (324/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00324.h5 (325/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00325.h5 (326/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00326.h5 (327/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00327.h5 (328/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00328.h5 (329/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00329.h5 (330/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00330.h5 (331/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00331.h5 (332/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00332.h5 (333/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00333.h5 (334/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00334.h5 (335/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00335.h5 (336/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00336.h5 (337/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00337.h5 (338/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00338.h5 (339/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00339.h5 (340/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00340.h5 (341/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00341.h5 (342/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00342.h5 (343/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00343.h5 (344/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00344.h5 (345/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00345.h5 (346/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00346.h5 (347/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00347.h5 (348/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00348.h5 (349/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00349.h5 (350/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00350.h5 (351/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00351.h5 (352/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00352.h5 (353/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00353.h5 (354/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00354.h5 (355/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00355.h5 (356/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00356.h5 (357/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00357.h5 (358/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00358.h5 (359/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00359.h5 (360/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00360.h5 (361/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00361.h5 (362/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00362.h5 (363/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00363.h5 (364/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00364.h5 (365/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00365.h5 (366/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00366.h5 (367/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00367.h5 (368/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00368.h5 (369/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00369.h5 (370/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00370.h5 (371/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00371.h5 (372/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00372.h5 (373/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00373.h5 (374/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00374.h5 (375/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00375.h5 (376/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00376.h5 (377/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00377.h5 (378/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00378.h5 (379/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00379.h5 (380/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00380.h5 (381/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00381.h5 (382/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00382.h5 (383/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00383.h5 (384/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00384.h5 (385/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00385.h5 (386/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00386.h5 (387/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00387.h5 (388/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00388.h5 (389/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00389.h5 (390/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00390.h5 (391/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00391.h5 (392/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00392.h5 (393/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00393.h5 (394/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00394.h5 (395/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00395.h5 (396/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00396.h5 (397/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00397.h5 (398/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00398.h5 (399/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00399.h5 (400/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00400.h5 (401/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00401.h5 (402/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00402.h5 (403/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00403.h5 (404/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00404.h5 (405/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00405.h5 (406/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00406.h5 (407/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00407.h5 (408/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00408.h5 (409/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00409.h5 (410/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00410.h5 (411/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00411.h5 (412/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00412.h5 (413/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00413.h5 (414/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00414.h5 (415/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00415.h5 (416/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00416.h5 (417/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00417.h5 (418/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00418.h5 (419/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00419.h5 (420/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00420.h5 (421/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00421.h5 (422/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00422.h5 (423/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00423.h5 (424/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00424.h5 (425/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00425.h5 (426/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00426.h5 (427/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00427.h5 (428/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00428.h5 (429/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00429.h5 (430/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00430.h5 (431/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00431.h5 (432/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00432.h5 (433/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00433.h5 (434/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00434.h5 (435/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00435.h5 (436/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00436.h5 (437/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00437.h5 (438/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00438.h5 (439/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00439.h5 (440/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00440.h5 (441/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00441.h5 (442/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00442.h5 (443/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00443.h5 (444/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00444.h5 (445/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00445.h5 (446/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00446.h5 (447/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00447.h5 (448/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00448.h5 (449/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00449.h5 (450/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00450.h5 (451/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00451.h5 (452/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00452.h5 (453/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00453.h5 (454/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00454.h5 (455/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00455.h5 (456/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00456.h5 (457/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00457.h5 (458/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00458.h5 (459/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00459.h5 (460/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00460.h5 (461/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00461.h5 (462/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00462.h5 (463/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00463.h5 (464/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00464.h5 (465/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00465.h5 (466/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00466.h5 (467/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00467.h5 (468/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00468.h5 (469/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00469.h5 (470/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00470.h5 (471/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00471.h5 (472/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00472.h5 (473/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00473.h5 (474/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00474.h5 (475/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00475.h5 (476/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00476.h5 (477/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00477.h5 (478/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00478.h5 (479/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00479.h5 (480/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00480.h5 (481/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00481.h5 (482/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00482.h5 (483/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00483.h5 (484/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00484.h5 (485/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00485.h5 (486/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00486.h5 (487/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00487.h5 (488/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00488.h5 (489/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00489.h5 (490/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00490.h5 (491/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00491.h5 (492/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00492.h5 (493/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00493.h5 (494/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00494.h5 (495/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00495.h5 (496/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00496.h5 (497/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00497.h5 (498/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00498.h5 (499/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00499.h5 (500/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00500.h5 (501/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00501.h5 (502/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00502.h5 (503/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00503.h5 (504/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00504.h5 (505/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00505.h5 (506/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00506.h5 (507/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00507.h5 (508/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00508.h5 (509/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00509.h5 (510/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00510.h5 (511/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00511.h5 (512/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00512.h5 (513/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00513.h5 (514/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00514.h5 (515/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00515.h5 (516/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00516.h5 (517/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00517.h5 (518/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00518.h5 (519/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00519.h5 (520/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00520.h5 (521/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00521.h5 (522/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00522.h5 (523/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00523.h5 (524/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00524.h5 (525/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00525.h5 (526/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00526.h5 (527/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00527.h5 (528/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00528.h5 (529/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00529.h5 (530/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00530.h5 (531/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00531.h5 (532/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00532.h5 (533/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00533.h5 (534/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00534.h5 (535/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00535.h5 (536/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00536.h5 (537/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00537.h5 (538/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00538.h5 (539/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00539.h5 (540/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00540.h5 (541/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00541.h5 (542/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00542.h5 (543/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00543.h5 (544/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00544.h5 (545/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00545.h5 (546/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00546.h5 (547/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00547.h5 (548/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00548.h5 (549/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00549.h5 (550/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00550.h5 (551/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00551.h5 (552/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00552.h5 (553/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00553.h5 (554/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00554.h5 (555/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00555.h5 (556/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00556.h5 (557/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00557.h5 (558/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00558.h5 (559/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00559.h5 (560/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00560.h5 (561/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00561.h5 (562/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00562.h5 (563/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00563.h5 (564/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00564.h5 (565/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00565.h5 (566/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00566.h5 (567/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00567.h5 (568/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00568.h5 (569/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00569.h5 (570/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00570.h5 (571/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00571.h5 (572/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00572.h5 (573/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00573.h5 (574/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00574.h5 (575/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00575.h5 (576/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00576.h5 (577/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00577.h5 (578/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00578.h5 (579/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00579.h5 (580/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00580.h5 (581/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00581.h5 (582/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00582.h5 (583/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00583.h5 (584/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00584.h5 (585/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00585.h5 (586/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00586.h5 (587/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00587.h5 (588/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00588.h5 (589/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00589.h5 (590/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00590.h5 (591/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00591.h5 (592/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00592.h5 (593/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00593.h5 (594/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00594.h5 (595/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00595.h5 (596/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00596.h5 (597/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00597.h5 (598/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00598.h5 (599/600 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00599.h5 (600/600 loops)
# Done!
# Concatenating vectors ...
# Done!
# 	 | Sparse array loaded from ../RAW_DATA/GeO2_3_485C/GeO2_3_485C_0001/scan0004/
# 	 | Shape:       (2999568, 4471016)
# 	 | Sparsity:     1.7e-04
# 	 | Memory usage (scipy.csr_array): 19.551 GB (np.array usage: 49960.302 GB)
# Filtering gamma ray signal (i.e. signals over treshold) ...
# Done! (elapsed time = 14.57 s)
# Removing gamma ray signal (set 0s) ...
# Done! (elapsed time = 12.72 s)

# %% [markdown]
# ### Flux check

# %%
#############################################
mask = e4m_mask * e4m_htmask * bs_mask
#############################################

XPCS.gen_plots4mask(e4m_data, itime, Ith_high= .4, Nff=100_000, e4m_mask=mask)
# Out:
# ################################################################################
# Maximum count in the hull run -> 5
# # of pixels above Ith_high treshold ->  19 pixels (of 4471016 => 0.0 %)
# ################################################################################

# %% [markdown]
# ### Intensity analysis

# %%
####################
Lbin = 1
Nstep = 100
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
####################

t_It, It = XPCS.get_It(e4m_data, itime, mask=mask, Lbin=Lbin, Nstep=Nstep)
np.savez(Idts_folder+'Idt_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4), t_It=t_It, It=It)

# %%
plt.figure(figsize=(10,5))
plt.scatter(t_It, It, label='It')

plt.xlabel('Time (s)')
plt.ylabel('Integrated intensity [photons/pixel/s]')
plt.xscale('log')
#plt.xlim(1e-2, 1)
plt.gca().secondary_xaxis('top', functions=(lambda x: x/itime, lambda x: x*itime))
plt.grid()

# %% [markdown]
# ### Correlation

# %%
###################
Nfi = 1
Nff = None
Lbin = 10
Nbunch = 30
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
###################
if Nfi == None: Nfi = 0
if Nff == None: Nff = e4m_data.shape[0]
if Lbin == None: Lbin = 1


Lbunch = (Nff-Nfi)//Nbunch

t, g2, t_mt, g2_mt = {}, {}, {}, {}

for i in range(Nbunch):
    
    print('Computing G2t for bunch', i+1, '(Nfi =', Nfi+i*Lbunch, ', Nff =', Nfi+(i+1)*Lbunch, ') ...')
    G2t = XPCS.get_G2t(e4m_data, mask, Nfi=Nfi+i*Lbunch, Nff=Nfi+(i+1)*Lbunch, Lbin=Lbin)

    t_bunch = round(itime*Lbunch*Nbunch*(i+1/2),1)

    t[t_bunch], g2[t_bunch] = XPCS.get_g2(itime*Lbin, G2t, cython=False)
    t_mt[t_bunch], g2_mt[t_bunch] = XPCS.get_g2_mt(itime*Lbin, g2[t_bunch])
# Out:
# Computing G2t for bunch 1 (Nfi = 1 , Nff = 99986 ) ...
# Loading frames ...
# Done! (elapsed time = 0.99 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.1 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.863 GB
# Masking data ...
# Done! (elapsed time = 1.03 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.82e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.29 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.11 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.18 s)
#
# Computing G2t for bunch 2 (Nfi = 99986 , Nff = 199971 ) ...
# Loading frames ...
# Done! (elapsed time = 0.47 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.98 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.862 GB
# Masking data ...
# Done! (elapsed time = 0.67 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.82e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.29 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.92 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.28 s)
#
# Computing G2t for bunch 3 (Nfi = 199971 , Nff = 299956 ) ...
# Loading frames ...
# Done! (elapsed time = 0.77 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.86 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.863 GB
# Masking data ...
# Done! (elapsed time = 0.63 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.82e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.289 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.02 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.17 s)
#
# Computing G2t for bunch 4 (Nfi = 299956 , Nff = 399941 ) ...
# Loading frames ...
# Done! (elapsed time = 0.47 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.97 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.863 GB
# Masking data ...
# Done! (elapsed time = 0.62 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.82e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.289 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.97 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Computing g2...
# Done! (elapsed time = 0.15 s)
#
# Computing G2t for bunch 5 (Nfi = 399941 , Nff = 499926 ) ...
# Loading frames ...
# Done! (elapsed time = 0.47 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.81 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.73e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.863 GB
# Masking data ...
# Done! (elapsed time = 0.64 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.82e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.289 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.85 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.04 s)
#
# Computing g2...
# Done! (elapsed time = 0.27 s)
#
# Computing G2t for bunch 6 (Nfi = 499926 , Nff = 599911 ) ...
# Loading frames ...
# Done! (elapsed time = 0.82 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.94 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.862 GB
# Masking data ...
# Done! (elapsed time = 0.64 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.81e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.289 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.85 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.04 s)
#
# Computing g2...
# Done! (elapsed time = 0.15 s)
#
# Computing G2t for bunch 7 (Nfi = 599911 , Nff = 699896 ) ...
# Loading frames ...
# Done! (elapsed time = 0.61 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.81 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.861 GB
# Masking data ...
# Done! (elapsed time = 0.65 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.81e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.288 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.95 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.25 s)
#
# Computing G2t for bunch 8 (Nfi = 699896 , Nff = 799881 ) ...
# Loading frames ...
# Done! (elapsed time = 0.98 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.94 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.861 GB
# Masking data ...
# Done! (elapsed time = 0.62 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.81e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.288 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.88 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.04 s)
#
# Computing g2...
# Done! (elapsed time = 0.15 s)
#
# Computing G2t for bunch 9 (Nfi = 799881 , Nff = 899866 ) ...
# Loading frames ...
# Done! (elapsed time = 0.62 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.81 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.861 GB
# Masking data ...
# Done! (elapsed time = 0.63 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.81e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.288 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.89 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.16 s)
#
# Computing G2t for bunch 10 (Nfi = 899866 , Nff = 999851 ) ...
# Loading frames ...
# Done! (elapsed time = 0.61 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.91 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.859 GB
# Masking data ...
# Done! (elapsed time = 0.62 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.81e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.288 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.8 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.17 s)
#
# Computing G2t for bunch 11 (Nfi = 999851 , Nff = 1099836 ) ...
# Loading frames ...
# Done! (elapsed time = 0.6 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.78 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.72e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.858 GB
# Masking data ...
# Done! (elapsed time = 0.62 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.80e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.287 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.85 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.07 s)
#
# Computing g2...
# Done! (elapsed time = 0.25 s)
#
# Computing G2t for bunch 12 (Nfi = 1099836 , Nff = 1199821 ) ...
# Loading frames ...
# Done! (elapsed time = 1.04 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.18 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.71e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.857 GB
# Masking data ...
# Done! (elapsed time = 0.99 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.80e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.287 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.98 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.28 s)
#
# Computing G2t for bunch 13 (Nfi = 1199821 , Nff = 1299806 ) ...
# Loading frames ...
# Done! (elapsed time = 1.01 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.85 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.71e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.856 GB
# Masking data ...
# Done! (elapsed time = 0.61 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.80e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.287 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.15 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.17 s)
#
# Computing G2t for bunch 14 (Nfi = 1299806 , Nff = 1399791 ) ...
# Loading frames ...
# Done! (elapsed time = 0.6 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.95 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.71e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.855 GB
# Masking data ...
# Done! (elapsed time = 0.61 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.80e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.286 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.03 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.28 s)
#
# Computing G2t for bunch 15 (Nfi = 1399791 , Nff = 1499776 ) ...
# Loading frames ...
# Done! (elapsed time = 0.81 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.77 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.71e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.855 GB
# Masking data ...
# Done! (elapsed time = 0.62 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.80e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.286 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.85 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.16 s)
#
# Computing G2t for bunch 16 (Nfi = 1499776 , Nff = 1599761 ) ...
# Loading frames ...
# Done! (elapsed time = 0.6 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.94 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.71e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.854 GB
# Masking data ...
# Done! (elapsed time = 0.62 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.80e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.286 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.97 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.09 s)
#
# Computing g2...
# Done! (elapsed time = 0.19 s)
#
# Computing G2t for bunch 17 (Nfi = 1599761 , Nff = 1699746 ) ...
# Loading frames ...
# Done! (elapsed time = 0.59 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.88 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.71e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.853 GB
# Masking data ...
# Done! (elapsed time = 0.65 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.79e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.286 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.87 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.17 s)
#
# Computing G2t for bunch 18 (Nfi = 1699746 , Nff = 1799731 ) ...
# Loading frames ...
# Done! (elapsed time = 0.6 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.96 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.70e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.852 GB
# Masking data ...
# Done! (elapsed time = 0.64 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.79e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.285 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.79 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.16 s)
#
# Computing G2t for bunch 19 (Nfi = 1799731 , Nff = 1899716 ) ...
# Loading frames ...
# Done! (elapsed time = 0.6 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.76 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.70e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.851 GB
# Masking data ...
# Done! (elapsed time = 0.65 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.79e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.285 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.8 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.16 s)
#
# Computing G2t for bunch 20 (Nfi = 1899716 , Nff = 1999701 ) ...
# Loading frames ...
# Done! (elapsed time = 0.6 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.96 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.70e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.85 GB
# Masking data ...
# Done! (elapsed time = 0.82 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.79e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.285 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.06 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.21 s)
#
# Computing G2t for bunch 21 (Nfi = 1999701 , Nff = 2099686 ) ...
# Loading frames ...
# Done! (elapsed time = 0.88 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.83 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.70e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.849 GB
# Masking data ...
# Done! (elapsed time = 0.69 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.79e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.285 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.96 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.17 s)
#
# Computing G2t for bunch 22 (Nfi = 2099686 , Nff = 2199671 ) ...
# Loading frames ...
# Done! (elapsed time = 0.59 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.92 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.70e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.848 GB
# Masking data ...
# Done! (elapsed time = 0.62 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.78e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.284 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.84 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.17 s)
#
# Computing G2t for bunch 23 (Nfi = 2199671 , Nff = 2299656 ) ...
# Loading frames ...
# Done! (elapsed time = 0.48 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.81 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.76e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.879 GB
# Masking data ...
# Done! (elapsed time = 0.71 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.85e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.294 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.85 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.22 s)
#
# Computing G2t for bunch 24 (Nfi = 2299656 , Nff = 2399641 ) ...
# Loading frames ...
# Done! (elapsed time = 1.09 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.45 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.76e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.881 GB
# Masking data ...
# Done! (elapsed time = 0.79 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.85e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.295 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.23 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.2 s)
#
# Computing G2t for bunch 25 (Nfi = 2399641 , Nff = 2499626 ) ...
# Loading frames ...
# Done! (elapsed time = 0.97 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.06 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.76e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.881 GB
# Masking data ...
# Done! (elapsed time = 1.31 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.85e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.295 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.07 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.15 s)
#
# Computing G2t for bunch 26 (Nfi = 2499626 , Nff = 2599611 ) ...
# Loading frames ...
# Done! (elapsed time = 0.58 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.91 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.76e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.879 GB
# Masking data ...
# Done! (elapsed time = 0.68 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.85e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.295 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.18 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.04 s)
#
# Computing g2...
# Done! (elapsed time = 0.15 s)
#
# Computing G2t for bunch 27 (Nfi = 2599611 , Nff = 2699596 ) ...
# Loading frames ...
# Done! (elapsed time = 0.84 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.39 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.76e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.878 GB
# Masking data ...
# Done! (elapsed time = 1.08 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.85e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.294 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.36 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.08 s)
#
# Computing g2...
# Done! (elapsed time = 0.26 s)
#
# Computing G2t for bunch 28 (Nfi = 2699596 , Nff = 2799581 ) ...
# Loading frames ...
# Done! (elapsed time = 1.0 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.92 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.76e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.877 GB
# Masking data ...
# Done! (elapsed time = 1.21 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.85e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.294 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.25 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.16 s)
#
# Computing G2t for bunch 29 (Nfi = 2799581 , Nff = 2899566 ) ...
# Loading frames ...
# Done! (elapsed time = 0.49 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 0.85 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.875 GB
# Masking data ...
# Done! (elapsed time = 1.62 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.84e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.293 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.19 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.05 s)
#
# Computing g2...
# Done! (elapsed time = 0.22 s)
#
# Computing G2t for bunch 30 (Nfi = 2899566 , Nff = 2999551 ) ...
# Loading frames ...
# Done! (elapsed time = 0.97 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 1.11 s)
# 	 | 9998 frames X 4471016 pixels
# 	 | sparsity = 1.75e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.873 GB
# Masking data ...
# Done! (elapsed time = 1.52 s)
# 	 | 9998 frames X 1424709 pixels
# 	 | sparsity = 1.84e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.293 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 1.17 s)
# 	 | 9998 X 9998 squared matrix
# 	 | memory usage (np.array @ float64) = 0.745 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.06 s)
#
# Computing g2...
# Done! (elapsed time = 0.18 s)

# %%
##################
t1_fit = 0
t2_fit = 1e8
##################
 
plt.figure(figsize=(10,5))
fit_out = pd.DataFrame(columns=['tau', 'beta', 'c', 'y0', 'dtau', 'dbeta', 'dc', 'dy0'])
fit_out.index.name = 't'
for k in g2.keys():
    #plt.scatter(t[k], g2[k], s=1, label = str(k)+'s')
    plt.scatter(t_mt[k], g2_mt[k], label=str(k)+'s')

    popt, pcov = curve_fit(decorelation_f, t[k][(t1_fit<t[k])*(t[k]<t2_fit)], g2[k][(t1_fit<t[k])*(t[k]<t2_fit)], p0=[3, .7, .02, 1], bounds=([0, 0, 0, 0], [np.inf, np.inf, np.inf, np.inf]))
    fit_out.loc[k] = [popt[0], popt[1], popt[2], popt[3], np.sqrt(pcov[0,0]), np.sqrt(pcov[1,1]), np.sqrt(pcov[2,2]), np.sqrt(pcov[3,3])]
    
    x = np.arange(np.min(t[k]), np.max(t[k]), 1e-2)
    y = decorelation_f(x, *popt)
    plt.plot(x, y,)

plt.xlabel('t [s]')
plt.ylabel('g2')
plt.xscale('log')
plt.legend()
plt.show()



plt.figure(figsize=(10,5))
plt.title('tau')
plt.errorbar(fit_out.index, fit_out.tau,  yerr=fit_out.dtau, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('tau [s]')
plt.show()

plt.figure(figsize=(10,5))
plt.title('beta')
plt.errorbar(fit_out.index, fit_out.beta,  yerr=fit_out.dbeta, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('beta')
plt.show()

plt.figure(figsize=(10,5))
plt.title('c')
plt.errorbar(fit_out.index, fit_out.c,  yerr=fit_out.dc, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('c')
plt.show()

plt.figure(figsize=(10,5))
plt.title('y0')
plt.errorbar(fit_out.index, fit_out.y0,  yerr=fit_out.dy0, fmt='o')
plt.xlabel('t [s]')
plt.ylabel('y0')
plt.show()
