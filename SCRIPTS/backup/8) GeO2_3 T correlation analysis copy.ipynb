# %%
### IMPORT SCIENTIFIC LIBRARIES ###
import numpy as np
import pandas as pd
from scipy import sparse
from scipy.optimize import curve_fit
import importlib

import matplotlib.pyplot as plt
#import seaborn as sns
plt.rcParams['font.size'], plt.rcParams['axes.labelsize'] = 14, 18
#%matplotlib widget

from tqdm import tqdm
import io, sys
from contextlib import redirect_stdout, redirect_stderr

import os

import h5py
import hdf5plugin

import sys
sys.path.append('./XPCS_library/')

import ID10_tools as ID10
from ID10_tools import Nx, Ny, Npx
importlib.reload(ID10)
ID10.set_version('v2')

import XPCS_tools as XPCS
from XPCS_tools import E2lambda, lambda2E, theta2Q, Q2theta, decorelation_f
importlib.reload(XPCS)
XPCS.set_beamline('ID10')

import COSMICRAY_tools as COSMIC
importlib.reload(COSMIC)
COSMIC.set_beamline('ID10')

# RAW FOLDER PATH
raw_folder = '../RAW_DATA/'
masks_folder = '../masks/'
fit_outs_folder = './data/fit_outs/'
Idts_folder = './data/Idts/'
g2_folder = './data/g2/'

# EXPERIMENTAL VARIABLES
XPCS.set_expvar(1350, 1400, 7)
ID10.Nfmax_dense_file = 2000
ID10.Nfmax_sparse_file = 5000

# %% [markdown]
# ## Load masks

# %%
e4m_htmask = np.load(masks_folder+'e4m_htmask_copper_foil_30um_1_1'+'.npy')
e4m_mask = np.load(masks_folder+'e4m_mask'+'.npy')
#bs_mask = np.load(masks_folder+'bs_mask_copper_foil_30um'+'.npy')  # beam-stop mask

# %%
plt.figure(figsize=(8, 8))
plt.imshow((e4m_mask*e4m_htmask).reshape(Nx,Ny), cmap='gray', origin='lower')

# %% [markdown]
# ### BS mask and Q definition
# Using a random scan in GeO2_6, because we are not changing the measurement configuration

# %% [markdown]
# #### Beamstop mask

# %%
#######################################
sample_name = 'GeO2_6'
Ndataset = 1
Nscan =12
Nfi, Nff = 0, 1000
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
# Out:
# #############################
# command = mtimescan 0.02 1 220000
# Ei = 9.699998837562536
# itime = 0.0201
# theta = 1.7500000000000004
# Q = 0.15
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/1 loops)
# Done!
# Concatenating vectors ...
# Done!
# 	 | Sparse array loaded from ../RAW_DATA/GeO2_6/GeO2_6_0001/scan0012/
# 	 | Shape:       (1000, 4471016)
# 	 | Sparsity:     3.8e-03
# 	 | Memory usage (scipy.csr_array): 0.192 GB (np.array usage: 16.656 GB)

# %%
geom = [{'geom':'Rectangle', 'x0':1250, 'y0':1300, 'xl':250, 'yl':1950, 'inside':False},
        {'geom':'Circle', 'Cx':1300, 'Cy':950, 'r':1470, 'inside':True}, 
        ]
XPCS.gen_plots4mask(e4m_data, itime, Ith_high=1, Nff=10000, mask_geom=geom,)
# Out:
# ################################################################################
# Maximum count in the hull run -> 4689
# # of pixels above Ith_high treshold ->  75 pixels (of 4471016 => 0.0 %)
# ################################################################################

# %%
bs_mask = XPCS.gen_mask(e4m_data, itime, e4m_mask=None, mask_geom=geom)
# Out:
# #################################################
# Masked area =  93.74594052000708 %
# #################################################

# %% [markdown]
# #### Q mask

# %%
Qmask = XPCS.gen_Qmask(Ei, theta, .19, .02, Qmap_plot=True)

# %% [markdown]
# ## XPCS scan (T = 30C Q =  0.19 Å, 20 min @ 1ms (1_200_000 fm)) (GeO2_4_30C, dataset 2, scan 3, 9.7 keV)

# %%
#######################################
sample_name = 'GeO2_4_30C'
Ndataset = 2
Nscan = 4
Nfi, Nff =  None, None
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
#e4m_data = ID10.load_dense_e4m_new(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )

e4m_data = COSMIC.fast_gamma_filter(e4m_data, Imaxth_high=5)
# Out:
# #############################
# command = mtimescan 0.001 1 1200192
# Ei = 9.699998837562536
# itime = 0.0011
# theta = 1.7500000000000004
# Q = 0.15
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00001.h5 (2/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00002.h5 (3/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00003.h5 (4/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00004.h5 (5/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00005.h5 (6/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00006.h5 (7/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00007.h5 (8/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00008.h5 (9/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00009.h5 (10/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00010.h5 (11/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00011.h5 (12/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00012.h5 (13/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00013.h5 (14/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00014.h5 (15/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00015.h5 (16/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00016.h5 (17/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00017.h5 (18/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00018.h5 (19/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00019.h5 (20/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00020.h5 (21/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00021.h5 (22/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00022.h5 (23/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00023.h5 (24/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00024.h5 (25/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00025.h5 (26/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00026.h5 (27/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00027.h5 (28/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00028.h5 (29/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00029.h5 (30/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00030.h5 (31/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00031.h5 (32/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00032.h5 (33/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00033.h5 (34/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00034.h5 (35/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00035.h5 (36/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00036.h5 (37/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00037.h5 (38/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00038.h5 (39/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00039.h5 (40/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00040.h5 (41/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00041.h5 (42/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00042.h5 (43/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00043.h5 (44/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00044.h5 (45/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00045.h5 (46/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00046.h5 (47/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00047.h5 (48/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00048.h5 (49/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00049.h5 (50/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00050.h5 (51/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00051.h5 (52/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00052.h5 (53/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00053.h5 (54/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00054.h5 (55/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00055.h5 (56/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00056.h5 (57/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00057.h5 (58/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00058.h5 (59/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00059.h5 (60/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00060.h5 (61/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00061.h5 (62/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00062.h5 (63/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00063.h5 (64/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00064.h5 (65/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00065.h5 (66/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00066.h5 (67/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00067.h5 (68/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00068.h5 (69/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00069.h5 (70/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00070.h5 (71/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00071.h5 (72/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00072.h5 (73/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00073.h5 (74/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00074.h5 (75/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00075.h5 (76/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00076.h5 (77/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00077.h5 (78/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00078.h5 (79/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00079.h5 (80/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00080.h5 (81/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00081.h5 (82/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00082.h5 (83/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00083.h5 (84/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00084.h5 (85/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00085.h5 (86/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00086.h5 (87/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00087.h5 (88/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00088.h5 (89/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00089.h5 (90/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00090.h5 (91/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00091.h5 (92/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00092.h5 (93/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00093.h5 (94/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00094.h5 (95/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00095.h5 (96/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00096.h5 (97/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00097.h5 (98/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00098.h5 (99/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00099.h5 (100/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00100.h5 (101/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00101.h5 (102/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00102.h5 (103/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00103.h5 (104/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00104.h5 (105/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00105.h5 (106/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00106.h5 (107/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00107.h5 (108/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00108.h5 (109/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00109.h5 (110/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00110.h5 (111/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00111.h5 (112/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00112.h5 (113/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00113.h5 (114/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00114.h5 (115/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00115.h5 (116/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00116.h5 (117/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00117.h5 (118/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00118.h5 (119/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00119.h5 (120/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00120.h5 (121/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00121.h5 (122/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00122.h5 (123/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00123.h5 (124/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00124.h5 (125/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00125.h5 (126/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00126.h5 (127/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00127.h5 (128/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00128.h5 (129/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00129.h5 (130/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00130.h5 (131/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00131.h5 (132/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00132.h5 (133/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00133.h5 (134/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00134.h5 (135/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00135.h5 (136/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00136.h5 (137/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00137.h5 (138/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00138.h5 (139/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00139.h5 (140/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00140.h5 (141/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00141.h5 (142/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00142.h5 (143/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00143.h5 (144/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00144.h5 (145/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00145.h5 (146/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00146.h5 (147/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00147.h5 (148/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00148.h5 (149/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00149.h5 (150/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00150.h5 (151/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00151.h5 (152/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00152.h5 (153/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00153.h5 (154/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00154.h5 (155/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00155.h5 (156/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00156.h5 (157/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00157.h5 (158/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00158.h5 (159/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00159.h5 (160/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00160.h5 (161/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00161.h5 (162/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00162.h5 (163/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00163.h5 (164/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00164.h5 (165/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00165.h5 (166/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00166.h5 (167/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00167.h5 (168/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00168.h5 (169/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00169.h5 (170/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00170.h5 (171/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00171.h5 (172/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00172.h5 (173/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00173.h5 (174/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00174.h5 (175/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00175.h5 (176/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00176.h5 (177/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00177.h5 (178/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00178.h5 (179/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00179.h5 (180/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00180.h5 (181/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00181.h5 (182/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00182.h5 (183/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00183.h5 (184/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00184.h5 (185/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00185.h5 (186/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00186.h5 (187/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00187.h5 (188/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00188.h5 (189/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00189.h5 (190/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00190.h5 (191/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00191.h5 (192/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00192.h5 (193/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00193.h5 (194/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00194.h5 (195/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00195.h5 (196/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00196.h5 (197/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00197.h5 (198/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00198.h5 (199/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00199.h5 (200/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00200.h5 (201/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00201.h5 (202/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00202.h5 (203/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00203.h5 (204/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00204.h5 (205/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00205.h5 (206/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00206.h5 (207/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00207.h5 (208/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00208.h5 (209/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00209.h5 (210/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00210.h5 (211/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00211.h5 (212/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00212.h5 (213/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00213.h5 (214/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00214.h5 (215/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00215.h5 (216/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00216.h5 (217/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00217.h5 (218/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00218.h5 (219/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00219.h5 (220/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00220.h5 (221/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00221.h5 (222/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00222.h5 (223/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00223.h5 (224/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00224.h5 (225/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00225.h5 (226/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00226.h5 (227/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00227.h5 (228/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00228.h5 (229/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00229.h5 (230/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00230.h5 (231/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00231.h5 (232/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00232.h5 (233/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00233.h5 (234/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00234.h5 (235/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00235.h5 (236/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00236.h5 (237/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00237.h5 (238/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00238.h5 (239/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00239.h5 (240/241 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00240.h5 (241/241 loops)
# Done!
# Concatenating vectors ...
# Done!
# 	 | Sparse array loaded from ../RAW_DATA/GeO2_4_30C/GeO2_4_30C_0002/scan0004/
# 	 | Shape:       (1200192, 4471016)
# 	 | Sparsity:     2.3e-04
# 	 | Memory usage (scipy.csr_array): 10.502 GB (np.array usage: 19990.197 GB)
# Filtering gamma ray signal (i.e. signals over treshold) ...
# Done! (elapsed time = 3.86 s)
# Removing gamma ray signal (set 0s) ...
# Done! (elapsed time = 7.34 s)

# %% [markdown]
# ### Flux check

# %%
#############################################
mask = e4m_mask * e4m_htmask * bs_mask
#############################################

XPCS.gen_plots4mask(e4m_data, itime, Ith_high= .4, Nff=100_000, e4m_mask=mask)
# Out:
# ################################################################################
# Maximum count in the hull run -> 5
# # of pixels above Ith_high treshold ->  135 pixels (of 4471016 => 0.0 %)
# ################################################################################

# %% [markdown]
# ### Intensity analysis

# %%
####################
Lbin = 1
Nstep = 100
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
####################

t_It, It = XPCS.get_It(e4m_data, itime, mask=mask, Lbin=Lbin, Nstep=Nstep)
np.savez(Idts_folder+'Idt_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4), t_It=t_It, It=It)

# %%
plt.figure(figsize=(10,5))
plt.scatter(t_It, It, label='It')

plt.xlabel('Time (s)')
plt.ylabel('Integrated intensity [photons/pixel/s]')
plt.xscale('log')
#plt.xlim(1e-2, 1)
plt.gca().secondary_xaxis('top', functions=(lambda x: x/itime, lambda x: x*itime))
plt.grid()

# %% [markdown]
# ### Correlation

# %%
###################
Nfi = 100_000
Nff = None
Lbin = 10
Nbunch = 5
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
###################
if Lbin is None: Lbin=1

G2t = XPCS.get_G2t_bybunch(e4m_data, mask=mask, Nfi=Nfi, Nff=Nff, Lbin=Lbin, Nbunch=Nbunch)
# Out:
# Computing G2t for bunch 1 (Nfi = 100000 , Nff = 320038 ) ...
# Loading frames ...
# Done! (elapsed time = 4.77 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 6.72 s)
# 	 | 22003 frames X 4471016 pixels
# 	 | sparsity = 2.29e-03
# 	 | memory usage (sparse.csr_array @ float64) = 2.513 GB
# Masking data ...
# Done! (elapsed time = 2.81 s)
# 	 | 22003 frames X 1424709 pixels
# 	 | sparsity = 2.48e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.87 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 5.69 s)
# 	 | 22003 X 22003 squared matrix
# 	 | memory usage (np.array @ float64) = 3.607 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.42 s)
#
# Done!
#
# Computing G2t for bunch 2 (Nfi = 320038 , Nff = 540076 ) ...
# Loading frames ...
# Done! (elapsed time = 3.81 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 6.47 s)
# 	 | 22003 frames X 4471016 pixels
# 	 | sparsity = 2.34e-03
# 	 | memory usage (sparse.csr_array @ float64) = 2.571 GB
# Masking data ...
# Done! (elapsed time = 2.4 s)
# 	 | 22003 frames X 1424709 pixels
# 	 | sparsity = 2.54e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.89 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 5.12 s)
# 	 | 22003 X 22003 squared matrix
# 	 | memory usage (np.array @ float64) = 3.607 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 1.88 s)
#
# Done!
#
# Computing G2t for bunch 3 (Nfi = 540076 , Nff = 760114 ) ...
# Loading frames ...
# Done! (elapsed time = 3.75 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 8.18 s)
# 	 | 22003 frames X 4471016 pixels
# 	 | sparsity = 2.37e-03
# 	 | memory usage (sparse.csr_array @ float64) = 2.601 GB
# Masking data ...
# Done! (elapsed time = 3.52 s)
# 	 | 22003 frames X 1424709 pixels
# 	 | sparsity = 2.57e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.901 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 5.39 s)
# 	 | 22003 X 22003 squared matrix
# 	 | memory usage (np.array @ float64) = 3.607 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 2.18 s)
#
# Done!
#
# Computing G2t for bunch 4 (Nfi = 760114 , Nff = 980152 ) ...
# Loading frames ...
# Done! (elapsed time = 3.28 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 7.99 s)
# 	 | 22003 frames X 4471016 pixels
# 	 | sparsity = 2.39e-03
# 	 | memory usage (sparse.csr_array @ float64) = 2.624 GB
# Masking data ...
# Done! (elapsed time = 3.6 s)
# 	 | 22003 frames X 1424709 pixels
# 	 | sparsity = 2.59e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.909 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 5.9 s)
# 	 | 22003 X 22003 squared matrix
# 	 | memory usage (np.array @ float64) = 3.607 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 2.3 s)
#
# Done!
#
# Computing G2t for bunch 5 (Nfi = 980152 , Nff = 1200190 ) ...
# Loading frames ...
# Done! (elapsed time = 3.61 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 9.64 s)
# 	 | 22003 frames X 4471016 pixels
# 	 | sparsity = 2.40e-03
# 	 | memory usage (sparse.csr_array @ float64) = 2.637 GB
# Masking data ...
# Done! (elapsed time = 3.87 s)
# 	 | 22003 frames X 1424709 pixels
# 	 | sparsity = 2.61e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.914 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 5.75 s)
# 	 | 22003 X 22003 squared matrix
# 	 | memory usage (np.array @ float64) = 3.607 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 2.17 s)
#
# Done!

# %%
############################
t1, t2 = 0, 10
vmin, vmax = 1.0, 1.06
############################
XPCS.plot_G2t(G2t, vmin, vmax, itime=itime, t1=t1, t2=t2, sigma_filter=3)

# %%
################
Nbunch = 1
################

NfXbunch = int(G2t.shape[0]/Nbunch)
t, g2, t_mt, g2_mt = {}, {}, {}, {}
for n in range(Nbunch):
    t_bunch = round(itime*Lbin*NfXbunch*(n+1/2),1)

    t[t_bunch], g2[t_bunch] = XPCS.get_g2(itime*Lbin, np.array(G2t[NfXbunch*n:NfXbunch*(n+1), NfXbunch*n:NfXbunch*(n+1)]), cython=False)
    t_mt[t_bunch], g2_mt[t_bunch] = XPCS.get_g2_mt(itime*Lbin, g2[t_bunch])
# Out:
# Computing g2...
# Done! (elapsed time = 0.57 s)

# %%
##################
t1_fit = 0
t2_fit = 1e8
##################
 
plt.figure(figsize=(10,5))
fit_out = pd.DataFrame(columns=['tau', 'beta', 'c', 'y0', 'dtau', 'dbeta', 'dc', 'dy0'])
fit_out.index.name = 't'
for k in g2.keys():
    #plt.scatter(t[k], g2[k], s=1, label = str(k)+'s')
    plt.scatter(t_mt[k], g2_mt[k], label=str(k)+'s')

    popt, pcov = curve_fit(decorelation_f, t[k][(t1_fit<t[k])*(t[k]<t2_fit)], g2[k][(t1_fit<t[k])*(t[k]<t2_fit)], p0=[3, .7, .02, 1], bounds=([0, 0, 0, 0], [np.inf, np.inf, np.inf, np.inf]))
    fit_out.loc[k] = [popt[0], popt[1], popt[2], popt[3], np.sqrt(pcov[0,0]), np.sqrt(pcov[1,1]), np.sqrt(pcov[2,2]), np.sqrt(pcov[3,3])]
    
    x = np.arange(np.min(t[k]), np.max(t[k]), 1e-2)
    y = decorelation_f(x, *popt)
    plt.plot(x, y,)

plt.xlabel('t [s]')
plt.ylabel('g2')
plt.xscale('log')
plt.legend()
plt.show()

if Nbunch == 1:
    print(f'tau = {popt[0]} +/- {np.sqrt(pcov[0,0])}')
    print(f'beta = {popt[1]} +/- {np.sqrt(pcov[1,1])}')
    print(f'c = {popt[2]} +/- {np.sqrt(pcov[2,2])}')
    print(f'y0 = {popt[3]} +/- {np.sqrt(pcov[3,3])}')
else:
    plt.figure(figsize=(10,5))
    plt.title('tau')
    plt.errorbar(fit_out.index, fit_out.tau,  yerr=fit_out.dtau, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('tau [s]')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('beta')
    plt.errorbar(fit_out.index, fit_out.beta,  yerr=fit_out.dbeta, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('beta')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('c')
    plt.errorbar(fit_out.index, fit_out.c,  yerr=fit_out.dc, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('c')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('y0')
    plt.errorbar(fit_out.index, fit_out.y0,  yerr=fit_out.dy0, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('y0')
    plt.show()
# Out:
# tau = 5.850003891843158 +/- 0.18183009075263418
# beta = 0.8083777471893149 +/- 0.020664917566224877
# c = 0.030355579202803427 +/- 0.0005741208212575034
# y0 = 1.0025770556758344 +/- 2.5200645878821166e-05

# %% [markdown]
# ## XPCS scan (T = 30C Q =  0.19 Å, 20 min @ 1ms (1_200_000 fm)) (GeO2_4_30C, dataset 2, scan 5, E = 9.7 keV)

# %%
#######################################
sample_name = 'GeO2_4_30C'
Ndataset = 2
Nscan = 5
Nfi, Nff =  None, None
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
#e4m_data = ID10.load_dense_e4m_new(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )

e4m_data = COSMIC.fast_gamma_filter(e4m_data, Imaxth_high=5)
# Out:
# #############################
# command = mtimescan 0.001 1 2400384
# Ei = 9.699998837562536
# itime = 0.0011
# theta = 1.7500000000000004
# Q = 0.15
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00001.h5 (2/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00002.h5 (3/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00003.h5 (4/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00004.h5 (5/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00005.h5 (6/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00006.h5 (7/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00007.h5 (8/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00008.h5 (9/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00009.h5 (10/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00010.h5 (11/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00011.h5 (12/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00012.h5 (13/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00013.h5 (14/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00014.h5 (15/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00015.h5 (16/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00016.h5 (17/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00017.h5 (18/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00018.h5 (19/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00019.h5 (20/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00020.h5 (21/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00021.h5 (22/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00022.h5 (23/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00023.h5 (24/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00024.h5 (25/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00025.h5 (26/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00026.h5 (27/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00027.h5 (28/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00028.h5 (29/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00029.h5 (30/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00030.h5 (31/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00031.h5 (32/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00032.h5 (33/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00033.h5 (34/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00034.h5 (35/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00035.h5 (36/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00036.h5 (37/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00037.h5 (38/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00038.h5 (39/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00039.h5 (40/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00040.h5 (41/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00041.h5 (42/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00042.h5 (43/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00043.h5 (44/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00044.h5 (45/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00045.h5 (46/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00046.h5 (47/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00047.h5 (48/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00048.h5 (49/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00049.h5 (50/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00050.h5 (51/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00051.h5 (52/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00052.h5 (53/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00053.h5 (54/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00054.h5 (55/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00055.h5 (56/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00056.h5 (57/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00057.h5 (58/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00058.h5 (59/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00059.h5 (60/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00060.h5 (61/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00061.h5 (62/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00062.h5 (63/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00063.h5 (64/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00064.h5 (65/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00065.h5 (66/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00066.h5 (67/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00067.h5 (68/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00068.h5 (69/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00069.h5 (70/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00070.h5 (71/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00071.h5 (72/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00072.h5 (73/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00073.h5 (74/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00074.h5 (75/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00075.h5 (76/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00076.h5 (77/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00077.h5 (78/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00078.h5 (79/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00079.h5 (80/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00080.h5 (81/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00081.h5 (82/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00082.h5 (83/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00083.h5 (84/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00084.h5 (85/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00085.h5 (86/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00086.h5 (87/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00087.h5 (88/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00088.h5 (89/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00089.h5 (90/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00090.h5 (91/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00091.h5 (92/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00092.h5 (93/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00093.h5 (94/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00094.h5 (95/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00095.h5 (96/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00096.h5 (97/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00097.h5 (98/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00098.h5 (99/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00099.h5 (100/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00100.h5 (101/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00101.h5 (102/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00102.h5 (103/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00103.h5 (104/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00104.h5 (105/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00105.h5 (106/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00106.h5 (107/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00107.h5 (108/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00108.h5 (109/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00109.h5 (110/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00110.h5 (111/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00111.h5 (112/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00112.h5 (113/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00113.h5 (114/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00114.h5 (115/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00115.h5 (116/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00116.h5 (117/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00117.h5 (118/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00118.h5 (119/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00119.h5 (120/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00120.h5 (121/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00121.h5 (122/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00122.h5 (123/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00123.h5 (124/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00124.h5 (125/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00125.h5 (126/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00126.h5 (127/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00127.h5 (128/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00128.h5 (129/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00129.h5 (130/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00130.h5 (131/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00131.h5 (132/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00132.h5 (133/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00133.h5 (134/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00134.h5 (135/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00135.h5 (136/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00136.h5 (137/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00137.h5 (138/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00138.h5 (139/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00139.h5 (140/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00140.h5 (141/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00141.h5 (142/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00142.h5 (143/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00143.h5 (144/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00144.h5 (145/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00145.h5 (146/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00146.h5 (147/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00147.h5 (148/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00148.h5 (149/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00149.h5 (150/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00150.h5 (151/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00151.h5 (152/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00152.h5 (153/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00153.h5 (154/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00154.h5 (155/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00155.h5 (156/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00156.h5 (157/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00157.h5 (158/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00158.h5 (159/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00159.h5 (160/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00160.h5 (161/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00161.h5 (162/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00162.h5 (163/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00163.h5 (164/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00164.h5 (165/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00165.h5 (166/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00166.h5 (167/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00167.h5 (168/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00168.h5 (169/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00169.h5 (170/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00170.h5 (171/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00171.h5 (172/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00172.h5 (173/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00173.h5 (174/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00174.h5 (175/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00175.h5 (176/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00176.h5 (177/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00177.h5 (178/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00178.h5 (179/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00179.h5 (180/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00180.h5 (181/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00181.h5 (182/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00182.h5 (183/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00183.h5 (184/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00184.h5 (185/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00185.h5 (186/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00186.h5 (187/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00187.h5 (188/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00188.h5 (189/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00189.h5 (190/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00190.h5 (191/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00191.h5 (192/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00192.h5 (193/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00193.h5 (194/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00194.h5 (195/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00195.h5 (196/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00196.h5 (197/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00197.h5 (198/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00198.h5 (199/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00199.h5 (200/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00200.h5 (201/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00201.h5 (202/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00202.h5 (203/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00203.h5 (204/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00204.h5 (205/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00205.h5 (206/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00206.h5 (207/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00207.h5 (208/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00208.h5 (209/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00209.h5 (210/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00210.h5 (211/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00211.h5 (212/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00212.h5 (213/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00213.h5 (214/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00214.h5 (215/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00215.h5 (216/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00216.h5 (217/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00217.h5 (218/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00218.h5 (219/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00219.h5 (220/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00220.h5 (221/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00221.h5 (222/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00222.h5 (223/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00223.h5 (224/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00224.h5 (225/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00225.h5 (226/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00226.h5 (227/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00227.h5 (228/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00228.h5 (229/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00229.h5 (230/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00230.h5 (231/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00231.h5 (232/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00232.h5 (233/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00233.h5 (234/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00234.h5 (235/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00235.h5 (236/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00236.h5 (237/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00237.h5 (238/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00238.h5 (239/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00239.h5 (240/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00240.h5 (241/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00241.h5 (242/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00242.h5 (243/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00243.h5 (244/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00244.h5 (245/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00245.h5 (246/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00246.h5 (247/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00247.h5 (248/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00248.h5 (249/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00249.h5 (250/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00250.h5 (251/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00251.h5 (252/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00252.h5 (253/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00253.h5 (254/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00254.h5 (255/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00255.h5 (256/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00256.h5 (257/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00257.h5 (258/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00258.h5 (259/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00259.h5 (260/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00260.h5 (261/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00261.h5 (262/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00262.h5 (263/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00263.h5 (264/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00264.h5 (265/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00265.h5 (266/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00266.h5 (267/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00267.h5 (268/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00268.h5 (269/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00269.h5 (270/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00270.h5 (271/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00271.h5 (272/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00272.h5 (273/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00273.h5 (274/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00274.h5 (275/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00275.h5 (276/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00276.h5 (277/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00277.h5 (278/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00278.h5 (279/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00279.h5 (280/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00280.h5 (281/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00281.h5 (282/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00282.h5 (283/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00283.h5 (284/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00284.h5 (285/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00285.h5 (286/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00286.h5 (287/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00287.h5 (288/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00288.h5 (289/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00289.h5 (290/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00290.h5 (291/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00291.h5 (292/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00292.h5 (293/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00293.h5 (294/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00294.h5 (295/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00295.h5 (296/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00296.h5 (297/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00297.h5 (298/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00298.h5 (299/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00299.h5 (300/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00300.h5 (301/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00301.h5 (302/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00302.h5 (303/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00303.h5 (304/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00304.h5 (305/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00305.h5 (306/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00306.h5 (307/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00307.h5 (308/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00308.h5 (309/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00309.h5 (310/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00310.h5 (311/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00311.h5 (312/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00312.h5 (313/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00313.h5 (314/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00314.h5 (315/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00315.h5 (316/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00316.h5 (317/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00317.h5 (318/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00318.h5 (319/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00319.h5 (320/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00320.h5 (321/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00321.h5 (322/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00322.h5 (323/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00323.h5 (324/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00324.h5 (325/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00325.h5 (326/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00326.h5 (327/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00327.h5 (328/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00328.h5 (329/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00329.h5 (330/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00330.h5 (331/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00331.h5 (332/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00332.h5 (333/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00333.h5 (334/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00334.h5 (335/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00335.h5 (336/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00336.h5 (337/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00337.h5 (338/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00338.h5 (339/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00339.h5 (340/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00340.h5 (341/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00341.h5 (342/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00342.h5 (343/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00343.h5 (344/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00344.h5 (345/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00345.h5 (346/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00346.h5 (347/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00347.h5 (348/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00348.h5 (349/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00349.h5 (350/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00350.h5 (351/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00351.h5 (352/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00352.h5 (353/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00353.h5 (354/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00354.h5 (355/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00355.h5 (356/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00356.h5 (357/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00357.h5 (358/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00358.h5 (359/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00359.h5 (360/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00360.h5 (361/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00361.h5 (362/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00362.h5 (363/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00363.h5 (364/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00364.h5 (365/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00365.h5 (366/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00366.h5 (367/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00367.h5 (368/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00368.h5 (369/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00369.h5 (370/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00370.h5 (371/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00371.h5 (372/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00372.h5 (373/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00373.h5 (374/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00374.h5 (375/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00375.h5 (376/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00376.h5 (377/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00377.h5 (378/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00378.h5 (379/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00379.h5 (380/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00380.h5 (381/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00381.h5 (382/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00382.h5 (383/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00383.h5 (384/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00384.h5 (385/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00385.h5 (386/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00386.h5 (387/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00387.h5 (388/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00388.h5 (389/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00389.h5 (390/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00390.h5 (391/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00391.h5 (392/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00392.h5 (393/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00393.h5 (394/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00394.h5 (395/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00395.h5 (396/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00396.h5 (397/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00397.h5 (398/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00398.h5 (399/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00399.h5 (400/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00400.h5 (401/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00401.h5 (402/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00402.h5 (403/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00403.h5 (404/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00404.h5 (405/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00405.h5 (406/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00406.h5 (407/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00407.h5 (408/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00408.h5 (409/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00409.h5 (410/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00410.h5 (411/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00411.h5 (412/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00412.h5 (413/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00413.h5 (414/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00414.h5 (415/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00415.h5 (416/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00416.h5 (417/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00417.h5 (418/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00418.h5 (419/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00419.h5 (420/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00420.h5 (421/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00421.h5 (422/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00422.h5 (423/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00423.h5 (424/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00424.h5 (425/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00425.h5 (426/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00426.h5 (427/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00427.h5 (428/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00428.h5 (429/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00429.h5 (430/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00430.h5 (431/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00431.h5 (432/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00432.h5 (433/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00433.h5 (434/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00434.h5 (435/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00435.h5 (436/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00436.h5 (437/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00437.h5 (438/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00438.h5 (439/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00439.h5 (440/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00440.h5 (441/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00441.h5 (442/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00442.h5 (443/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00443.h5 (444/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00444.h5 (445/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00445.h5 (446/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00446.h5 (447/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00447.h5 (448/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00448.h5 (449/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00449.h5 (450/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00450.h5 (451/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00451.h5 (452/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00452.h5 (453/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00453.h5 (454/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00454.h5 (455/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00455.h5 (456/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00456.h5 (457/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00457.h5 (458/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00458.h5 (459/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00459.h5 (460/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00460.h5 (461/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00461.h5 (462/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00462.h5 (463/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00463.h5 (464/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00464.h5 (465/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00465.h5 (466/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00466.h5 (467/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00467.h5 (468/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00468.h5 (469/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00469.h5 (470/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00470.h5 (471/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00471.h5 (472/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00472.h5 (473/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00473.h5 (474/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00474.h5 (475/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00475.h5 (476/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00476.h5 (477/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00477.h5 (478/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00478.h5 (479/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00479.h5 (480/481 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00480.h5 (481/481 loops)
# Done!
# Concatenating vectors ...
# Done!
# 	 | Sparse array loaded from ../RAW_DATA/GeO2_4_30C/GeO2_4_30C_0002/scan0005/
# 	 | Shape:       (2400384, 4471016)
# 	 | Sparsity:     1.3e-04
# 	 | Memory usage (scipy.csr_array): 11.631 GB (np.array usage: 39980.394 GB)
# Filtering gamma ray signal (i.e. signals over treshold) ...
# Done! (elapsed time = 5.85 s)
# Removing gamma ray signal (set 0s) ...
# Done! (elapsed time = 7.27 s)

# %% [markdown]
# ### Flux check

# %%
#############################################
mask = e4m_mask * e4m_htmask * bs_mask
#############################################

XPCS.gen_plots4mask(e4m_data, itime, Ith_high= .4, Nff=100_000, e4m_mask=mask)
# Out:
# ################################################################################
# Maximum count in the hull run -> 5
# # of pixels above Ith_high treshold ->  1 pixels (of 4471016 => 0.0 %)
# ################################################################################

# %% [markdown]
# ### Intensity analysis

# %%
####################
Lbin = 1
Nstep = 100
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
####################

t_It, It = XPCS.get_It(e4m_data, itime, mask=mask, Lbin=Lbin, Nstep=Nstep)
np.savez(Idts_folder+'Idt_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4), t_It=t_It, It=It)

# %%
plt.figure(figsize=(10,5))
plt.scatter(t_It, It, label='It')

plt.xlabel('Time (s)')
plt.ylabel('Integrated intensity [photons/pixel/s]')
plt.xscale('log')
#plt.xlim(1e-2, 1)
plt.gca().secondary_xaxis('top', functions=(lambda x: x/itime, lambda x: x*itime))
plt.grid()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Correlation

# %%
###################
Nfi = 100_000
Nff = None
Lbin = 10
Nbunch = 5
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
###################
if Lbin is None: Lbin=1

G2t = XPCS.get_G2t_bybunch(e4m_data, mask=mask, Nfi=Nfi, Nff=Nff, Lbin=Lbin, Nbunch=Nbunch)
# Out:
# Computing G2t for bunch 1 (Nfi = 100000 , Nff = 560076 ) ...
# Loading frames ...
# Done! (elapsed time = 1.84 s)
# Binning frames (Lbin = 10, using MKL library) ...
# Done! (elapsed time = 5.07 s)
# 	 | 46007 frames X 4471016 pixels
# 	 | sparsity = 1.24e-03
# 	 | memory usage (sparse.csr_array @ float64) = 2.857 GB
# Masking data ...
# Done! (elapsed time = 2.33 s)
# 	 | 46007 frames X 1424709 pixels
# 	 | sparsity = 1.35e-03
# 	 | memory usage (sparse.csr_array @ float64) = 0.99 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 9.4 s)
# 	 | 46007 X 46007 squared matrix
# 	 | memory usage (np.array @ float64) = 15.77 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 7.03 s)
#
# Done!
#
# Computing G2t for bunch 2 (Nfi = 560076 , Nff = 1020152 ) ...
# Loading frames ...
# Done! (elapsed time = 1.93 s)
# Binning frames (Lbin = 10, using MKL library) ...

# %%
############################
t1, t2 = 0, 10
vmin, vmax = 1.0, 1.06
############################
XPCS.plot_G2t(G2t, vmin, vmax, itime=itime, t1=t1, t2=t2, sigma_filter=3)

# %%
################
Nbunch = 1
################

NfXbunch = int(G2t.shape[0]/Nbunch)
t, g2, t_mt, g2_mt = {}, {}, {}, {}
for n in range(Nbunch):
    t_bunch = round(itime*Lbin*NfXbunch*(n+1/2),1)

    t[t_bunch], g2[t_bunch] = XPCS.get_g2(itime*Lbin, np.array(G2t[NfXbunch*n:NfXbunch*(n+1), NfXbunch*n:NfXbunch*(n+1)]), cython=False)
    t_mt[t_bunch], g2_mt[t_bunch] = XPCS.get_g2_mt(itime*Lbin, g2[t_bunch])
# Out:
# Computing g2...
# Done! (elapsed time = 0.57 s)

# %%
##################
t1_fit = 0
t2_fit = 1e8
##################
 
plt.figure(figsize=(10,5))
fit_out = pd.DataFrame(columns=['tau', 'beta', 'c', 'y0', 'dtau', 'dbeta', 'dc', 'dy0'])
fit_out.index.name = 't'
for k in g2.keys():
    #plt.scatter(t[k], g2[k], s=1, label = str(k)+'s')
    plt.scatter(t_mt[k], g2_mt[k], label=str(k)+'s')

    popt, pcov = curve_fit(decorelation_f, t[k][(t1_fit<t[k])*(t[k]<t2_fit)], g2[k][(t1_fit<t[k])*(t[k]<t2_fit)], p0=[3, .7, .02, 1], bounds=([0, 0, 0, 0], [np.inf, np.inf, np.inf, np.inf]))
    fit_out.loc[k] = [popt[0], popt[1], popt[2], popt[3], np.sqrt(pcov[0,0]), np.sqrt(pcov[1,1]), np.sqrt(pcov[2,2]), np.sqrt(pcov[3,3])]
    
    x = np.arange(np.min(t[k]), np.max(t[k]), 1e-2)
    y = decorelation_f(x, *popt)
    plt.plot(x, y,)

plt.xlabel('t [s]')
plt.ylabel('g2')
plt.xscale('log')
plt.legend()
plt.show()

if Nbunch == 1:
    print(f'tau = {popt[0]} +/- {np.sqrt(pcov[0,0])}')
    print(f'beta = {popt[1]} +/- {np.sqrt(pcov[1,1])}')
    print(f'c = {popt[2]} +/- {np.sqrt(pcov[2,2])}')
    print(f'y0 = {popt[3]} +/- {np.sqrt(pcov[3,3])}')
else:
    plt.figure(figsize=(10,5))
    plt.title('tau')
    plt.errorbar(fit_out.index, fit_out.tau,  yerr=fit_out.dtau, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('tau [s]')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('beta')
    plt.errorbar(fit_out.index, fit_out.beta,  yerr=fit_out.dbeta, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('beta')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('c')
    plt.errorbar(fit_out.index, fit_out.c,  yerr=fit_out.dc, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('c')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('y0')
    plt.errorbar(fit_out.index, fit_out.y0,  yerr=fit_out.dy0, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('y0')
    plt.show()
# Out:
# tau = 5.850003891843158 +/- 0.18183009075263418
# beta = 0.8083777471893149 +/- 0.020664917566224877
# c = 0.030355579202803427 +/- 0.0005741208212575034
# y0 = 1.0025770556758344 +/- 2.5200645878821166e-05

# %% [markdown]
# ## XPCS scan (T = 30C Q =  0.19 Å, 50 min @ 1ms (3_000_000 fm)) (GeO2_4_30C, dataset 2, scan 5, 10.25 keV)

# %%
#######################################
sample_name = 'GeO2_4_10p25'
Ndataset = 1
Nscan = 14
Nfi, Nff =  None, None
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
#e4m_data = ID10.load_dense_e4m_new(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )

e4m_data = COSMIC.fast_gamma_filter(e4m_data, Imaxth_high=5)
# Out:
# #############################
# command = mtimescan 0.001 1 3599664
# Ei = 10.25000164635837
# itime = 0.0011
# theta = 1.7500000000000004
# Q = 0.16
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00001.h5 (2/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00002.h5 (3/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00003.h5 (4/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00004.h5 (5/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00005.h5 (6/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00006.h5 (7/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00007.h5 (8/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00008.h5 (9/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00009.h5 (10/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00010.h5 (11/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00011.h5 (12/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00012.h5 (13/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00013.h5 (14/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00014.h5 (15/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00015.h5 (16/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00016.h5 (17/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00017.h5 (18/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00018.h5 (19/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00019.h5 (20/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00020.h5 (21/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00021.h5 (22/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00022.h5 (23/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00023.h5 (24/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00024.h5 (25/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00025.h5 (26/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00026.h5 (27/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00027.h5 (28/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00028.h5 (29/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00029.h5 (30/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00030.h5 (31/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00031.h5 (32/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00032.h5 (33/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00033.h5 (34/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00034.h5 (35/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00035.h5 (36/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00036.h5 (37/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00037.h5 (38/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00038.h5 (39/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00039.h5 (40/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00040.h5 (41/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00041.h5 (42/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00042.h5 (43/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00043.h5 (44/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00044.h5 (45/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00045.h5 (46/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00046.h5 (47/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00047.h5 (48/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00048.h5 (49/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00049.h5 (50/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00050.h5 (51/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00051.h5 (52/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00052.h5 (53/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00053.h5 (54/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00054.h5 (55/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00055.h5 (56/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00056.h5 (57/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00057.h5 (58/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00058.h5 (59/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00059.h5 (60/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00060.h5 (61/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00061.h5 (62/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00062.h5 (63/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00063.h5 (64/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00064.h5 (65/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00065.h5 (66/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00066.h5 (67/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00067.h5 (68/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00068.h5 (69/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00069.h5 (70/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00070.h5 (71/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00071.h5 (72/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00072.h5 (73/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00073.h5 (74/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00074.h5 (75/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00075.h5 (76/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00076.h5 (77/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00077.h5 (78/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00078.h5 (79/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00079.h5 (80/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00080.h5 (81/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00081.h5 (82/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00082.h5 (83/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00083.h5 (84/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00084.h5 (85/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00085.h5 (86/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00086.h5 (87/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00087.h5 (88/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00088.h5 (89/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00089.h5 (90/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00090.h5 (91/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00091.h5 (92/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00092.h5 (93/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00093.h5 (94/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00094.h5 (95/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00095.h5 (96/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00096.h5 (97/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00097.h5 (98/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00098.h5 (99/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00099.h5 (100/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00100.h5 (101/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00101.h5 (102/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00102.h5 (103/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00103.h5 (104/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00104.h5 (105/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00105.h5 (106/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00106.h5 (107/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00107.h5 (108/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00108.h5 (109/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00109.h5 (110/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00110.h5 (111/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00111.h5 (112/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00112.h5 (113/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00113.h5 (114/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00114.h5 (115/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00115.h5 (116/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00116.h5 (117/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00117.h5 (118/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00118.h5 (119/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00119.h5 (120/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00120.h5 (121/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00121.h5 (122/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00122.h5 (123/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00123.h5 (124/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00124.h5 (125/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00125.h5 (126/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00126.h5 (127/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00127.h5 (128/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00128.h5 (129/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00129.h5 (130/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00130.h5 (131/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00131.h5 (132/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00132.h5 (133/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00133.h5 (134/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00134.h5 (135/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00135.h5 (136/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00136.h5 (137/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00137.h5 (138/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00138.h5 (139/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00139.h5 (140/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00140.h5 (141/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00141.h5 (142/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00142.h5 (143/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00143.h5 (144/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00144.h5 (145/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00145.h5 (146/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00146.h5 (147/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00147.h5 (148/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00148.h5 (149/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00149.h5 (150/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00150.h5 (151/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00151.h5 (152/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00152.h5 (153/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00153.h5 (154/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00154.h5 (155/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00155.h5 (156/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00156.h5 (157/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00157.h5 (158/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00158.h5 (159/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00159.h5 (160/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00160.h5 (161/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00161.h5 (162/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00162.h5 (163/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00163.h5 (164/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00164.h5 (165/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00165.h5 (166/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00166.h5 (167/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00167.h5 (168/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00168.h5 (169/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00169.h5 (170/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00170.h5 (171/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00171.h5 (172/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00172.h5 (173/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00173.h5 (174/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00174.h5 (175/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00175.h5 (176/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00176.h5 (177/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00177.h5 (178/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00178.h5 (179/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00179.h5 (180/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00180.h5 (181/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00181.h5 (182/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00182.h5 (183/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00183.h5 (184/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00184.h5 (185/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00185.h5 (186/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00186.h5 (187/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00187.h5 (188/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00188.h5 (189/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00189.h5 (190/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00190.h5 (191/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00191.h5 (192/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00192.h5 (193/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00193.h5 (194/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00194.h5 (195/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00195.h5 (196/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00196.h5 (197/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00197.h5 (198/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00198.h5 (199/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00199.h5 (200/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00200.h5 (201/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00201.h5 (202/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00202.h5 (203/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00203.h5 (204/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00204.h5 (205/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00205.h5 (206/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00206.h5 (207/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00207.h5 (208/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00208.h5 (209/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00209.h5 (210/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00210.h5 (211/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00211.h5 (212/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00212.h5 (213/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00213.h5 (214/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00214.h5 (215/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00215.h5 (216/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00216.h5 (217/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00217.h5 (218/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00218.h5 (219/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00219.h5 (220/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00220.h5 (221/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00221.h5 (222/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00222.h5 (223/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00223.h5 (224/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00224.h5 (225/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00225.h5 (226/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00226.h5 (227/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00227.h5 (228/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00228.h5 (229/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00229.h5 (230/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00230.h5 (231/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00231.h5 (232/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00232.h5 (233/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00233.h5 (234/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00234.h5 (235/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00235.h5 (236/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00236.h5 (237/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00237.h5 (238/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00238.h5 (239/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00239.h5 (240/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00240.h5 (241/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00241.h5 (242/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00242.h5 (243/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00243.h5 (244/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00244.h5 (245/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00245.h5 (246/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00246.h5 (247/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00247.h5 (248/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00248.h5 (249/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00249.h5 (250/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00250.h5 (251/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00251.h5 (252/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00252.h5 (253/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00253.h5 (254/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00254.h5 (255/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00255.h5 (256/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00256.h5 (257/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00257.h5 (258/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00258.h5 (259/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00259.h5 (260/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00260.h5 (261/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00261.h5 (262/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00262.h5 (263/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00263.h5 (264/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00264.h5 (265/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00265.h5 (266/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00266.h5 (267/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00267.h5 (268/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00268.h5 (269/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00269.h5 (270/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00270.h5 (271/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00271.h5 (272/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00272.h5 (273/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00273.h5 (274/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00274.h5 (275/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00275.h5 (276/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00276.h5 (277/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00277.h5 (278/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00278.h5 (279/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00279.h5 (280/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00280.h5 (281/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00281.h5 (282/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00282.h5 (283/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00283.h5 (284/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00284.h5 (285/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00285.h5 (286/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00286.h5 (287/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00287.h5 (288/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00288.h5 (289/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00289.h5 (290/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00290.h5 (291/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00291.h5 (292/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00292.h5 (293/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00293.h5 (294/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00294.h5 (295/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00295.h5 (296/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00296.h5 (297/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00297.h5 (298/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00298.h5 (299/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00299.h5 (300/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00300.h5 (301/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00301.h5 (302/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00302.h5 (303/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00303.h5 (304/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00304.h5 (305/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00305.h5 (306/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00306.h5 (307/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00307.h5 (308/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00308.h5 (309/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00309.h5 (310/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00310.h5 (311/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00311.h5 (312/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00312.h5 (313/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00313.h5 (314/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00314.h5 (315/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00315.h5 (316/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00316.h5 (317/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00317.h5 (318/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00318.h5 (319/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00319.h5 (320/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00320.h5 (321/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00321.h5 (322/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00322.h5 (323/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00323.h5 (324/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00324.h5 (325/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00325.h5 (326/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00326.h5 (327/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00327.h5 (328/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00328.h5 (329/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00329.h5 (330/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00330.h5 (331/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00331.h5 (332/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00332.h5 (333/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00333.h5 (334/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00334.h5 (335/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00335.h5 (336/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00336.h5 (337/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00337.h5 (338/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00338.h5 (339/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00339.h5 (340/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00340.h5 (341/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00341.h5 (342/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00342.h5 (343/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00343.h5 (344/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00344.h5 (345/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00345.h5 (346/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00346.h5 (347/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00347.h5 (348/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00348.h5 (349/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00349.h5 (350/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00350.h5 (351/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00351.h5 (352/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00352.h5 (353/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00353.h5 (354/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00354.h5 (355/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00355.h5 (356/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00356.h5 (357/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00357.h5 (358/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00358.h5 (359/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00359.h5 (360/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00360.h5 (361/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00361.h5 (362/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00362.h5 (363/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00363.h5 (364/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00364.h5 (365/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00365.h5 (366/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00366.h5 (367/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00367.h5 (368/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00368.h5 (369/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00369.h5 (370/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00370.h5 (371/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00371.h5 (372/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00372.h5 (373/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00373.h5 (374/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00374.h5 (375/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00375.h5 (376/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00376.h5 (377/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00377.h5 (378/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00378.h5 (379/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00379.h5 (380/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00380.h5 (381/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00381.h5 (382/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00382.h5 (383/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00383.h5 (384/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00384.h5 (385/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00385.h5 (386/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00386.h5 (387/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00387.h5 (388/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00388.h5 (389/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00389.h5 (390/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00390.h5 (391/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00391.h5 (392/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00392.h5 (393/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00393.h5 (394/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00394.h5 (395/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00395.h5 (396/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00396.h5 (397/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00397.h5 (398/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00398.h5 (399/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00399.h5 (400/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00400.h5 (401/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00401.h5 (402/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00402.h5 (403/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00403.h5 (404/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00404.h5 (405/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00405.h5 (406/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00406.h5 (407/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00407.h5 (408/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00408.h5 (409/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00409.h5 (410/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00410.h5 (411/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00411.h5 (412/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00412.h5 (413/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00413.h5 (414/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00414.h5 (415/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00415.h5 (416/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00416.h5 (417/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00417.h5 (418/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00418.h5 (419/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00419.h5 (420/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00420.h5 (421/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00421.h5 (422/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00422.h5 (423/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00423.h5 (424/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00424.h5 (425/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00425.h5 (426/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00426.h5 (427/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00427.h5 (428/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00428.h5 (429/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00429.h5 (430/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00430.h5 (431/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00431.h5 (432/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00432.h5 (433/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00433.h5 (434/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00434.h5 (435/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00435.h5 (436/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00436.h5 (437/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00437.h5 (438/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00438.h5 (439/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00439.h5 (440/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00440.h5 (441/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00441.h5 (442/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00442.h5 (443/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00443.h5 (444/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00444.h5 (445/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00445.h5 (446/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00446.h5 (447/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00447.h5 (448/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00448.h5 (449/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00449.h5 (450/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00450.h5 (451/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00451.h5 (452/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00452.h5 (453/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00453.h5 (454/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00454.h5 (455/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00455.h5 (456/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00456.h5 (457/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00457.h5 (458/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00458.h5 (459/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00459.h5 (460/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00460.h5 (461/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00461.h5 (462/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00462.h5 (463/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00463.h5 (464/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00464.h5 (465/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00465.h5 (466/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00466.h5 (467/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00467.h5 (468/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00468.h5 (469/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00469.h5 (470/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00470.h5 (471/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00471.h5 (472/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00472.h5 (473/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00473.h5 (474/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00474.h5 (475/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00475.h5 (476/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00476.h5 (477/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00477.h5 (478/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00478.h5 (479/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00479.h5 (480/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00480.h5 (481/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00481.h5 (482/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00482.h5 (483/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00483.h5 (484/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00484.h5 (485/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00485.h5 (486/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00486.h5 (487/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00487.h5 (488/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00488.h5 (489/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00489.h5 (490/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00490.h5 (491/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00491.h5 (492/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00492.h5 (493/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00493.h5 (494/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00494.h5 (495/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00495.h5 (496/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00496.h5 (497/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00497.h5 (498/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00498.h5 (499/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00499.h5 (500/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00500.h5 (501/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00501.h5 (502/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00502.h5 (503/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00503.h5 (504/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00504.h5 (505/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00505.h5 (506/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00506.h5 (507/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00507.h5 (508/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00508.h5 (509/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00509.h5 (510/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00510.h5 (511/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00511.h5 (512/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00512.h5 (513/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00513.h5 (514/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00514.h5 (515/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00515.h5 (516/624 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_
s)
#
# Done!
#
# Computing G2t for bunch 3 (Nfi = 124652 , Nff = 186978 ) ...
# Loading frames ...
# Done! (elapsed time = 0.68 s)
# 	 | 62326 frames X 4471016 pixels
# 	 | sparsity = 2.43e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.569 GB
# Masking data ...
# Done! (elapsed time = 1.58 s)
# 	 | 62326 frames X 1424709 pixels
# 	 | sparsity = 2.64e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.197 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 9.89 s)
# 	 | 62326 X 62326 squared matrix
# 	 | memory usage (np.array @ float64) = 28.942 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 13.48 s)
#
# Done!
#
# Computing G2t for bunch 4 (Nfi = 186978 , Nff = 249304 ) ...
# Loading frames ...
# Done! (elapsed time = 0.46 s)
# 	 | 62326 frames X 4471016 pixels
# 	 | sparsity = 2.44e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.571 GB
# Masking data ...
# Done! (elapsed time = 2.41 s)
# 	 | 62326 frames X 1424709 pixels
# 	 | sparsity = 2.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.198 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 9.99 s)
# 	 | 62326 X 62326 squared matrix
# 	 | memory usage (np.array @ float64) = 28.942 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 14.19 s)
#
# Done!
#
# Computing G2t for bunch 5 (Nfi = 249304 , Nff = 311630 ) ...
# Loading frames ...
# Done! (elapsed time = 0.46 s)
# 	 | 62326 frames X 4471016 pixels
# 	 | sparsity = 2.45e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.572 GB
# Masking data ...
# Done! (elapsed time = 2.33 s)
# 	 | 62326 frames X 1424709 pixels
# 	 | sparsity = 2.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.198 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 9.9 s)
# 	 | 62326 X 62326 squared matrix
# 	 | memory usage (np.array @ float64) = 28.942 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 14.42 s)
#
# Done!
#
# Computing G2t for bunch 6 (Nfi = 311630 , Nff = 373956 ) ...
# Loading frames ...
# Done! (elapsed time = 0.63 s)
# 	 | 62326 frames X 4471016 pixels
# 	 | sparsity = 2.45e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.572 GB
# Masking data ...
# Done! (elapsed time = 2.18 s)
# 	 | 62326 frames X 1424709 pixels
# 	 | sparsity = 2.65e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.198 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 10.12 s)
# 	 | 62326 X 62326 squared matrix
# 	 | memory usage (np.array @ float64) = 28.942 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 14.69 s)
#
# Done!
#
# Computing G2t for bunch 7 (Nfi = 373956 , Nff = 436282 ) ...
# Loading frames ...
# Done! (elapsed time = 0.85 s)
# 	 | 62326 frames X 4471016 pixels
# 	 | sparsity = 2.45e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.573 GB
# Masking data ...
# Done! (elapsed time = 1.55 s)
# 	 | 62326 frames X 1424709 pixels
# 	 | sparsity = 2.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.198 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 9.85 s)
# 	 | 62326 X 62326 squared matrix
# 	 | memory usage (np.array @ float64) = 28.942 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 13.12 s)
#
# Done!
#
# Computing G2t for bunch 8 (Nfi = 436282 , Nff = 498608 ) ...
# Loading frames ...
# Done! (elapsed time = 0.42 s)
# 	 | 62326 frames X 4471016 pixels
# 	 | sparsity = 2.45e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.573 GB
# Masking data ...
# Done! (elapsed time = 1.38 s)
# 	 | 62326 frames X 1424709 pixels
# 	 | sparsity = 2.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.198 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 9.7 s)
# 	 | 62326 X 62326 squared matrix
# 	 | memory usage (np.array @ float64) = 28.942 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 13.87 s)
#
# Done!
#
# Computing G2t for bunch 9 (Nfi = 498608 , Nff = 560934 ) ...
# Loading frames ...
# Done! (elapsed time = 0.54 s)
# 	 | 62326 frames X 4471016 pixels
# 	 | sparsity = 2.45e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.573 GB
# Masking data ...
# Done! (elapsed time = 3.25 s)
# 	 | 62326 frames X 1424709 pixels
# 	 | sparsity = 2.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.198 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 10.14 s)
# 	 | 62326 X 62326 squared matrix
# 	 | memory usage (np.array @ float64) = 28.942 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 16.7 s)
#
# Done!
#
# Computing G2t for bunch 10 (Nfi = 560934 , Nff = 623260 ) ...
# Loading frames ...
# Done! (elapsed time = 0.7 s)
# 	 | 62326 frames X 4471016 pixels
# 	 | sparsity = 2.45e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.573 GB
# Masking data ...
# Done! (elapsed time = 2.92 s)
# 	 | 62326 frames X 1424709 pixels
# 	 | sparsity = 2.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.198 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 9.99 s)
# 	 | 62326 X 62326 squared matrix
# 	 | memory usage (np.array @ float64) = 28.942 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 13.77 s)
#
# Done!
#
# Computing G2t for bunch 11 (Nfi = 623260 , Nff = 685586 ) ...
# Loading frames ...
# Done! (elapsed time = 0.42 s)
# 	 | 62326 frames X 4471016 pixels
# 	 | sparsity = 2.45e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.573 GB
# Masking data ...
# Done! (elapsed time = 1.37 s)
# 	 | 62326 frames X 1424709 pixels
# 	 | sparsity = 2.66e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.198 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 10.13 s)
# 	 | 62326 X 62326 squared matrix
# 	 | memory usage (np.array @ float64) = 28.942 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 13.81 s)
#
# Done!
#
# Computing G2t for bunch 12 (Nfi = 685586 , Nff = 747912 ) ...
# Loading frames ...
# Done! (elapsed time = 0.71 s)
# 	 | 62326 frames X 4471016 pixels
# 	 | sparsity = 2.53e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.59 GB
# Masking data ...
# Done! (elapsed time = 1.74 s)
# 	 | 62326 frames X 1424709 pixels
# 	 | sparsity = 2.74e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.204 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 9.96 s)
# 	 | 62326 X 62326 squared matrix
# 	 | memory usage (np.array @ float64) = 28.942 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 14.46 s)
#
# Done!
#
# Computing G2t for bunch 13 (Nfi = 747912 , Nff = 810238 ) ...
# Loading frames ...
# Done! (elapsed time = 0.44 s)
# 	 | 62326 frames X 4471016 pixels
# 	 | sparsity = 2.54e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.594 GB
# Masking data ...
# Done! (elapsed time = 1.43 s)
# 	 | 62326 frames X 1424709 pixels
# 	 | sparsity = 2.75e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.205 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 10.07 s)
# 	 | 62326 X 62326 squared matrix
# 	 | memory usage (np.array @ float64) = 28.942 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 14.83 s)
#
# Done!
#
# Computing G2t for bunch 14 (Nfi = 810238 , Nff = 872564 ) ...
# Loading frames ...
# Done! (elapsed time = 0.86 s)
# 	 | 62326 frames X 4471016 pixels
# 	 | sparsity = 2.54e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.594 GB
# Masking data ...
# Done! (elapsed time = 1.51 s)
# 	 | 62326 frames X 1424709 pixels
# 	 | sparsity = 2.75e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.205 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 9.97 s)
# 	 | 62326 X 62326 squared matrix
# 	 | memory usage (np.array @ float64) = 28.942 GB
# Normalizing G2t (using NumExpr library)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 10
#       7 ###################
#       8 if Lbin is None: Lbin=1
# ---> 10 G2t = XPCS.get_G2t_bybunch(e4m_data, mask=mask, Nfi=Nfi, Nff=Nff, Lbin=Lbin, Nbunch=Nbunch)
#
# File /mnt/storage/data/visitor/hc6209/id10-coh/20250408/SCRIPTS/XPCS_library/XPCS_tools.py:727, in get_G2t_bybunch(e4m_data, Nbunch, mask, Nfi, Nff, Lbin, MKL_library, NumExpr_library)
#     725 for i in range(Nbunch):
#     726     print('Computing G2t for bunch', i+1, '(Nfi =', Nfi+i*Lbunch, ', Nff =', Nfi+(i+1)*Lbunch, ') ...')
# --> 727     G2t += get_G2t(e4m_data, mask, Nfi=Nfi+i*Lbunch, Nff=Nfi+(i+1)*Lbunch, Lbin=Lbin, MKL_library=MKL_library, NumExpr_library=NumExpr_library)
#     728     print('Done!\n')
#     730 return G2t/Nbunch
#
# File /mnt/storage/data/visitor/hc6209/id10-coh/20250408/SCRIPTS/XPCS_library/XPCS_tools.py:666, in get_G2t(e4m_data, mask, Nfi, Nff, Lbin, MKL_library, NumExpr_library)
#     664     Itr = It[:, None] # q[:, None] -> q.reshape(N, 1)
#     665     Itc = It[None, :] # q[None, :] -> q.reshape(1, N)
# --> 666     ne.evaluate('G2t*Itr*Itc', out=G2t)
#     667 else:
#     668     np.multiply(G2t, It[:,None], out=G2t)
#
# File ~/anaconda3/envs/XPCSenv/lib/python3.13/site-packages/numexpr/necompiler.py:975, in evaluate(ex, local_dict, global_dict, out, order, casting, sanitize, _frame_depth, **kwargs)
#     971 e = validate(ex, local_dict=local_dict, global_dict=global_dict,
#     972              out=out, order=order, casting=casting,
#     973              _frame_depth=_frame_depth, sanitize=sanitize, **kwargs)
#     974 if e is None:
# --> 975     return re_evaluate(local_dict=local_dict, global_dict=global_dict, _frame_depth=_frame_depth)
#     976 else:
#     977     raise e
#
# File ~/anaconda3/envs/XPCSenv/lib/python3.13/site-packages/numexpr/necompiler.py:1007, in re_evaluate(local_dict, global_dict, _frame_depth)
#    1005 kwargs = _numexpr_last['kwargs']
#    1006 with evaluate_lock:
# -> 1007     return compiled_ex(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
############################
t1, t2 = 0, 10
vmin, vmax = 1.0, 1.06
############################
XPCS.plot_G2t(G2t, vmin, vmax, itime=itime, t1=t1, t2=t2, sigma_filter=3)

# %%
################
Nbunch = 1
################

NfXbunch = int(G2t.shape[0]/Nbunch)
t, g2, t_mt, g2_mt = {}, {}, {}, {}
for n in range(Nbunch):
    t_bunch = round(itime*Lbin*NfXbunch*(n+1/2),1)

    t[t_bunch], g2[t_bunch] = XPCS.get_g2(itime*Lbin, np.array(G2t[NfXbunch*n:NfXbunch*(n+1), NfXbunch*n:NfXbunch*(n+1)]), cython=False)
    t_mt[t_bunch], g2_mt[t_bunch] = XPCS.get_g2_mt(itime*Lbin, g2[t_bunch])
# Out:
# Computing g2...
# Done! (elapsed time = 1.79 s)

# %%
##################
t1_fit = 0
t2_fit = 1e8
##################
 
plt.figure(figsize=(10,5))
fit_out = pd.DataFrame(columns=['tau', 'beta', 'c', 'y0', 'dtau', 'dbeta', 'dc', 'dy0'])
fit_out.index.name = 't'
for k in g2.keys():
    #plt.scatter(t[k], g2[k], s=1, label = str(k)+'s')
    plt.scatter(t_mt[k], g2_mt[k], label=str(k)+'s')

    popt, pcov = curve_fit(decorelation_f, t[k][(t1_fit<t[k])*(t[k]<t2_fit)], g2[k][(t1_fit<t[k])*(t[k]<t2_fit)], p0=[3, .7, .02, 1], bounds=([0, 0, 0, 0], [np.inf, np.inf, np.inf, np.inf]))
    fit_out.loc[k] = [popt[0], popt[1], popt[2], popt[3], np.sqrt(pcov[0,0]), np.sqrt(pcov[1,1]), np.sqrt(pcov[2,2]), np.sqrt(pcov[3,3])]
    
    x = np.arange(np.min(t[k]), np.max(t[k]), 1e-4)
    y = decorelation_f(x, *popt)
    plt.plot(x, y,)

plt.xlabel('t [s]')
plt.ylabel('g2')
plt.xscale('log')
plt.legend()
plt.show()

if Nbunch == 1:
    print(f'tau = {popt[0]} +/- {np.sqrt(pcov[0,0])}')
    print(f'beta = {popt[1]} +/- {np.sqrt(pcov[1,1])}')
    print(f'c = {popt[2]} +/- {np.sqrt(pcov[2,2])}')
    print(f'y0 = {popt[3]} +/- {np.sqrt(pcov[3,3])}')
else:
    plt.figure(figsize=(10,5))
    plt.title('tau')
    plt.errorbar(fit_out.index, fit_out.tau,  yerr=fit_out.dtau, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('tau [s]')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('beta')
    plt.errorbar(fit_out.index, fit_out.beta,  yerr=fit_out.dbeta, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('beta')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('c')
    plt.errorbar(fit_out.index, fit_out.c,  yerr=fit_out.dc, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('c')
    plt.xlim(0)
    plt.show()

    plt.figure(figsize=(10,5))
    plt.title('y0')
    plt.errorbar(fit_out.index, fit_out.y0,  yerr=fit_out.dy0, fmt='o')
    plt.xlabel('t [s]')
    plt.ylabel('y0')
    plt.show()
# Out:
# tau = 0.2299969741672385 +/- 0.010283896937404769
# beta = 0.6260230763061072 +/- 0.015297183932521625
# c = 0.11999999999999998 +/- 0.0027195565783599807
# y0 = 1.0031999109599095 +/- 4.5141098019705e-05

# %% [markdown]
# ## XPCS scan (T = 30C Q =  0.19 Å, 20 min @ 1ms (1_200_000 fm)) (GeO2_4_30C, dataset 2, scan 5, 10.25 keV, fresh point)

# %%
#######################################
sample_name = 'GeO2_4_10p25'
Ndataset = 1
Nscan = 15
Nfi, Nff =  None, None
#######################################

scan = ID10.load_scan(raw_folder, sample_name, Ndataset, Nscan)
Ei = scan['monoe']
itime = scan['fast_timer_period'][0]
theta = scan['delcoup']
Q = round(XPCS.theta2Q(Ei,  theta),2)

print('#############################')
print('command =', scan['command'])
print('Ei =', Ei)
print('itime =', itime)
print('theta =', theta)
print('Q =', Q)
print('#############################\n')

e4m_data = ID10.load_sparse_e4m(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )
#e4m_data = ID10.load_dense_e4m_new(raw_folder, sample_name, Ndataset, Nscan, Nfi, Nff,  n_jobs=1, )

e4m_data = COSMIC.fast_gamma_filter(e4m_data, Imaxth_high=5)
# Out:
# #############################
# command = mtimescan 0.001 1 3599664
# Ei = 10.25000164635837
# itime = 0.0011
# theta = 1.7500000000000004
# Q = 0.16
# #############################
#
# Loading sparse array ...
# 	 -> loading file eiger4m_v2_sparse_frame_0_00000.h5 (1/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00001.h5 (2/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00002.h5 (3/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00003.h5 (4/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00004.h5 (5/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00005.h5 (6/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00006.h5 (7/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00007.h5 (8/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00008.h5 (9/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00009.h5 (10/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00010.h5 (11/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00011.h5 (12/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00012.h5 (13/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00013.h5 (14/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00014.h5 (15/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00015.h5 (16/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00016.h5 (17/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00017.h5 (18/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00018.h5 (19/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00019.h5 (20/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00020.h5 (21/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00021.h5 (22/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00022.h5 (23/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00023.h5 (24/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00024.h5 (25/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00025.h5 (26/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00026.h5 (27/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00027.h5 (28/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00028.h5 (29/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00029.h5 (30/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00030.h5 (31/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00031.h5 (32/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00032.h5 (33/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00033.h5 (34/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00034.h5 (35/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00035.h5 (36/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00036.h5 (37/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00037.h5 (38/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00038.h5 (39/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00039.h5 (40/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00040.h5 (41/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00041.h5 (42/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00042.h5 (43/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00043.h5 (44/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00044.h5 (45/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00045.h5 (46/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00046.h5 (47/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00047.h5 (48/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00048.h5 (49/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00049.h5 (50/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00050.h5 (51/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00051.h5 (52/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00052.h5 (53/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00053.h5 (54/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00054.h5 (55/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00055.h5 (56/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00056.h5 (57/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00057.h5 (58/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00058.h5 (59/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00059.h5 (60/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00060.h5 (61/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00061.h5 (62/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00062.h5 (63/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00063.h5 (64/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00064.h5 (65/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00065.h5 (66/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00066.h5 (67/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00067.h5 (68/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00068.h5 (69/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00069.h5 (70/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00070.h5 (71/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00071.h5 (72/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00072.h5 (73/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00073.h5 (74/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00074.h5 (75/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00075.h5 (76/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00076.h5 (77/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00077.h5 (78/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00078.h5 (79/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00079.h5 (80/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00080.h5 (81/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00081.h5 (82/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00082.h5 (83/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00083.h5 (84/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00084.h5 (85/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00085.h5 (86/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00086.h5 (87/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00087.h5 (88/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00088.h5 (89/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00089.h5 (90/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00090.h5 (91/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00091.h5 (92/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00092.h5 (93/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00093.h5 (94/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00094.h5 (95/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00095.h5 (96/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00096.h5 (97/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00097.h5 (98/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00098.h5 (99/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00099.h5 (100/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00100.h5 (101/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00101.h5 (102/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00102.h5 (103/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00103.h5 (104/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00104.h5 (105/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00105.h5 (106/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00106.h5 (107/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00107.h5 (108/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00108.h5 (109/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00109.h5 (110/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00110.h5 (111/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00111.h5 (112/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00112.h5 (113/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00113.h5 (114/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00114.h5 (115/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00115.h5 (116/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00116.h5 (117/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00117.h5 (118/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00118.h5 (119/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00119.h5 (120/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00120.h5 (121/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00121.h5 (122/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00122.h5 (123/124 loops)
# 	 -> loading file eiger4m_v2_sparse_frame_0_00123.h5 (124/124 loops)
# Done!
# Concatenating vectors ...
# Done!
# 	 | Sparse array loaded from ../RAW_DATA/GeO2_4_10p25/GeO2_4_10p25_0001/scan0015/
# 	 | Shape:       (620000, 4471016)
# 	 | Sparsity:     2.3e-04
# 	 | Memory usage (scipy.csr_array): 5.393 GB (np.array usage: 10326.616 GB)
# Filtering gamma ray signal (i.e. signals over treshold) ...
# Done! (elapsed time = 2.8 s)
# Removing gamma ray signal (set 0s) ...
# Done! (elapsed time = 3.14 s)

# %% [markdown]
# ### Flux check

# %%
#############################################
mask = e4m_mask * e4m_htmask * bs_mask
#############################################

XPCS.gen_plots4mask(e4m_data, itime, Ith_high= .4, Nff=100_000, e4m_mask=mask)
# Out:
# ################################################################################
# Maximum count in the hull run -> 5
# # of pixels above Ith_high treshold ->  1231 pixels (of 4471016 => 0.04 %)
# ################################################################################

# %% [markdown]
# ### Intensity analysis

# %%
####################
Lbin = 1
Nstep = 10
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
####################

t_It, It = XPCS.get_It(e4m_data, itime, mask=mask, Lbin=Lbin, Nstep=Nstep)
np.savez(Idts_folder+'Idt_'+sample_name+'_'+str(Ndataset).zfill(4)+'_'+str(Nscan).zfill(4), t_It=t_It, It=It)

# %%
plt.figure(figsize=(10,5))
plt.scatter(t_It, It, label='It')

plt.xlabel('Time (s)')
plt.ylabel('Integrated intensity [photons/pixel/s]')
plt.xscale('log')
#plt.xlim(1e-2, 1)
plt.gca().secondary_xaxis('top', functions=(lambda x: x/itime, lambda x: x*itime))
plt.grid()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Correlation

# %%
###################
Nfi = None
Nff = None
Lbin = 1
Nbunch = 50
mask = e4m_mask * e4m_htmask * bs_mask * Qmask
###################
if Lbin is None: Lbin=1

G2t = XPCS.get_G2t_bybunch(e4m_data, mask=mask, Nfi=Nfi, Nff=Nff, Lbin=Lbin, Nbunch=Nbunch)
# Out:
# Computing G2t for bunch 1 (Nfi = 0 , Nff = 8400 ) ...
# Loading frames ...
# Done! (elapsed time = 0.1 s)
# 	 | 8400 frames X 4471016 pixels
# 	 | sparsity = 2.06e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.065 GB
# Masking data ...
# Done! (elapsed time = 0.36 s)
# 	 | 8400 frames X 1424709 pixels
# 	 | sparsity = 2.25e-04
# 	 | memory usage (sparse.csr_array @ uint8) = 0.023 GB
# Computing G2t (using MKL library)...
# Done! (elapsed time = 0.16 s)
# 	 | 8400 X 8400 squared matrix
# 	 | memory usage (np.array @ float64) = 0.526 GB
# Normalizing G2t (using NumExpr library)...
# Done! (elapsed time = 0.03 s)
#
# Done!
#
# Computing G2t for bunch 2 (Nfi =